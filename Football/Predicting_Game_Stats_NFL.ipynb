# %% [markdown]
# # Predicting NFL Game Stats

# %% [markdown]
# ## Predicting QB Passing Yards in Game<br>
#
# In this initial version of this code, I will attempt to predict QB passing yards in a regular season game.  My plan is to expand this code to predict other stats in a regular season OR postseason game (rushing yards, total score, etc.).
# <br>
# I will use play-by-play data from the `nfl_data_py` Python package
# <br>
# **Credit to *Tim Bryan* for inspiring this project and giving a general framework of how to approach it**

# %%
import warnings
import numpy as np
import pandas as pd
import nfl_data_py as nfl
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display
from ipywidgets import interactive, BoundedFloatText, IntText, ToggleButtons, Layout

## Turn off max columns for Pandas DataFrame
pd.set_option('display.max_columns', None)

pd.set_option('display.max_colwidth', None)

## View the column names of the NFL play-by-play data table 
for colname in nfl.see_pbp_cols():
    print(colname)
# Out:
# play_id
# game_id
# old_game_id
# home_team
# away_team
# season_type
# week
# posteam
# posteam_type
# defteam
# side_of_field
# yardline_100
# game_date
# quarter_seconds_remaining
# half_seconds_remaining
# game_seconds_remaining
# game_half
# quarter_end
# drive
# sp
# qtr
# down
# goal_to_go
# time
# yrdln
# ydstogo
# ydsnet
# desc
# play_type
# yards_gained
# shotgun
# no_huddle
# qb_dropback
# qb_kneel
# qb_spike
# qb_scramble
# pass_length
# pass_location
# air_yards
# yards_after_catch
# run_location
# run_gap
# field_goal_result
# kick_distance
# extra_point_result
# two_point_conv_result
# home_timeouts_remaining
# away_timeouts_remaining
# timeout
# timeout_team
# td_team
# td_player_name
# td_player_id
# posteam_timeouts_remaining
# defteam_timeouts_remaining
# total_home_score
# total_away_score
# posteam_score
# defteam_score
# score_differential
# posteam_score_post
# defteam_score_post
# score_differential_post
# no_score_prob
# opp_fg_prob
# opp_safety_prob
# opp_td_prob
# fg_prob
# safety_prob
# td_prob
# extra_point_prob
# two_point_conversion_prob
# ep
# epa
# total_home_epa
# total_away_epa
# total_home_rush_epa
# total_away_rush_epa
# total_home_pass_epa
# total_away_pass_epa
# air_epa
# yac_epa
# comp_air_epa
# comp_yac_epa
# total_home_comp_air_epa
# total_away_comp_air_epa
# total_home_comp_yac_epa
# total_away_comp_yac_epa
# total_home_raw_air_epa
# total_away_raw_air_epa
# total_home_raw_yac_epa
# total_away_raw_yac_epa
# wp
# def_wp
# home_wp
# away_wp
# wpa
# vegas_wpa
# vegas_home_wpa
# home_wp_post
# away_wp_post
# vegas_wp
# vegas_home_wp
# total_home_rush_wpa
# total_away_rush_wpa
# total_home_pass_wpa
# total_away_pass_wpa
# air_wpa
# yac_wpa
# comp_air_wpa
# comp_yac_wpa
# total_home_comp_air_wpa
# total_away_comp_air_wpa
# total_home_comp_yac_wpa
# total_away_comp_yac_wpa
# total_home_raw_air_wpa
# total_away_raw_air_wpa
# total_home_raw_yac_wpa
# total_away_raw_yac_wpa
# punt_blocked
# first_down_rush
# first_down_pass
# first_down_penalty
# third_down_converted
# third_down_failed
# fourth_down_converted
# fourth_down_failed
# incomplete_pass
# touchback
# interception
# punt_inside_twenty
# punt_in_endzone
# punt_out_of_bounds
# punt_downed
# punt_fair_catch
# kickoff_inside_twenty
# kickoff_in_endzone
# kickoff_out_of_bounds
# kickoff_downed
# kickoff_fair_catch
# fumble_forced
# fumble_not_forced
# fumble_out_of_bounds
# solo_tackle
# safety
# penalty
# tackled_for_loss
# fumble_lost
# own_kickoff_recovery
# own_kickoff_recovery_td
# qb_hit
# rush_attempt
# pass_attempt
# sack
# touchdown
# pass_touchdown
# rush_touchdown
# return_touchdown
# extra_point_attempt
# two_point_attempt
# field_goal_attempt
# kickoff_attempt
# punt_attempt
# fumble
# complete_pass
# assist_tackle
# lateral_reception
# lateral_rush
# lateral_return
# lateral_recovery
# passer_player_id
# passer_player_name
# passing_yards
# receiver_player_id
# receiver_player_name
# receiving_yards
# rusher_player_id
# rusher_player_name
# rushing_yards
# lateral_receiver_player_id
# lateral_receiver_player_name
# lateral_receiving_yards
# lateral_rusher_player_id
# lateral_rusher_player_name
# lateral_rushing_yards
# lateral_sack_player_id
# lateral_sack_player_name
# interception_player_id
# interception_player_name
# lateral_interception_player_id
# lateral_interception_player_name
# punt_returner_player_id
# punt_returner_player_name
# lateral_punt_returner_player_id
# lateral_punt_returner_player_name
# kickoff_returner_player_name
# kickoff_returner_player_id
# lateral_kickoff_returner_player_id
# lateral_kickoff_returner_player_name
# punter_player_id
# punter_player_name
# kicker_player_name
# kicker_player_id
# own_kickoff_recovery_player_id
# own_kickoff_recovery_player_name
# blocked_player_id
# blocked_player_name
# tackle_for_loss_1_player_id
# tackle_for_loss_1_player_name
# tackle_for_loss_2_player_id
# tackle_for_loss_2_player_name
# qb_hit_1_player_id
# qb_hit_1_player_name
# qb_hit_2_player_id
# qb_hit_2_player_name
# forced_fumble_player_1_team
# forced_fumble_player_1_player_id
# forced_fumble_player_1_player_name
# forced_fumble_player_2_team
# forced_fumble_player_2_player_id
# forced_fumble_player_2_player_name
# solo_tackle_1_team
# solo_tackle_2_team
# solo_tackle_1_player_id
# solo_tackle_2_player_id
# solo_tackle_1_player_name
# solo_tackle_2_player_name
# assist_tackle_1_player_id
# assist_tackle_1_player_name
# assist_tackle_1_team
# assist_tackle_2_player_id
# assist_tackle_2_player_name
# assist_tackle_2_team
# assist_tackle_3_player_id
# assist_tackle_3_player_name
# assist_tackle_3_team
# assist_tackle_4_player_id
# assist_tackle_4_player_name
# assist_tackle_4_team
# tackle_with_assist
# tackle_with_assist_1_player_id
# tackle_with_assist_1_player_name
# tackle_with_assist_1_team
# tackle_with_assist_2_player_id
# tackle_with_assist_2_player_name
# tackle_with_assist_2_team
# pass_defense_1_player_id
# pass_defense_1_player_name
# pass_defense_2_player_id
# pass_defense_2_player_name
# fumbled_1_team
# fumbled_1_player_id
# fumbled_1_player_name
# fumbled_2_player_id
# fumbled_2_player_name
# fumbled_2_team
# fumble_recovery_1_team
# fumble_recovery_1_yards
# fumble_recovery_1_player_id
# fumble_recovery_1_player_name
# fumble_recovery_2_team
# fumble_recovery_2_yards
# fumble_recovery_2_player_id
# fumble_recovery_2_player_name
# sack_player_id
# sack_player_name
# half_sack_1_player_id
# half_sack_1_player_name
# half_sack_2_player_id
# half_sack_2_player_name
# return_team
# return_yards
# penalty_team
# penalty_player_id
# penalty_player_name
# penalty_yards
# replay_or_challenge
# replay_or_challenge_result
# penalty_type
# defensive_two_point_attempt
# defensive_two_point_conv
# defensive_extra_point_attempt
# defensive_extra_point_conv
# safety_player_name
# safety_player_id
# season
# cp
# cpoe
# series
# series_success
# series_result
# order_sequence
# start_time
# time_of_day
# stadium
# weather
# nfl_api_id
# play_clock
# play_deleted
# play_type_nfl
# special_teams_play
# st_play_type
# end_clock_time
# end_yard_line
# fixed_drive
# fixed_drive_result
# drive_real_start_time
# drive_play_count
# drive_time_of_possession
# drive_first_downs
# drive_inside20
# drive_ended_with_score
# drive_quarter_start
# drive_quarter_end
# drive_yards_penalized
# drive_start_transition
# drive_end_transition
# drive_game_clock_start
# drive_game_clock_end
# drive_start_yard_line
# drive_end_yard_line
# drive_play_id_started
# drive_play_id_ended
# away_score
# home_score
# location
# result
# total
# spread_line
# total_line
# div_game
# roof
# surface
# temp
# wind
# home_coach
# away_coach
# stadium_id
# game_stadium
# aborted_play
# success
# passer
# passer_jersey_number
# rusher
# rusher_jersey_number
# receiver
# receiver_jersey_number
# pass
# rush
# first_down
# special
# play
# passer_id
# rusher_id
# receiver_id
# name
# jersey_number
# id
# fantasy_player_name
# fantasy_player_id
# fantasy
# fantasy_id
# out_of_bounds
# home_opening_kickoff
# qb_epa
# xyac_epa
# xyac_mean_yardage
# xyac_median_yardage
# xyac_success
# xyac_fd
# xpass
# pass_oe

# %%
# cols = ['season', 'week', 'play_type', 'incomplete_pass', 'complete_pass', 'interception', 'desc', 'posteam', 'posteam_type', 'defteam',
#         'epa', 'total_home_epa', 'total_away_epa', 'total_home_pass_epa', 'total_away_pass_epa',
#         'wpa', 'total_home_pass_wpa', 'total_away_pass_wpa'
#        ]

# df = nfl.import_pbp_data(range(2006, 2023), cols)
# print()

# df = df[cols]

# df = df[~df['play_type'].isna()]

# df.head(180)

# %%
# df2 = df[df['total_home_pass_epa'] != 0.]

# print(np.all(df['total_home_epa'] == df['total_away_epa'] * -1.))
# print(np.all(df2['total_home_pass_epa'] == df2['total_away_pass_epa'] * -1.))
# print(np.all(df2['total_home_pass_wpa'] == df2['total_away_pass_wpa'] * -1.))

# %% [markdown]
# These are the initial columns I am selecting to predict passing yards with (very likely to change and be reordered in a more logical way):
# <br>
# `'passer_player_name',
# 'season',
# 'season_type',
# 'week',
# 'home_team',
# 'away_team',
# 'posteam',
# 'posteam_type',
# 'defteam',
# 'desc',
# 'play_type',
# 'pass_attempt',
# 'incomplete_pass',
# 'complete_pass',
# 'pass_oe',
# 'cpoe',
# 'passing_yards',
# 'air_yards',
# 'yards_after_catch',
# 'pass_touchdown',
# 'interception',
# 'fumble_lost',
# 'fumbled_1_team',
# 'fumbled_2_team',
# 'fumble_recovery_1_team',
# 'fumble_recovery_2_team',
# 'qb_hit',
# 'sack',
# 'touchback',
# 'penalty',
# 'penalty_team',
# 'penalty_yards',
# 'epa',
# 'wpa',
# 'home_score',
# 'away_score'`

# %%
## Creating a list of columns to use for the QB data
## I want to include "roof," "temp," and "wind" but a lot of the data is missing. 
## "Roof" is missing by far the least (53 games all in 2021) of the three, and can be populated and used with some extra time
pbp_columns = [
    'passer_player_name',
    'season',
    'season_type',
    'week',
    'home_team',
    'away_team',
    'posteam',
    'posteam_type',
    'defteam',
    #'game_seconds_remaining',
    'desc',
    'play_type',
    'pass_attempt',
    'incomplete_pass',
    'complete_pass',
    'pass_oe',
    'cpoe',
    'passing_yards',
    'air_yards',
    'yards_after_catch',
    'pass_touchdown',
    'interception',
    'fumble_lost',
    'fumbled_1_team', 
    'fumbled_2_team',
    'fumble_recovery_1_team',
    'fumble_recovery_2_team',
    'qb_hit',
    'sack',
    'touchback',
    'penalty',
    'penalty_team',
    'penalty_yards',
    'epa',
    'wpa',
    'home_score',
    'away_score'
]

seasons = range(2006, 2023)

# %%
## Importing and displaying the selected play-by-play data
pbp = nfl.import_pbp_data(seasons, pbp_columns)
print()

## nfl_data_py loads other columns that don't appear to be listed via see_pbp_cols(), so setting to only the columns I want
pbp = pbp[pbp_columns]

print(pbp.shape)

pbp.head(180)
# Out:
# 2006 done.
# 2007 done.
# 2008 done.
# 2009 done.
# 2010 done.
# 2011 done.
# 2012 done.
# 2013 done.
# 2014 done.
# 2015 done.
# 2016 done.
# 2017 done.
# 2018 done.
# 2019 done.
# 2020 done.
# 2021 done.
# 2022 done.
# Downcasting floats.
#
# (820627, 36)
#     passer_player_name  season season_type  week home_team away_team posteam  \
# 0                 None    2006         REG     1       CAR       ATL    None
# 1                 None    2006         REG     1       CAR       ATL     ATL
# 2                 None    2006         REG     1       CAR       ATL     ATL
# 3                 None    2006         REG     1       CAR       ATL     ATL
# 4               M.Vick    2006         REG     1       CAR       ATL     ATL
# ..                 ...     ...         ...   ...       ...       ...     ...
# 175         J.Delhomme    2006         REG     1       CAR       ATL     CAR
# 176               None    2006         REG     1       CAR       ATL     ATL
# 177               None    2006         REG     1       CAR       ATL    None
# 178               None    2006         REG     1        TB       BAL    None
# 179               None    2006         REG     1        TB       BAL     BAL
#
#     posteam_type defteam  \
# 0           None    None
# 1           away     CAR
# 2           away     CAR
# 3           away     CAR
# 4           away     CAR
# ..           ...     ...
# 175         home     ATL
# 176         away     CAR
# 177         None    None
# 178         None    None
# 179         away      TB
#
#                                                                                                                desc  \
# 0                                                                                                              GAME
# 1    7-J.Baker kicks 75 yards from CAR 30 to ATL -5. 20-A.Rossum to ATL 33 for 38 yards (7-J.Baker, 31-R.Marshall).
# 2                               (14:54) 28-W.Dunn right tackle to ATL 38 for 5 yards (99-M.Kemoeatu, 77-K.Jenkins).
# 3                                               (14:18) 28-W.Dunn right end to ATL 37 for -1 yards (36-S.Williams).
# 4              (13:33) (Shotgun) 7-M.Vick pass short right to 83-A.Crumpler to ATL 47 for 10 yards (31-R.Marshall).
# ..                                                                                                              ...
# 175                                      (:17) (Shotgun) 17-J.Delhomme pass incomplete short right to 83-K.Colbert.
# 176                                                                   (:13) 7-M.Vick kneels to ATL 32 for -1 yards.
# 177                                                                                                        END GAME
# 178                                                                                                            GAME
# 179                3-M.Bryant kicks 68 yards from TB 30 to BAL 2. 36-B.Sams to BAL 20 for 18 yards (23-J.Phillips).
#
#     play_type  pass_attempt  incomplete_pass  complete_pass    pass_oe  \
# 0        None           NaN              NaN            NaN        NaN
# 1     kickoff           0.0              0.0            0.0        NaN
# 2         run           0.0              0.0            0.0 -44.816696
# 3         run           0.0              0.0            0.0 -43.687210
# 4        pass           1.0              0.0            1.0   3.369230
# ..        ...           ...              ...            ...        ...
# 175      pass           1.0              1.0            0.0   1.456791
# 176  qb_kneel           0.0              0.0            0.0        NaN
# 177      None           NaN              NaN            NaN        NaN
# 178      None           NaN              NaN            NaN        NaN
# 179   kickoff           0.0              0.0            0.0        NaN
#
#           cpoe  passing_yards  air_yards  yards_after_catch  pass_touchdown  \
# 0          NaN            NaN        NaN                NaN             NaN
# 1          NaN            NaN        NaN                NaN             0.0
# 2          NaN            NaN        NaN                NaN             0.0
# 3          NaN            NaN        NaN                NaN             0.0
# 4    41.941399           10.0        9.0                1.0             0.0
# ..         ...            ...        ...                ...             ...
# 175 -57.791496            NaN        8.0                NaN             0.0
# 176        NaN            NaN        NaN                NaN             0.0
# 177        NaN            NaN        NaN                NaN             NaN
# 178        NaN            NaN        NaN                NaN             NaN
# 179        NaN            NaN        NaN                NaN             0.0
#
#      interception  fumble_lost fumbled_1_team fumbled_2_team  \
# 0             NaN          NaN           None           None
# 1             0.0          0.0           None           None
# 2             0.0          0.0           None           None
# 3             0.0          0.0           None           None
# 4             0.0          0.0           None           None
# ..            ...          ...            ...            ...
# 175           0.0          0.0           None           None
# 176           0.0          0.0           None           None
# 177           NaN          NaN           None           None
# 178           NaN          NaN           None           None
# 179           0.0          0.0           None           None
#
#     fumble_recovery_1_team fumble_recovery_2_team  qb_hit  sack  touchback  \
# 0                     None                   None     NaN   NaN        0.0
# 1                     None                   None     0.0   0.0        0.0
# 2                     None                   None     0.0   0.0        0.0
# 3                     None                   None     0.0   0.0        0.0
# 4                     None                   None     0.0   0.0        0.0
# ..                     ...                    ...     ...   ...        ...
# 175                   None                   None     0.0   0.0        0.0
# 176                   None                   None     0.0   0.0        0.0
# 177                   None                   None     NaN   NaN        0.0
# 178                   None                   None     NaN   NaN        0.0
# 179                   None                   None     0.0   0.0        0.0
#
#      penalty penalty_team  penalty_yards       epa       wpa  home_score  \
# 0        NaN         None            NaN -0.000000 -0.000000           6
# 1        0.0         None            NaN  0.892853  0.017605           6
# 2        0.0         None            NaN  0.119106  0.002342           6
# 3        0.0         None            NaN -0.851534 -0.023510           6
# 4        0.0         None            NaN  1.862235  0.043966           6
# ..       ...          ...            ...       ...       ...         ...
# 175      0.0         None            NaN -1.420999 -0.000802           6
# 176      0.0         None            NaN  0.000000       NaN           6
# 177      NaN         None            NaN       NaN       NaN           6
# 178      NaN         None            NaN -0.000000 -0.000000           0
# 179      0.0         None            NaN  0.041341 -0.000000           0
#
#      away_score
# 0            20
# 1            20
# 2            20
# 3            20
# 4            20
# ..          ...
# 175          20
# 176          20
# 177          20
# 178          27
# 179          27
#
# [180 rows x 36 columns]

# %%
## Allows me to check for unexpected NA values in a DataFrame column as well as 
## helps me know what I may be dropping and why
def check_cols_for_NAs(df, cols, extra_disp_cols=[], which='passer', raise_errors=True):
    print('Columns to check for NA values: ', cols)
    print()
    
    cols_isna = df[cols].isna().any(axis=0) ## DataFrame.isnull is an alias for DataFrame.isna
                                            ## Returns a Series where the indexes are the column names of the main DataFrame
                                            ## The Series values are a Boolean indicating if the column in the main DataFrame
                                            ## contains NA values (None or NaN)
                
    cols_wNA = cols_isna[cols_isna].index   ## Uses Boolean indexing to return the Series indexes corresponding to a "True" value
    
    if len(cols_wNA) > 0:
        for colname in cols_wNA:
            
            if which == 'passer':
                display_cols = ['player_name',
                                'season', 
                                'week', 
                                'matchup', 
                                'posteam', 
                                'posteam_home',
                                'defteam'
                               ] 
                
            elif which == 'defense':
                display_cols = ['defteam',
                                'season', 
                                'week', 
                                'matchup',  
                                'defteam_home'
                               ] 
            
            display_cols += extra_disp_cols
            
            if colname in display_cols:
                display_cols.remove(colname) ## For general knowledge, removes the *first occurence* of the element
            display_cols.append(colname) ## Will display the offending column as the last column of the DataFrame subset
            
            display(df[df[colname].isna()][display_cols])
            
            print('Number of rows with NA value in column "{}": '.format(colname), end='')
            print(df[df[colname].isna()].shape[0])
            print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
        
        if raise_errors:
            raise ValueError(
                '''{} column(s) in the DataFrame have NA values (None or NaN).

                See above displayed DataFrame subsets'''
                .format(cols_wNA.values)
            )
        else:
            warnings.warn(
                '''{} column(s) in the DataFrame have NA values (None or NaN).

                See above displayed DataFrame subsets'''
                .format(cols_wNA.values)
            )
            
    else:
        print('NO NA VALUES DETECTED :)')
        print('\n\n')
        return
            
## Currently only works when columns are appended to the existing DataFrame
def reorder_columns(df, added_cols, after_which_col):
    cols = df.columns.to_list()
    insert_idx = cols.index(after_which_col) + 1
    reordered_cols = cols[:insert_idx] + added_cols + cols[insert_idx:-len(added_cols)]
    
    return reordered_cols

# %%
## Reducing the play-by-play DataFrame down to regular season (season_type=REG) data only
pbp_reg = pbp[pbp['season_type'] == 'REG'].drop(columns='season_type')
del(pbp)

## Removing play_type=None rows - having checked that in all cases (aside from MAYBE a mismarked play_type on a play that
## occured with a *declined* penalty - at worst would be ~130 rows) a play_type=None really is not a mismarked play but a
## e.g. timeout, beginning/end of game/quarter/half, listing of team captains, suspension/resumption of game, two-minute warning, etc.

# strings = '^game|^end|^two-minute warning|^timeout|captains|captians|suspended|resumed'
# pbp_reg['desc'] = pbp_reg['desc'].str.strip()
# pbp_reg = pbp_reg[~pbp_reg['desc'].str.contains(strings, case=False)]
pbp_reg = pbp_reg[~pbp_reg['play_type'].isna()]

## In an effort to avoid having NA values in "posteam," "posteam_home," and "defteam" columns before grouping
## (even though grouping can drop NA values), I am removing certain events (ex. timeouts)
## ^ denotes the pattern is checked for at the beginning of the string
pbp_reg['desc'] = pbp_reg['desc'].str.strip()
pbp_reg = pbp_reg[~pbp_reg['desc'].str.contains('^timeout', case=False)] ## Has "play_type" of "no_play"

## Adding column where the two teams playing against each other are both listed - will be used in future grouping tasks
pbp_reg['matchup'] = pbp_reg['home_team'] + '-' + pbp_reg['away_team']

## Reordering the columns
## Places "matchup" after "week" and removes "matchup" from the end
reordered_columns = reorder_columns(pbp_reg, ['matchup'], 'week')
pbp_reg = pbp_reg[reordered_columns]

## Setting the "posteam_type" values of "home" and "away" to 1 (home team = True) and 0 (home team = False), respectively.
pbp_reg.loc[pbp_reg['posteam_type'] == 'home', 'posteam_type'] = 1
pbp_reg.loc[pbp_reg['posteam_type'] == 'away', 'posteam_type'] = 0

## Renaming "passer_player_name" column to a more generic name for when I expand and generalize this code more
## Renaming "posteam_type" column to "posteam_home" to better reflect its new Boolean nature (1=home team, 0=away team)
pbp_reg.rename(columns={'passer_player_name': 'player_name', 'posteam_type': 'posteam_home'}, inplace=True)

## Columns to check initially for missing values. 
## "season," "week," "home_team," "away_team," "posteam," and "play_type" are the most important at this moment
## because the DataFrame will next be grouped by "season," "week," "matchup (defined with "home_team" and "away_team")," and "posteam"
## "play_type" is used in an aggregation function next as well. 
## It is not necessary at the moment to check "posteam_home" and "defteam." They are included sort of for completeness.

cols_to_check = ['season', 'week', 'home_team', 'away_team', 'posteam', 'posteam_home', 'defteam', 'play_type']

check_cols_for_NAs(pbp_reg, cols_to_check, 
                   extra_disp_cols=['desc', 'play_type', 'penalty', 'penalty_team', 'penalty_yards'], 
                   raise_errors=False)

pbp_reg.head()
# Out:
# Columns to check for NA values:  ['season', 'week', 'home_team', 'away_team', 'posteam', 'posteam_home', 'defteam', 'play_type']
#        player_name  season  week  matchup posteam_home defteam  \
# 509253        None    2016    12  BUF-JAX         None    None
#
#                                                   desc play_type  penalty  \
# 509253  E.Manuel in at QB. Timeout #1 by BUF at 06:55.   no_play      0.0
#
#        penalty_team  penalty_yards posteam
# 509253         None            NaN    None
# Number of rows with NA value in column "posteam": 1
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        player_name  season  week  matchup posteam defteam  \
# 509253        None    2016    12  BUF-JAX    None    None
#
#                                                   desc play_type  penalty  \
# 509253  E.Manuel in at QB. Timeout #1 by BUF at 06:55.   no_play      0.0
#
#        penalty_team  penalty_yards posteam_home
# 509253         None            NaN         None
# Number of rows with NA value in column "posteam_home": 1
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        player_name  season  week  matchup posteam posteam_home  \
# 509253        None    2016    12  BUF-JAX    None         None
#
#                                                   desc play_type  penalty  \
# 509253  E.Manuel in at QB. Timeout #1 by BUF at 06:55.   no_play      0.0
#
#        penalty_team  penalty_yards defteam
# 509253         None            NaN    None
# Number of rows with NA value in column "defteam": 1
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /tmp/ipykernel_9872/1537699982.py:55: UserWarning: ['posteam' 'posteam_home' 'defteam'] column(s) in the DataFrame have NA values (None or NaN).
#
#                 See above displayed DataFrame subsets
#   warnings.warn(
#   player_name  season  week  matchup home_team away_team posteam posteam_home  \
# 1        None    2006     1  CAR-ATL       CAR       ATL     ATL            0
# 2        None    2006     1  CAR-ATL       CAR       ATL     ATL            0
# 3        None    2006     1  CAR-ATL       CAR       ATL     ATL            0
# 4      M.Vick    2006     1  CAR-ATL       CAR       ATL     ATL            0
# 5        None    2006     1  CAR-ATL       CAR       ATL     ATL            0
#
#   defteam  \
# 1     CAR
# 2     CAR
# 3     CAR
# 4     CAR
# 5     CAR
#
#                                                                                                                                                    desc  \
# 1                                        7-J.Baker kicks 75 yards from CAR 30 to ATL -5. 20-A.Rossum to ATL 33 for 38 yards (7-J.Baker, 31-R.Marshall).
# 2                                                                   (14:54) 28-W.Dunn right tackle to ATL 38 for 5 yards (99-M.Kemoeatu, 77-K.Jenkins).
# 3                                                                                   (14:18) 28-W.Dunn right end to ATL 37 for -1 yards (36-S.Williams).
# 4                                                  (13:33) (Shotgun) 7-M.Vick pass short right to 83-A.Crumpler to ATL 47 for 10 yards (31-R.Marshall).
# 5  (12:58) 7-M.Vick pass incomplete short left to 12-M.Jenkins. PENALTY on CAR-58-T.Davis, Roughing the Passer, 15 yards, enforced at ATL 47 - No Play.
#
#   play_type  pass_attempt  incomplete_pass  complete_pass    pass_oe  \
# 1   kickoff           0.0              0.0            0.0        NaN
# 2       run           0.0              0.0            0.0 -44.816696
# 3       run           0.0              0.0            0.0 -43.687210
# 4      pass           1.0              0.0            1.0   3.369230
# 5   no_play           0.0              0.0            0.0  55.721855
#
#         cpoe  passing_yards  air_yards  yards_after_catch  pass_touchdown  \
# 1        NaN            NaN        NaN                NaN             0.0
# 2        NaN            NaN        NaN                NaN             0.0
# 3        NaN            NaN        NaN                NaN             0.0
# 4  41.941399           10.0        9.0                1.0             0.0
# 5        NaN            NaN        NaN                NaN             0.0
#
#    interception  fumble_lost fumbled_1_team fumbled_2_team  \
# 1           0.0          0.0           None           None
# 2           0.0          0.0           None           None
# 3           0.0          0.0           None           None
# 4           0.0          0.0           None           None
# 5           0.0          0.0           None           None
#
#   fumble_recovery_1_team fumble_recovery_2_team  qb_hit  sack  touchback  \
# 1                   None                   None     0.0   0.0        0.0
# 2                   None                   None     0.0   0.0        0.0
# 3                   None                   None     0.0   0.0        0.0
# 4                   None                   None     0.0   0.0        0.0
# 5                   None                   None     0.0   0.0        0.0
#
#    penalty penalty_team  penalty_yards       epa       wpa  home_score  \
# 1      0.0         None            NaN  0.892853  0.017605           6
# 2      0.0         None            NaN  0.119106  0.002342           6
# 3      0.0         None            NaN -0.851534 -0.023510           6
# 4      0.0         None            NaN  1.862235  0.043966           6
# 5      1.0          CAR           15.0  1.110637  0.067985           6
#
#    away_score
# 1          20
# 2          20
# 3          20
# 4          20
# 5          20

# %%
# print(pbp_reg['play_type'].unique())
# print('\n\n')

# for play_type in pbp_reg['play_type'].unique():
#     df = pbp_reg[pbp_reg['play_type'] == play_type]
#     print('For the play type "{}":'.format(play_type))
#     print('The unique values in column "pass_oe": ', df['pass_oe'].unique())
#     print('The unique values in column "interception": ', df['interception'].unique())
#     print('The unique values in column "fumble_lost": ', df['fumble_lost'].unique())
#     print('\n\n\n')
    
# print(len(pbp_reg[~pbp_reg['fumble_recovery_1_team'].isna()]), len(pbp_reg[~pbp_reg['fumble_recovery_2_team'].isna()]))

# display(pbp_reg[~pbp_reg['fumble_recovery_2_team'].isna()][['season', 'week', 'matchup', 'posteam', 'defteam', 'desc', 'play_type', 'fumble_lost', 'fumble_recovery_1_team', 'fumble_recovery_2_team']])

# df_kick = pbp_reg[(pbp_reg['play_type'] == 'kickoff')]
# display(df_kick[df_kick['fumble_lost'] == 1][['season', 'week', 'matchup', 'posteam', 'defteam', 'desc', 'play_type', 'fumble_lost', 'fumble_recovery_1_team', 'fumble_recovery_2_team']])

# df_punt = pbp_reg[(pbp_reg['play_type'] == 'punt')]
# display(df_punt[df_punt['fumble_lost'] == 1][['season', 'week', 'matchup', 'posteam', 'defteam', 'desc', 'play_type', 'fumble_lost', 'fumble_recovery_1_team', 'fumble_recovery_2_team']])

#display(pbp_reg.loc[[471]])

# %% [markdown]
# ### Passer and Passer's Team Data Preprocessing  and Feature Engineering

# %% [markdown]
# #### Passer's Team<br>
#
# Column names for full team (not just passer) stats have **\_team** in them.

# %%
# cols_to_disp = ['season', 'week', 'matchup', 'posteam', 'defteam', 'desc', 'play_type', 'interception', 'touchback',
#                 'fumble_lost', 'fumbled_1_team', 'fumbled_2_team', 'fumble_recovery_1_team', 'fumble_recovery_2_team']

# print(len(pbp_reg[(pbp_reg['fumble_lost'] == 1) & (pbp_reg['fumbled_1_team'].isna() == False)]), len(pbp_reg[(pbp_reg['fumble_lost'] == 1) & (pbp_reg['fumble_recovery_1_team'].isna() == False)]))
# print(len(pbp_reg[~pbp_reg['fumbled_2_team'].isna()]), len(pbp_reg[~pbp_reg['fumble_recovery_2_team'].isna()]))

# display(pbp_reg[(pbp_reg['fumble_lost'] == 1)][cols_to_disp])
# display(pbp_reg[(pbp_reg['fumble_lost'] == 1) & (pbp_reg['interception'] == 1)][cols_to_disp])
# display(pbp_reg[(pbp_reg['fumble_lost'] == 1) & (pbp_reg['fumbled_2_team'].isna() == False)][cols_to_disp])
# display(pbp_reg[(pbp_reg['fumble_lost'] == 1) & (pbp_reg['fumbled_1_team'].isna() == False) & (pbp_reg['fumble_recovery_1_team'].isna())][cols_to_disp])
# display(pbp_reg[(pbp_reg['fumble_lost'] == 1) & (pbp_reg['fumbled_2_team'].isna() == False) & (pbp_reg['fumble_recovery_2_team'].isna())][cols_to_disp])

# %%
def pass_percentage(play_type):
    num_pass_plays = len(play_type[play_type == 'pass'])
    num_run_plays  = len(play_type[play_type == 'run'])
    pass_perc = (num_pass_plays / (num_pass_plays + num_run_plays)) * 100.
    
    return pass_perc
    
def assign_lost_fumbles(group, assign_recoveries=False):
    def increase_count(fumbling_team, fumble_count):
        if fumbling_team == team1:
            return [fumble_count[0]+1, fumble_count[1]]
        else:
            return [fumble_count[0], fumble_count[1]+1]
        
    team1 = group['matchup'].iloc[0].split('-')[0]
    team2 = group['matchup'].iloc[0].split('-')[1]
    fumbles = [0, 0] ## [Team1 fumbles, Team2 fumbles]
    
    ## limit to only entries of plays with a lost fumble
    lost_fumbles = group[group['fumble_lost'] == 1]
    
    for idx in lost_fumbles.index:
        fumbled1_team  = lost_fumbles.loc[idx, 'fumbled_1_team']
        fumbled2_team  = lost_fumbles.loc[idx, 'fumbled_2_team']
        recovery1_team = lost_fumbles.loc[idx, 'fumble_recovery_1_team']
        recovery2_team = lost_fumbles.loc[idx, 'fumble_recovery_2_team']
        touchback = lost_fumbles.loc[idx, 'touchback']
        
        if fumbled1_team is None:
            raise ValueError('The team responsible for the first lost fumble of the play is missing')
        
        ## Whether the opposing team recovers the fumble or the fumble is out of the end zone (recovery1_team = None)
        if fumbled1_team != recovery1_team:
            fumbles = increase_count(fumbled1_team, fumbles)
        
        ## If a second fumble occurs on the play and is either recovered by the opposing team or 
        ## fumbled out of the end zone (recovery2_team = None and touchback = 1)
        ## recovery2_team = None and touchback = 0 could occur when the fumble is recovered by the same player or 
        ## fumbled out of bounds (not in the end zone)
        if fumbled2_team is not None:
            if ((recovery2_team is not None) and (fumbled2_team != recovery2_team)) or ((recovery2_team is None) and (touchback == 1.)):
                fumbles = increase_count(fumbled2_team, fumbles)
        
        ## If, say on a series of laterals, one team keeps fumbling and recovering their fumbles until the 3+ fumble
        ## is recovered by the opposing team (only two columns present in DataFrame for fumbling teams and recovering teams)
        if len(set([fumbled1_team, fumbled2_team, recovery1_team, recovery2_team])) == 1:
            fumbles = increase_count(fumbled1_team, fumbles)
            
    return_group = group[['season', 'week', 'matchup']].iloc[:2]
    
    if assign_recoveries:
        return_group['recovering_team'] = [team2, team1]
        return_group['fumbles_recovered'] = fumbles ## Set up as [# team1 fumbles, # team2 fumbles]
    else:
        return_group['fumbling_team'] = [team1, team2]
        return_group['fumbles_lost'] = fumbles ## Set up as [# team1 fumbles, # team2 fumbles]
    
    return return_group
        
def turnover_diff(turnovers, by_recoveries=False):
    diff = turnovers.values[1] - turnovers.values[0]
    
    if by_recoveries:
        return [-diff, diff]
    else:
        return [diff, -diff]
    
def check_for_unexpected_missing_values(group, raise_errors=True):
    ## For the below play types, I expect "pass_oe" to be NA for every entry based on initial exploration of the DataFrame
    ## For other play types ("run," "pass," and maybe "no_play"), I expect "pass_oe" to have real values
    ## I do not expect any NA values in the "interception" or "fumble_lost" columns
    print('\n\n')
    print('Evaluating the subset of plays of type "{}":'.format(group['play_type'].iloc[0]))

    if group['play_type'].iloc[0] in ['kickoff', 'field_goal', 'punt', 'extra_point', 'qb_kneel', 'qb_spike']:
        if np.any(group['pass_oe'].isna() == False):
            display(group[group['pass_oe'].isna() == False])
            
            raise ValueError('Unexpected non-NA value in column "pass_oe" for play type {}'.format(group['play_type'].iloc[0]))
        
        check_cols_for_NAs(group, 
                           ['interception', 'fumble_lost'], 
                           extra_disp_cols=['desc', 'play_type', 'penalty', 'penalty_team', 'penalty_yards'],
                           raise_errors=raise_errors
                          )
        
    else:
        check_cols_for_NAs(group, 
                           ['pass_oe', 'interception', 'fumble_lost'], 
                           extra_disp_cols=['desc', 'play_type', 'pass_oe', 'passing_yards', 'penalty', 'penalty_team', 'penalty_yards'],
                           raise_errors=raise_errors
                          )
    return group
     
## Aside from one anomolous entry, any pass or run plays with an NA "pass_oe" correspond to two-point conversion attempts
## Passing stats do not appear to be tracked for two-point conversion attempts
#pbp_reg = pbp_reg[~pbp_reg['desc'].str.contains('two-point conversion', case=False)]  

## "pass_oe" seems to be recorded even for "no_play" play types, unless there is a pre-snap penalty
## "pass_oe" seems to be positive (indicating pass play called) when a qb "scrambles."
## However, in this circumstance, the "play_type" is listed as "run."
_ = pbp_reg.groupby('play_type', sort=False, as_index=False).apply(lambda x: check_for_unexpected_missing_values(x, raise_errors=False))

## In the case of punts, the receiving team is listed as the "defteam" (opposite for kickoffs). So, if the receiving team
## loses a fumble, it is the "defteam" that is losing the fumble (fumble_lost=1), not the "posteam" as I initially grouped by and aggregating for.
## This can occur on other plays as well, such as when the "posteam" throws an interception, and the ball is fumbled by the "defteam" on a return.
## Upon further inspection, the best way to deal with attributing lost fumbles is to use the columns "fumbled_{1/2}_team" and "fumble_recovery_{1/2}_team."
## Additionally, using these columns, if multiple fumbles occur on the same play by each team, each fumble lost can be properly attributed.
## In the rare case that the ball is fumbled out of the end zone, resulting in a touchback and change of possession, the "touchback" Boolean column
## can be used knowing that the "fumble_recovery_{1/2}_team" value in this instance is "None."
## Alternatively, the "desc" column could be parsed to retrieve the details of more complicated, likely more improbable plays (not done here). 
## (ex. "recovered by {team}" seems to indicate a lack of change of possession team whereas "RECOVERED by {team}" seems to indicate change of poss.)
## In all, the method here should consider and properly assign the overwhelmingly vast majority of lost fumbles that occur
lost_fumbles_df = pbp_reg.groupby(['season', 'week', 'matchup'], sort=False, as_index=False).apply(lambda x: assign_lost_fumbles(x)).droplevel(0)

## For each team, each week, of each season, find the offense's percentage of plays (total run and pass plays) that were a pass.
## Also find the offense's "pass over expected" for the week to gauge if the team was more run-heavy (-%) or pass-heavy (+%) than expected.
## Also find the total numbers of interceptions and fumbles lost by the offense
off_scheme_int_df = pbp_reg.groupby(by=['season', 'week', 'matchup', 'posteam'], sort=False, as_index=False).agg({'play_type': pass_percentage, 
                                                                                                                  'pass_oe': np.nanmean, 
                                                                                                                  'interception': np.nansum
                                                                                                                 })

off_scheme_TOs_df = pd.merge(off_scheme_int_df, lost_fumbles_df, 
                             how='inner', 
                             left_on=['season', 'week', 'matchup', 'posteam'], 
                             right_on=['season', 'week', 'matchup', 'fumbling_team']
                            )

del(lost_fumbles_df)
del(off_scheme_int_df)

# ## Calculate total turnovers by the offense
off_scheme_TOs_df['total_turnovers'] = off_scheme_TOs_df['interception'] + off_scheme_TOs_df['fumbles_lost']

display(off_scheme_TOs_df)

if np.all(off_scheme_TOs_df['posteam'] == off_scheme_TOs_df['fumbling_team']):
    off_scheme_TOs_df.drop(columns='fumbling_team', inplace=True)  ## Drops what is effectively a duplicate column
else:
    raise ValueError('The columns "posteam" and "fumbling_team" are not identical as expected after merging')
    
off_scheme_TOs_df.set_index(['season', 'week', 'matchup', 'posteam'], inplace=True)
    
off_scheme_TOs_df['turnover_diff'] = off_scheme_TOs_df['total_turnovers'].groupby(by=['season', 'week', 'matchup'], sort=False).transform(turnover_diff)

off_scheme_TOs_df = off_scheme_TOs_df.drop(columns=['interception', 'fumbles_lost'])


off_scheme_TOs_df
# Out:
# Evaluating the subset of plays of type "kickoff":
# Columns to check for NA values:  ['interception', 'fumble_lost']
#
# NO NA VALUES DETECTED :)
#
#
#
#
#
#
# Evaluating the subset of plays of type "run":
# Columns to check for NA values:  ['pass_oe', 'interception', 'fumble_lost']
#        player_name  season  week  matchup posteam posteam_home defteam  \
# 1535          None    2006     1  WAS-MIN     MIN            0     WAS
# 2018          None    2006     1  TEN-NYJ     TEN            1     NYJ
# 8096          None    2006     3  HOU-WAS     HOU            1     WAS
# 8579          None    2006     4  TEN-DAL     TEN            1     DAL
# 16957         None    2006     7  DAL-NYG     DAL            1     NYG
# ...            ...     ...   ...      ...     ...          ...     ...
# 810231        None    2022    16  BAL-ATL     BAL            1     ATL
# 810530        None    2022    16   NE-CIN     CIN            0      NE
# 810835        None    2022    16   LA-DEN     DEN            0      LA
# 810980        None    2022    16  CAR-DET     DET            0     CAR
# 813868        None    2022    17   KC-DEN      KC            1     DEN
#
#                                                                                                                                                               desc  \
# 1535    (Kick formation) TWO-POINT CONVERSION ATTEMPT. 5-C.Kluwe rushes right end. ATTEMPT FAILS. Fumbled snap; holder attempted to rush for two point conversion.
# 2018                                                                               TWO-POINT CONVERSION ATTEMPT. 20-T.Henry rushes right tackle. ATTEMPT SUCCEEDS.
# 8096                                                                                            TWO-POINT CONVERSION ATTEMPT. 36-R.Dayne rushes. ATTEMPT SUCCEEDS.
# 8579                                                                              TWO-POINT CONVERSION ATTEMPT. 10-V.Young rushes up the middle. ATTEMPT SUCCEEDS.
# 16957                          (Pass formation) TWO-POINT CONVERSION ATTEMPT. 9-T.Romo rushes up the middle. ATTEMPT SUCCEEDS. Romo lined up in shotgun formation.
# ...                                                                                                                                                            ...
# 810231                                                                              TWO-POINT CONVERSION ATTEMPT. 2-T.Huntley rushes left guard. ATTEMPT SUCCEEDS.
# 810530                                                                                TWO-POINT CONVERSION ATTEMPT. 34-S.Perine rushes right guard. ATTEMPT FAILS.
# 810835                                                                           TWO-POINT CONVERSION ATTEMPT. 28-L.Murray rushes up the middle. ATTEMPT SUCCEEDS.
# 810980                                                                              TWO-POINT CONVERSION ATTEMPT. 42-J.Jackson rushes right tackle. ATTEMPT FAILS.
# 813868                                                                (Kick formation) TWO-POINT CONVERSION ATTEMPT. 5-T.Townsend rushes right end. ATTEMPT FAILS.
#
#        play_type  passing_yards  penalty penalty_team  penalty_yards  pass_oe
# 1535         run            NaN      0.0         None            NaN      NaN
# 2018         run            NaN      0.0         None            NaN      NaN
# 8096         run            NaN      0.0         None            NaN      NaN
# 8579         run            NaN      0.0         None            NaN      NaN
# 16957        run            NaN      0.0         None            NaN      NaN
# ...          ...            ...      ...          ...            ...      ...
# 810231       run            NaN      0.0         None            NaN      NaN
# 810530       run            NaN      0.0         None            NaN      NaN
# 810835       run            NaN      0.0         None            NaN      NaN
# 810980       run            NaN      0.0         None            NaN      NaN
# 813868       run            NaN      0.0         None            NaN      NaN
#
# [369 rows x 14 columns]
# Number of rows with NA value in column "pass_oe": 369
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
# Evaluating the subset of plays of type "pass":
# Columns to check for NA values:  ['pass_oe', 'interception', 'fumble_lost']
# /tmp/ipykernel_9872/1537699982.py:55: UserWarning: ['pass_oe'] column(s) in the DataFrame have NA values (None or NaN).
#
#                 See above displayed DataFrame subsets
#   warnings.warn(
#         player_name  season  week  matchup posteam posteam_home defteam  \
# 2033      K.Collins    2006     1  TEN-NYJ     TEN            1     NYJ
# 3085    D.Culpepper    2006     2  MIA-BUF     MIA            1     BUF
# 5944       S.McNair    2006     3  CLE-BAL     BAL            0     CLE
# 7231      E.Manning    2006     3  SEA-NYG     NYG            0     SEA
# 8811       M.Bulger    2006     4   LA-DET      LA            1     DET
# ...             ...     ...   ...      ...     ...          ...     ...
# 816748      D.Mills    2022    18  IND-HOU     HOU            0     IND
# 817084     C.Daniel    2022    18  DEN-LAC     LAC            0     DEN
# 817363      T.Boyle    2022    18  CHI-MIN     CHI            1     MIN
# 817603      M.Jones    2022    18   BUF-NE      NE            0     BUF
# 817792       D.Webb    2022    18  PHI-NYG     NYG            0     PHI
#
#                                                                                                                                                           desc  \
# 2033                                                             TWO-POINT CONVERSION ATTEMPT. 5-K.Collins pass to 83-D.Bennett is complete. ATTEMPT SUCCEEDS.
# 3085                                          (Pass formation) TWO-POINT CONVERSION ATTEMPT. 8-D.Culpepper pass to 84-C.Chambers is incomplete. ATTEMPT FAILS.
# 5944                                                                  TWO-POINT CONVERSION ATTEMPT. 9-S.McNair pass to 86-T.Heap is incomplete. ATTEMPT FAILS.
# 7231                                                              TWO-POINT CONVERSION ATTEMPT. 10-E.Manning pass to 81-A.Toomer is incomplete. ATTEMPT FAILS.
# 8811                                                               TWO-POINT CONVERSION ATTEMPT. 10-M.Bulger pass to 80-I.Bruce is complete. ATTEMPT SUCCEEDS.
# ...                                                                                                                                                        ...
# 816748                                                              TWO-POINT CONVERSION ATTEMPT. 10-D.Mills pass to 88-J.Akins is complete. ATTEMPT SUCCEEDS.
# 817084                                                              TWO-POINT CONVERSION ATTEMPT. 4-C.Daniel pass to 5-J.Palmer is complete. ATTEMPT SUCCEEDS.
# 817363  TWO-POINT CONVERSION ATTEMPT. 17-T.Boyle pass to 85-C.Kmet is incomplete. ATTEMPT FAILS. Penalty on CHI-72-A.Leatherwood, Illegal Formation, declined.
# 817603                                                           TWO-POINT CONVERSION ATTEMPT. 10-M.Jones pass to 38-R.Stevenson is incomplete. ATTEMPT FAILS.
# 817792                                                              TWO-POINT CONVERSION ATTEMPT. 12-D.Webb pass to 84-M.Johnson is incomplete. ATTEMPT FAILS.
#
#        play_type  passing_yards  penalty penalty_team  penalty_yards  pass_oe
# 2033        pass            NaN      0.0         None            NaN      NaN
# 3085        pass            NaN      0.0         None            NaN      NaN
# 5944        pass            NaN      0.0         None            NaN      NaN
# 7231        pass            NaN      0.0         None            NaN      NaN
# 8811        pass            NaN      0.0         None            NaN      NaN
# ...          ...            ...      ...          ...            ...      ...
# 816748      pass            NaN      0.0         None            NaN      NaN
# 817084      pass            NaN      0.0         None            NaN      NaN
# 817363      pass            NaN      0.0         None            NaN      NaN
# 817603      pass            NaN      0.0         None            NaN      NaN
# 817792      pass            NaN      0.0         None            NaN      NaN
#
# [1032 rows x 14 columns]
# Number of rows with NA value in column "pass_oe": 1032
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
# Evaluating the subset of plays of type "no_play":
# Columns to check for NA values:  ['pass_oe', 'interception', 'fumble_lost']
# /tmp/ipykernel_9872/1537699982.py:55: UserWarning: ['pass_oe'] column(s) in the DataFrame have NA values (None or NaN).
#
#                 See above displayed DataFrame subsets
#   warnings.warn(
#        player_name  season  week  matchup posteam posteam_home defteam  \
# 12            None    2006     1  CAR-ATL     ATL            0     CAR
# 20            None    2006     1  CAR-ATL     CAR            1     ATL
# 202           None    2006     1   TB-BAL     BAL            0      TB
# 319           None    2006     1   TB-BAL     BAL            0      TB
# 329           None    2006     1   TB-BAL     BAL            0      TB
# ...            ...     ...   ...      ...     ...          ...     ...
# 818164        None    2022    18  JAX-TEN     JAX            1     TEN
# 818193        None    2022    18  JAX-TEN     JAX            1     TEN
# 818215        None    2022    18  JAX-TEN     TEN            0     JAX
# 818241        None    2022    18  JAX-TEN     JAX            1     TEN
# 818313        None    2022    18  JAX-TEN     TEN            0     JAX
#
#                                                                                                                                                                                             desc  \
# 12      (10:26) 9-M.Koenen punts 24 yards to CAR 13, Center-47-B.Stutz, fair catch by 20-C.Gamble. PENALTY on CAR-99-M.Kemoeatu, Running Into the Kicker, 5 yards, enforced at CAR 37 - No Play.
# 20                                                                                                        (7:59) PENALTY on CAR-71-E.Mathis, False Start, 5 yards, enforced at ATL 41 - No Play.
# 202                                                                                                       (4:23) PENALTY on BAL-83-D.Wilcox, False Start, 5 yards, enforced at BAL 40 - No Play.
# 319                                                                                                      (5:32) PENALTY on BAL-7-K.Boller, Delay of Game, 5 yards, enforced at BAL 30 - No Play.
# 329                                                                (2:00) 7-K.Boller to BAL 28 for no gain. PENALTY on TB-94-G.Spires, Defensive Offside, 5 yards, enforced at BAL 28 - No Play.
# ...                                                                                                                                                                                          ...
# 818164                                                                                             (11:37) (Run formation) PENALTY on JAX, Delay of Game, 4 yards, enforced at JAX 34 - No Play.
# 818193                                                                                 (11:51) (Shotgun) PENALTY on JAX, Offensive Too Many Men on Field, 5 yards, enforced at TEN 46 - No Play.
# 818215                                                                                                   (2:31) PENALTY on TEN-85-C.Okonkwo, False Start, 5 yards, enforced at TEN 29 - No Play.
# 818241                                                                                        (11:28) (Shotgun) PENALTY on JAX-69-T.Shatley, False Start, 5 yards, enforced at TEN 43 - No Play.
# 818313                                                                                          (1:46) (Shotgun) PENALTY on TEN-81-A.Hooper, False Start, 5 yards, enforced at TEN 48 - No Play.
#
#        play_type  passing_yards  penalty penalty_team  penalty_yards  pass_oe
# 12       no_play            NaN      1.0          CAR            5.0      NaN
# 20       no_play            NaN      1.0          CAR            5.0      NaN
# 202      no_play            NaN      1.0          BAL            5.0      NaN
# 319      no_play            NaN      1.0          BAL            5.0      NaN
# 329      no_play            NaN      1.0           TB            5.0      NaN
# ...          ...            ...      ...          ...            ...      ...
# 818164   no_play            NaN      1.0          JAX            4.0      NaN
# 818193   no_play            NaN      1.0          JAX            5.0      NaN
# 818215   no_play            NaN      1.0          TEN            5.0      NaN
# 818241   no_play            NaN      1.0          JAX            5.0      NaN
# 818313   no_play            NaN      1.0          TEN            5.0      NaN
#
# [17312 rows x 14 columns]
# Number of rows with NA value in column "pass_oe": 17312
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        player_name  season  week  matchup posteam posteam_home defteam  \
# 3181          None    2006     2  MIN-CAR     CAR            0     MIN
# 3241          None    2006     2  MIN-CAR     CAR            0     MIN
# 4343          None    2006     2    GB-NO      GB            1      NO
# 6257          None    2006     3  MIN-CHI     MIN            1     CHI
# 6645          None    2006     3   NE-DEN     DEN            0      NE
# ...            ...     ...   ...      ...     ...          ...     ...
# 807711        None    2022    15  CLE-BAL     BAL            0     CLE
# 808298        None    2022    15  NYJ-DET     DET            0     NYJ
# 810013        None    2022    15  LAC-TEN     TEN            0     LAC
# 812842        None    2022    16   SF-WAS     WAS            0      SF
# 814484        None    2022    17   LAC-LA      LA            0     LAC
#
#                                                                                                                                                                                                                                                                                                                                                                       desc  \
# 3181                                                                                                                                       (14:11) 17-J.Delhomme pass incomplete deep right to 83-K.Colbert. Penalty on CAR-68-M.Wahle, Offensive Holding, offsetting, enforced at CAR 22 - No Play. Penalty on MIN-23-C.Griffin, Defensive Pass Interference, offsetting.
# 3241                                                                                                                     (5:28) 7-J.Baker punts 44 yards to MIN 3, Center-56-J.Kyle, downed by CAR-31-R.Marshall. Penalty on CAR-31-R.Marshall, Illegal Touch Kick, offsetting, enforced at MIN 47 - No Play. Penalty on MIN-27-R.Whitaker, Offensive Holding, offsetting.
# 4343                                                                                                           3-J.Carney kicks 64 yards from NO 30 to GB 6. 81-K.Robinson pushed ob at GB 42 for 36 yards (3-J.Carney). Penalty on GB-29-T.Culver, Offensive Holding, offsetting, enforced at NO 30 - No Play. Penalty on NO-56-A.Fincher, Defensive Offside, offsetting.
# 6257                                                                                                   9-R.Gould kicks 68 yards from CHI 30 to MIN 2. 22-A.Pinner to MIN 20 for 18 yards (24-R.Manning). Penalty on CHI-29-A.Peterson, Offensive Offside, offsetting, enforced at CHI 30 - No Play. Penalty on MIN-31-W.Hunter, Illegal Block Above the Waist, offsetting.
# 6645    (3:28) 3-P.Ernster punts 39 yards to NE 44, Center-83-M.Leach. 33-K.Faulk pushed ob at DEN 36 for 20 yards (42-S.Brandon, 51-K.Burns). Penalty on DEN-83-M.Leach, Defensive Holding, offsetting, enforced at DEN 17 - No Play. Penalty on NE-51-D.Davis, Illegal Block Above the Waist, offsetting. Penalty on DEN-42-S.Brandon, Face Mask (15 Yards), offsetting.
# ...                                                                                                                                                                                                                                                                                                                                                                    ...
# 807711                                                                                                                                      (8:28) (Shotgun) 2-T.Huntley pass incomplete short right to 13-D.Duvernay. Penalty on BAL-42-P.Ricard, Offensive Holding, offsetting, enforced at CLE 15 - No Play. Penalty on CLE-94-A.Wright, Defensive Offside, offsetting.
# 808298                                                                                                                                       (8:26) (Shotgun) 32-D.Swift left end to NYJ 34 for 2 yards (57-C.Mosley). Penalty on DET-77-F.Ragnow, Offensive Holding, offsetting, enforced at NYJ 36 - No Play. Penalty on NYJ-58-C.Lawson, Defensive Offside, offsetting.
# 810013                                                                                                                                                        (3:44) (Shotgun) 7-M.Willis pass incomplete deep right. Penalty on LAC-52-K.Mack, Defensive Offside, offsetting, enforced at TEN 25 - No Play. Penalty on TEN-7-M.Willis, Intentional Grounding, offsetting.
# 812842                                                                                                    (5:08) (Shotgun) 4-T.Heinicke pass deep left to 1-J.Dotson to SF 10 for 39 yards (38-D.Lenoir) [96-T.McGill]. Penalty on SF-7-C.Ward, Defensive Holding, offsetting, enforced at SF 49 - No Play. Penalty on WAS-71-W.Schweitzer, Offensive Holding, offsetting.
# 814484                                                                                                                              (6:11) (No Huddle, Shotgun) 17-B.Mayfield pass incomplete short right to 89-T.Higbee. Penalty on LA-68-T.Nsekhe, Offensive Holding, offsetting, enforced at LA 13 - No Play. Penalty on LAC-41-R.Layne, Defensive Holding, offsetting.
#
#        play_type    pass_oe  passing_yards  penalty penalty_team  \
# 3181     no_play  45.519238            NaN      NaN         None
# 3241     no_play        NaN            NaN      NaN         None
# 4343     no_play        NaN            NaN      NaN         None
# 6257     no_play        NaN            NaN      NaN         None
# 6645     no_play        NaN            NaN      NaN         None
# ...          ...        ...            ...      ...          ...
# 807711   no_play   2.614737            NaN      NaN         None
# 808298   no_play -91.005127            NaN      NaN         None
# 810013   no_play  44.201271            NaN      NaN         None
# 812842   no_play  48.517216            NaN      NaN         None
# 814484   no_play  18.300264            NaN      NaN         None
#
#         penalty_yards  interception
# 3181              NaN           NaN
# 3241              NaN           NaN
# 4343              NaN           NaN
# 6257              NaN           NaN
# 6645              NaN           NaN
# ...               ...           ...
# 807711            NaN           NaN
# 808298            NaN           NaN
# 810013            NaN           NaN
# 812842            NaN           NaN
# 814484            NaN           NaN
#
# [776 rows x 15 columns]
# Number of rows with NA value in column "interception": 776
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        player_name  season  week  matchup posteam posteam_home defteam  \
# 3181          None    2006     2  MIN-CAR     CAR            0     MIN
# 3241          None    2006     2  MIN-CAR     CAR            0     MIN
# 4343          None    2006     2    GB-NO      GB            1      NO
# 6257          None    2006     3  MIN-CHI     MIN            1     CHI
# 6645          None    2006     3   NE-DEN     DEN            0      NE
# ...            ...     ...   ...      ...     ...          ...     ...
# 807711        None    2022    15  CLE-BAL     BAL            0     CLE
# 808298        None    2022    15  NYJ-DET     DET            0     NYJ
# 810013        None    2022    15  LAC-TEN     TEN            0     LAC
# 812842        None    2022    16   SF-WAS     WAS            0      SF
# 814484        None    2022    17   LAC-LA      LA            0     LAC
#
#                                                                                                                                                                                                                                                                                                                                                                       desc  \
# 3181                                                                                                                                       (14:11) 17-J.Delhomme pass incomplete deep right to 83-K.Colbert. Penalty on CAR-68-M.Wahle, Offensive Holding, offsetting, enforced at CAR 22 - No Play. Penalty on MIN-23-C.Griffin, Defensive Pass Interference, offsetting.
# 3241                                                                                                                     (5:28) 7-J.Baker punts 44 yards to MIN 3, Center-56-J.Kyle, downed by CAR-31-R.Marshall. Penalty on CAR-31-R.Marshall, Illegal Touch Kick, offsetting, enforced at MIN 47 - No Play. Penalty on MIN-27-R.Whitaker, Offensive Holding, offsetting.
# 4343                                                                                                           3-J.Carney kicks 64 yards from NO 30 to GB 6. 81-K.Robinson pushed ob at GB 42 for 36 yards (3-J.Carney). Penalty on GB-29-T.Culver, Offensive Holding, offsetting, enforced at NO 30 - No Play. Penalty on NO-56-A.Fincher, Defensive Offside, offsetting.
# 6257                                                                                                   9-R.Gould kicks 68 yards from CHI 30 to MIN 2. 22-A.Pinner to MIN 20 for 18 yards (24-R.Manning). Penalty on CHI-29-A.Peterson, Offensive Offside, offsetting, enforced at CHI 30 - No Play. Penalty on MIN-31-W.Hunter, Illegal Block Above the Waist, offsetting.
# 6645    (3:28) 3-P.Ernster punts 39 yards to NE 44, Center-83-M.Leach. 33-K.Faulk pushed ob at DEN 36 for 20 yards (42-S.Brandon, 51-K.Burns). Penalty on DEN-83-M.Leach, Defensive Holding, offsetting, enforced at DEN 17 - No Play. Penalty on NE-51-D.Davis, Illegal Block Above the Waist, offsetting. Penalty on DEN-42-S.Brandon, Face Mask (15 Yards), offsetting.
# ...                                                                                                                                                                                                                                                                                                                                                                    ...
# 807711                                                                                                                                      (8:28) (Shotgun) 2-T.Huntley pass incomplete short right to 13-D.Duvernay. Penalty on BAL-42-P.Ricard, Offensive Holding, offsetting, enforced at CLE 15 - No Play. Penalty on CLE-94-A.Wright, Defensive Offside, offsetting.
# 808298                                                                                                                                       (8:26) (Shotgun) 32-D.Swift left end to NYJ 34 for 2 yards (57-C.Mosley). Penalty on DET-77-F.Ragnow, Offensive Holding, offsetting, enforced at NYJ 36 - No Play. Penalty on NYJ-58-C.Lawson, Defensive Offside, offsetting.
# 810013                                                                                                                                                        (3:44) (Shotgun) 7-M.Willis pass incomplete deep right. Penalty on LAC-52-K.Mack, Defensive Offside, offsetting, enforced at TEN 25 - No Play. Penalty on TEN-7-M.Willis, Intentional Grounding, offsetting.
# 812842                                                                                                    (5:08) (Shotgun) 4-T.Heinicke pass deep left to 1-J.Dotson to SF 10 for 39 yards (38-D.Lenoir) [96-T.McGill]. Penalty on SF-7-C.Ward, Defensive Holding, offsetting, enforced at SF 49 - No Play. Penalty on WAS-71-W.Schweitzer, Offensive Holding, offsetting.
# 814484                                                                                                                              (6:11) (No Huddle, Shotgun) 17-B.Mayfield pass incomplete short right to 89-T.Higbee. Penalty on LA-68-T.Nsekhe, Offensive Holding, offsetting, enforced at LA 13 - No Play. Penalty on LAC-41-R.Layne, Defensive Holding, offsetting.
#
#        play_type    pass_oe  passing_yards  penalty penalty_team  \
# 3181     no_play  45.519238            NaN      NaN         None
# 3241     no_play        NaN            NaN      NaN         None
# 4343     no_play        NaN            NaN      NaN         None
# 6257     no_play        NaN            NaN      NaN         None
# 6645     no_play        NaN            NaN      NaN         None
# ...          ...        ...            ...      ...          ...
# 807711   no_play   2.614737            NaN      NaN         None
# 808298   no_play -91.005127            NaN      NaN         None
# 810013   no_play  44.201271            NaN      NaN         None
# 812842   no_play  48.517216            NaN      NaN         None
# 814484   no_play  18.300264            NaN      NaN         None
#
#         penalty_yards  fumble_lost
# 3181              NaN          NaN
# 3241              NaN          NaN
# 4343              NaN          NaN
# 6257              NaN          NaN
# 6645              NaN          NaN
# ...               ...          ...
# 807711            NaN          NaN
# 808298            NaN          NaN
# 810013            NaN          NaN
# 812842            NaN          NaN
# 814484            NaN          NaN
#
# [776 rows x 15 columns]
# Number of rows with NA value in column "fumble_lost": 776
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
# Evaluating the subset of plays of type "field_goal":
# Columns to check for NA values:  ['interception', 'fumble_lost']
#
# NO NA VALUES DETECTED :)
#
#
#
#
#
#
# Evaluating the subset of plays of type "punt":
# Columns to check for NA values:  ['interception', 'fumble_lost']
#
# NO NA VALUES DETECTED :)
#
#
#
#
#
#
# Evaluating the subset of plays of type "extra_point":
# Columns to check for NA values:  ['interception', 'fumble_lost']
#
# NO NA VALUES DETECTED :)
#
#
#
#
#
#
# Evaluating the subset of plays of type "qb_kneel":
# Columns to check for NA values:  ['interception', 'fumble_lost']
#
# NO NA VALUES DETECTED :)
#
#
#
#
#
#
# Evaluating the subset of plays of type "qb_spike":
# Columns to check for NA values:  ['interception', 'fumble_lost']
#
# NO NA VALUES DETECTED :)
# /tmp/ipykernel_9872/1537699982.py:55: UserWarning: ['pass_oe' 'interception' 'fumble_lost'] column(s) in the DataFrame have NA values (None or NaN).
#
#                 See above displayed DataFrame subsets
#   warnings.warn(
#       season  week  matchup posteam  play_type    pass_oe  interception  \
# 0       2006     1  CAR-ATL     ATL  33.333333 -13.694357           0.0
# 1       2006     1  CAR-ATL     CAR  72.881356  -0.803797           1.0
# 2       2006     1   TB-BAL     BAL  46.551724  -2.519106           0.0
# 3       2006     1   TB-BAL      TB  74.000000   3.605388           3.0
# 4       2006     1   NE-BUF      NE  40.625000 -15.551071           1.0
# ...      ...   ...      ...     ...        ...        ...           ...
# 8761    2022    18  MIA-NYJ     NYJ  62.264151  -7.393189           0.0
# 8762    2022    18   ATL-TB      TB  62.962963  -3.075565           0.0
# 8763    2022    18   ATL-TB     ATL  47.761194  -6.894469           0.0
# 8764    2022    18  JAX-TEN     TEN  45.833333 -17.373583           1.0
# 8765    2022    18  JAX-TEN     JAX  73.333333   9.846007           0.0
#
#      fumbling_team  fumbles_lost  total_turnovers
# 0              ATL             0              0.0
# 1              CAR             1              2.0
# 2              BAL             0              0.0
# 3               TB             0              3.0
# 4               NE             1              2.0
# ...            ...           ...              ...
# 8761           NYJ             0              0.0
# 8762            TB             1              1.0
# 8763           ATL             1              1.0
# 8764           TEN             1              2.0
# 8765           JAX             1              1.0
#
# [8766 rows x 10 columns]
#                              play_type    pass_oe  total_turnovers  \
# season week matchup posteam
# 2006   1    CAR-ATL ATL      33.333333 -13.694357              0.0
#                     CAR      72.881356  -0.803797              2.0
#             TB-BAL  BAL      46.551724  -2.519106              0.0
#                     TB       74.000000   3.605388              3.0
#             NE-BUF  NE       40.625000 -15.551071              2.0
# ...                                ...        ...              ...
# 2022   18   MIA-NYJ NYJ      62.264151  -7.393189              0.0
#             ATL-TB  TB       62.962963  -3.075565              1.0
#                     ATL      47.761194  -6.894469              1.0
#             JAX-TEN TEN      45.833333 -17.373583              2.0
#                     JAX      73.333333   9.846007              1.0
#
#                              turnover_diff
# season week matchup posteam
# 2006   1    CAR-ATL ATL                2.0
#                     CAR               -2.0
#             TB-BAL  BAL                3.0
#                     TB                -3.0
#             NE-BUF  NE                -2.0
# ...                                    ...
# 2022   18   MIA-NYJ NYJ               -0.0
#             ATL-TB  TB                 0.0
#                     ATL               -0.0
#             JAX-TEN TEN               -1.0
#                     JAX                1.0
#
# [8766 rows x 4 columns]

# %%
## Declined penalties are not recorded outside of the "desc" column
## Offsetting penalties are not recorded outside of the "desc" column

def clean_penalty_df(matchup_group):
    matchup_group = matchup_group.reset_index(level='penalty_team')
    listed_teams  = matchup_group['penalty_team'].to_list()
    
    if len(listed_teams) == 3:  ## Case where both teams committed penalties but a third NaN team was listed due to plays without penalties
        matchup_group = matchup_group.dropna()
        
    elif len(listed_teams) == 2:  ## Case where only one of the teams committed penalties, and a second NaN team was listed for the plays without penalties
        teams_in_matchup = (matchup_group
                            .index
                            .get_level_values('matchup')
                            .to_list()[0]
                            .split('-')
                           )
        unlisted_team = [team for team in teams_in_matchup if team not in listed_teams][0]
        matchup_group['penalty_team'] = matchup_group['penalty_team'].fillna(unlisted_team)
        
    else:  ## Will need to be updated at a later time to handle at least the case of neither team being penalized during the game
        print(matchup_group.index)
        print('Number of listed teams: {}'.format(len(listed_teams)))
        print('Listed teams: ', listed_teams)
        raise ValueError('Neither team had a penalty called on them during this game or there is an error in the "penalty_team" column.')
    
    matchup_group = matchup_group.set_index('penalty_team', append=True)
    
    return matchup_group
    


## For each team, each week, of each season, find the team's total number of penalties and penalty yards
penalties_df = pbp_reg.groupby(by=['season', 'week', 'matchup', 'penalty_team'], sort=False, dropna=False).agg({'penalty': np.nansum, 'penalty_yards': np.nansum})

penalties_df = penalties_df.groupby(level=['season', 'week', 'matchup'], sort=False, as_index=False).apply(lambda x: clean_penalty_df(x)).droplevel(0)

penalties_df
# Out:
#                                   penalty  penalty_yards
# season week matchup penalty_team
# 2006   1    CAR-ATL CAR               8.0           45.0
#                     ATL               2.0           20.0
#             TB-BAL  BAL               4.0           25.0
#                     TB                3.0           21.0
#             NE-BUF  NE                1.0            5.0
# ...                                   ...            ...
# 2022   18   MIA-NYJ NYJ               6.0           54.0
#             ATL-TB  TB                3.0           30.0
#                     ATL               2.0           18.0
#             JAX-TEN TEN               6.0           40.0
#                     JAX               4.0           25.0
#
# [8766 rows x 2 columns]

# %%
## Merge the two preceding DataFrames
compiled_team_stats_df = pd.merge(off_scheme_TOs_df.reset_index(), penalties_df.reset_index(), 
                                  how='inner', ## Intersection or inner join of keys - Preserves the order of the left keys
                                  left_on=['season', 'week', 'matchup', 'posteam'], 
                                  right_on=['season', 'week', 'matchup', 'penalty_team'])

compiled_team_stats_df = compiled_team_stats_df.rename(columns={'play_type': 'perc_pass_plays_team', 
                                                                'pass_oe': 'pass_oe_team',
                                                                'total_turnovers': 'total_giveaways_team',
                                                                'turnover_diff': 'turnover_diff_team',
                                                                'penalty': 'total_penalties_team',
                                                                'penalty_yards': 'penalty_yards_team'
                                                               }
                                                      )

if np.all(compiled_team_stats_df['posteam'] == compiled_team_stats_df['penalty_team']):
    compiled_team_stats_df.drop(columns='penalty_team', inplace=True)  ## Drops what is effectively a duplicate column
else:
    raise ValueError('The columns "posteam" and "penalty_team" are not identical as expected after merging')


del(off_scheme_TOs_df)
del(penalties_df)
compiled_team_stats_df
# Out:
#       season  week  matchup posteam  perc_pass_plays_team  pass_oe_team  \
# 0       2006     1  CAR-ATL     ATL             33.333333    -13.694357
# 1       2006     1  CAR-ATL     CAR             72.881356     -0.803797
# 2       2006     1   TB-BAL     BAL             46.551724     -2.519106
# 3       2006     1   TB-BAL      TB             74.000000      3.605388
# 4       2006     1   NE-BUF      NE             40.625000    -15.551071
# ...      ...   ...      ...     ...                   ...           ...
# 8761    2022    18  MIA-NYJ     NYJ             62.264151     -7.393189
# 8762    2022    18   ATL-TB      TB             62.962963     -3.075565
# 8763    2022    18   ATL-TB     ATL             47.761194     -6.894469
# 8764    2022    18  JAX-TEN     TEN             45.833333    -17.373583
# 8765    2022    18  JAX-TEN     JAX             73.333333      9.846007
#
#       total_giveaways_team  turnover_diff_team  total_penalties_team  \
# 0                      0.0                 2.0                   2.0
# 1                      2.0                -2.0                   8.0
# 2                      0.0                 3.0                   4.0
# 3                      3.0                -3.0                   3.0
# 4                      2.0                -2.0                   1.0
# ...                    ...                 ...                   ...
# 8761                   0.0                -0.0                   6.0
# 8762                   1.0                 0.0                   3.0
# 8763                   1.0                -0.0                   2.0
# 8764                   2.0                -1.0                   6.0
# 8765                   1.0                 1.0                   4.0
#
#       penalty_yards_team
# 0                   20.0
# 1                   45.0
# 2                   25.0
# 3                   21.0
# 4                    5.0
# ...                  ...
# 8761                54.0
# 8762                30.0
# 8763                18.0
# 8764                40.0
# 8765                25.0
#
# [8766 rows x 10 columns]

# %% [markdown]
# #### Passer

# %%
## Creating another DataFrame which focuses on the "pass" play_type and the individual passer
passing_df = pbp_reg[pbp_reg['play_type'] == 'pass']
del(pbp_reg)

## Checking for missing values in "home_score" and "away_score" columns
check_cols_for_NAs(passing_df, ['home_score', 'away_score'], extra_disp_cols=['desc'])

## Creating more appropriate game score columns
## The original play-by-play DataFrame for the passer (pbp_reg) gives the home flag for the passer under the "posteam_home" column
## The original play-by-play DataFrame for the defense (dpbp_reg) gives the home flag for the defense under the "defteam_home" column
## These are exact opposites, hence the need for the "home_flag_which" keyword
def create_score_col(df, home_flag_which, posteam_score=True):
    home_flag  = df[home_flag_which+'_home'].to_numpy()
    home_score = df['home_score'].to_numpy()
    away_score = df['away_score'].to_numpy()
    
    tups = zip(home_flag, zip(home_score, away_score))

    if home_flag_which == 'posteam':
        if posteam_score:
            col = [tup[1][0] if tup[0] == 1 else tup[1][1] for tup in tups]
        else:
            col = [tup[1][1] if tup[0] == 1 else tup[1][0] for tup in tups]
            
    elif home_flag_which == 'defteam':
        if posteam_score:
            col = [tup[1][0] if tup[0] == 0 else tup[1][1] for tup in tups]
        else:
            col = [tup[1][1] if tup[0] == 0 else tup[1][0] for tup in tups]

    return col

passing_df['posteam_score'] = create_score_col(passing_df, 'posteam')
passing_df['defteam_score'] = create_score_col(passing_df, 'posteam', posteam_score=False)
passing_df['score_diff']    = passing_df['posteam_score'] - passing_df['defteam_score']
## "Score_diff" is positive if the possession team scores more than the defending team

reordered_columns = reorder_columns(passing_df, ['posteam_score', 'defteam_score', 'score_diff'], 'away_score')
passing_df = passing_df[reordered_columns]

# passing_df = passing_df.rename(columns={'game_seconds_remaining': 'game_min_rem_fp'})  ## fp = first pass
# passing_df['game_min_rem_fp'] /= 60.
# passing_df['game_min_rem_lp'] = passing_df['game_min_rem_fp']  ## lp = last pass
## Both game_min_remaining columns to be aggregrated in next code block to reflect the time left at the first pass and last pass, respectively

# passing_df = passing_df[passing_df.columns[:10].to_list() + 
#                         [passing_df.columns[-1]] + 
#                         passing_df.columns[10:-1].to_list()]
print(passing_df.shape)
passing_df.head()
# Out:
# Columns to check for NA values:  ['home_score', 'away_score']
#
# NO NA VALUES DETECTED :)
#
#
#
# (319773, 39)
#    player_name  season  week  matchup home_team away_team posteam  \
# 4       M.Vick    2006     1  CAR-ATL       CAR       ATL     ATL
# 6       M.Vick    2006     1  CAR-ATL       CAR       ATL     ATL
# 8       M.Vick    2006     1  CAR-ATL       CAR       ATL     ATL
# 11      M.Vick    2006     1  CAR-ATL       CAR       ATL     ATL
# 15  J.Delhomme    2006     1  CAR-ATL       CAR       ATL     CAR
#
#    posteam_home defteam  \
# 4             0     CAR
# 6             0     CAR
# 8             0     CAR
# 11            0     CAR
# 15            1     ATL
#
#                                                                                                     desc  \
# 4   (13:33) (Shotgun) 7-M.Vick pass short right to 83-A.Crumpler to ATL 47 for 10 yards (31-R.Marshall).
# 6           (12:51) (Shotgun) 7-M.Vick pass short left to 87-A.Lelie to CAR 33 for 5 yards (21-K.Lucas).
# 8                          (11:53) 7-M.Vick pass incomplete short middle to 83-A.Crumpler (55-D.Morgan).
# 11                                (11:01) (Shotgun) 7-M.Vick sacked at CAR 37 for -7 yards (92-D.Lewis).
# 15                    (9:42) 17-J.Delhomme pass short left to 19-K.Johnson ran ob at ATL 49 for 8 yards.
#
#    play_type  pass_attempt  incomplete_pass  complete_pass    pass_oe  \
# 4       pass           1.0              0.0            1.0   3.369230
# 6       pass           1.0              0.0            1.0  57.607498
# 8       pass           1.0              1.0            0.0  60.318436
# 11      pass           1.0              0.0            0.0   9.443247
# 15      pass           1.0              0.0            1.0  37.402725
#
#          cpoe  passing_yards  air_yards  yards_after_catch  pass_touchdown  \
# 4   41.941399           10.0        9.0                1.0             0.0
# 6   28.154320            5.0        5.0                0.0             0.0
# 8  -75.039024            NaN        6.0                NaN             0.0
# 11        NaN            NaN        NaN                NaN             0.0
# 15  29.104429            8.0        6.0                2.0             0.0
#
#     interception  fumble_lost fumbled_1_team fumbled_2_team  \
# 4            0.0          0.0           None           None
# 6            0.0          0.0           None           None
# 8            0.0          0.0           None           None
# 11           0.0          0.0           None           None
# 15           0.0          0.0           None           None
#
#    fumble_recovery_1_team fumble_recovery_2_team  qb_hit  sack  touchback  \
# 4                    None                   None     0.0   0.0        0.0
# 6                    None                   None     0.0   0.0        0.0
# 8                    None                   None     0.0   0.0        0.0
# 11                   None                   None     1.0   1.0        0.0
# 15                   None                   None     0.0   0.0        0.0
#
#     penalty penalty_team  penalty_yards       epa       wpa  home_score  \
# 4       0.0         None            NaN  1.862235  0.043966           6
# 6       0.0         None            NaN  0.184564 -0.012592           6
# 8       0.0         None            NaN -0.380531 -0.015467           6
# 11      0.0         None            NaN -2.290171 -0.043999           6
# 15      0.0         None            NaN  0.831313  0.014238           6
#
#     away_score  posteam_score  defteam_score  score_diff
# 4           20             20              6          14
# 6           20             20              6          14
# 8           20             20              6          14
# 11          20             20              6          14
# 15          20              6             20         -14

# %%
## Removing unnecessary columns and columns I have previously aggregated (more may be removed later)
## Pass_attempt column shows a Boolean 1.0, even for a sack. I can more accurately retrieve the pass attempts from the incomplete_pass and complete_pass columns
cols_to_drop = ['home_team', 'away_team', 'play_type', 'pass_attempt', 'pass_oe', 'fumble_lost', 'fumbled_1_team', 'fumbled_2_team', 
                'fumble_recovery_1_team', 'fumble_recovery_2_team', 'touchback', 'penalty', 'penalty_team', 'penalty_yards', 
                'home_score', 'away_score', 'defteam_score']

passing_df = passing_df.drop(columns=cols_to_drop)
passing_df = passing_df.rename(columns={'epa': 'pass_epa', ## This column is only considered for pass plays
                                        'wpa': 'pass_wpa', ## This column is only considered for pass plays
                                        'pass_touchdown': 'pass_touchdowns', ## These stats are aggregated (sums) so their column name is made plural
                                        'interception': 'interceptions',
                                        'qb_hit': 'qb_hits',
                                        'sack': 'sacks'
                                       }
                              ) 

## Filling NA values in "passing_yards," "air_yards," and "yards_after_catch" to make searching for actual missing values easier.
mask1 = passing_df['desc'].str.contains('incomplete|sacked|intercepted|two-point conversion', case=False) 
mask2 = passing_df['desc'].str.contains('sacked|two-point conversion', case=False) ## Air yards are still counted on incomplete/int passes

passing_df.loc[mask1, 'passing_yards'] = passing_df.loc[mask1, 'passing_yards'].fillna(0)
passing_df.loc[mask1, 'yards_after_catch'] = passing_df.loc[mask1, 'yards_after_catch'].fillna(0)
passing_df.loc[mask2, 'air_yards'] = passing_df.loc[mask2, 'air_yards'].fillna(0)

## Calculating missing, but calculable YAC and air yards (I have at least seen missing but calculable YAC)
## Passing yards have not been found to be missing at all, but can be calculated with air yards and YAC if this arises
missing_yac = passing_df[passing_df['yards_after_catch'].isna()]
missing_ay  = passing_df[passing_df['air_yards'].isna()]

## Outside of a couple of illegal forward passes, all plays seem to involve a fumble by the receiver that is recovered by the receiver. 
## Any yardage gained or lost between the fumble and recovery is reflected in the passing yards given.
## Ex. A play for 2 yards, fumbled and recovered 4 yards behind the 2 yard gain of the play results in -2 passing yards
## As such, and especially for plays where there is no yardage gained or lost between the fumble and recovery, 
## YAC should be calculable and affected by fumbles in the same way as the passing yards I would think.
## Ex. If that play had 2 air yards, the reciever would have -4 YAC to give the total listed -2 passing yards.
## Plays with an illegal forward pass should also have their YAC counted as the penalty is enforced where it occurs, after YAC has been gained
for entry in missing_yac.index:
    passing_yards = missing_yac.loc[entry, 'passing_yards']
    air_yards = missing_yac.loc[entry, 'air_yards']
    if (np.isnan(passing_yards) == False) and (np.isnan(air_yards) == False):
#         print('YAC before: ')
#         print('Play description: ', passing_df.loc[entry, 'desc'])
#         display(passing_df.loc[entry, ['player_name', 'posteam', 'season', 'week', 'passing_yards', 'air_yards', 'yards_after_catch', 'fumble_lost']])
        passing_df.loc[entry, 'yards_after_catch'] = passing_yards - air_yards
#         print('YAC after: ')
#         display(passing_df.loc[entry, ['player_name', 'posteam', 'season', 'week', 'passing_yards', 'air_yards', 'yards_after_catch', 'fumble_lost']])

## When passing yards and YAC are both 0, there is not enough information to determine the air yards.
## Entries involve incomplete passes, which could, at least sometimes, be throw aways as well as intentional grounding.
## I am not sure why incomplete passes to the middle of the field would have air yards listed as NaN. 
## Maybe tipped balls or no receiver in the area?  Or thrown out of the back of the end zone?
for entry in missing_ay.index:
    passing_yards = missing_ay.loc[entry, 'passing_yards']
    yac = missing_ay.loc[entry, 'yards_after_catch']
    if (np.isnan(passing_yards) == False) and (np.isnan(yac) == False) and ((passing_yards != 0) or (yac != 0)):
        passing_df.loc[entry, 'air_yards'] = passing_yards - yac

#passing_df = passing_df[~passing_df['desc'].str.contains('sacked|two-point conversion|thrown away|intentional grounding', case=False)]

## Check remaining unchecked columns to be aggrated for NA values
cols_to_check = [colname for colname in passing_df.columns if colname not in 
                 ['season', 'week', 'matchup', 'posteam', 'posteam_home', 'defteam', 'desc']]

## All NA values in the column "passing yards" correspond to two-point conversions (failures are sometimes listed as 0 for pass yards and YAC)
## A majority of missing "cpoe" values correspond to sacks, where I wouldn't expect a CPOE
## If two-point conversions and sacks are left out, there are 6790 entries with CPOE = NaN (2006-2022) or ~2.1% of the DataFrame
## If "ball thrown away" and "intentional grounding" plays are left out, there are 5880 CPOE = NaN entries (~1.8%)
## Missing air yards and YAC amount to ~175 missing entries or less
check_cols_for_NAs(passing_df, cols_to_check, 
                   extra_disp_cols=['desc', 'incomplete_pass', 'complete_pass', 'cpoe', 'interceptions', 'passing_yards', 'yards_after_catch', 'air_yards'], 
                   raise_errors=False)

## Aggregating the columns in the DataFrame by passer, season, and week
passer_df = passing_df.groupby(by=['player_name', 'season', 'week'], sort=False).agg(
    {'matchup': 'last',
     'posteam': 'last',
     'posteam_home': 'last', 
     'defteam': 'last',
     #'game_min_rem_fp': max,
     #'game_min_rem_lp': min,
     'incomplete_pass': np.nansum,
     'complete_pass': np.nansum, 
     'cpoe': np.nanmean,
     'passing_yards': np.nansum,
     'air_yards': np.nansum,
     'yards_after_catch': np.nansum,
     'pass_touchdowns': np.nansum,
     'interceptions': np.nansum,
     'qb_hits': np.nansum,
     'sacks': np.nansum,
     'pass_epa': np.nansum,
     'pass_wpa': np.nansum,
     'posteam_score': 'last',
     'score_diff': 'last'
    }
)

del(passing_df)

## Some more feature engineering
passer_df['pass_attempts']   = passer_df['incomplete_pass'] + passer_df['complete_pass']
passer_df['completion_perc'] = passer_df['complete_pass'] / passer_df['pass_attempts'] * 100.

## Remove anyone with 5 or fewer pass attempts (likely players involved in trick plays)
passer_df = passer_df[passer_df['pass_attempts'] > 5]

passer_df = passer_df.drop(columns=['incomplete_pass', 'complete_pass'])

reordered_columns = reorder_columns(passer_df, ['pass_attempts', 'completion_perc'], 'defteam')
passer_df = passer_df[reordered_columns]

passer_df.reset_index(inplace=True)

cols_to_check = [colname for colname in passer_df.columns if colname not in 
                 ['player_name', 'season', 'week', 'matchup', 'posteam', 'posteam_home', 'defteam']]

## There are 12 entries (grouped by player name, season, week) with missing CPOE averages.  All are from 2006 and have KC in the matchup.
## These entries are removed.
check_cols_for_NAs(passer_df, cols_to_check, 
                   extra_disp_cols=['pass_attempts', 'completion_perc', 'cpoe', 'passing_yards', 'air_yards',
                                    'yards_after_catch', 'pass_touchdowns', 'interceptions', 'qb_hits', 'sacks', 
                                    'pass_epa', 'pass_wpa', 'posteam_score', 'score_diff'
                                   ],
                   raise_errors=False
                  )

print()
print()
print('Removing the 12 entries from 2006 with NaN CPOE mean values and re-testing the DataFrame for NA values:')
print()
print()

passer_df = passer_df[~passer_df['cpoe'].isna()]

check_cols_for_NAs(passer_df, cols_to_check, 
                  extra_disp_cols=['pass_attempts', 'completion_perc', 'cpoe', 'passing_yards', 'air_yards',
                                   'yards_after_catch', 'pass_touchdowns', 'interceptions', 'qb_hits', 'sacks', 
                                   'pass_epa', 'pass_wpa', 'posteam_score', 'score_diff'
                                  ]
                 )


print(passer_df.shape)
passer_df.head(10)
# Out:
# Columns to check for NA values:  ['player_name', 'incomplete_pass', 'complete_pass', 'cpoe', 'passing_yards', 'air_yards', 'yards_after_catch', 'pass_touchdowns', 'interceptions', 'qb_hits', 'sacks', 'pass_epa', 'pass_wpa', 'posteam_score', 'score_diff']
#        player_name  season  week  matchup posteam posteam_home defteam  \
# 11          M.Vick    2006     1  CAR-ATL     ATL            0     CAR
# 66      J.Delhomme    2006     1  CAR-ATL     CAR            1     ATL
# 85      J.Delhomme    2006     1  CAR-ATL     CAR            1     ATL
# 113     J.Delhomme    2006     1  CAR-ATL     CAR            1     ATL
# 114     J.Delhomme    2006     1  CAR-ATL     CAR            1     ATL
# ...            ...     ...   ...      ...     ...          ...     ...
# 818283  T.Lawrence    2022    18  JAX-TEN     JAX            1     TEN
# 818288     J.Dobbs    2022    18  JAX-TEN     TEN            0     JAX
# 818291  T.Lawrence    2022    18  JAX-TEN     JAX            1     TEN
# 818303     J.Dobbs    2022    18  JAX-TEN     TEN            0     JAX
# 818311     J.Dobbs    2022    18  JAX-TEN     TEN            0     JAX
#
#                                                                                                                                                                                                         desc  \
# 11                                                                                                                                    (11:01) (Shotgun) 7-M.Vick sacked at CAR 37 for -7 yards (92-D.Lewis).
# 66                                                    (3:55) 17-J.Delhomme pass incomplete short right to 83-K.Colbert (25-C.Crocker). CAR-70-T.Wharton was injured during the play. His return is Doubtful.
# 85                          (:03) 17-J.Delhomme sacked at CAR 44 for -12 yards (55-J.Abraham). FUMBLES (55-J.Abraham), RECOVERED by ATL-92-C.Davis at CAR 44. 92-C.Davis to CAR 44 for no gain (68-M.Wahle).
# 113                                                                        (5:27) 17-J.Delhomme sacked at CAR 21 for -8 yards (55-J.Abraham). FUMBLES (55-J.Abraham), recovered by CAR-69-J.Gross at CAR 21.
# 114                                                                                                                                       (4:48) 17-J.Delhomme sacked at CAR 14 for -7 yards (75-R.Coleman).
# ...                                                                                                                                                                                                      ...
# 818283                                                                                                                                         (12:28) (Shotgun) 16-T.Lawrence pass incomplete short middle.
# 818288                                                                                                                                                       (10:50) 11-J.Dobbs pass incomplete short right.
# 818291                                                                                                                                       (9:45) 16-T.Lawrence sacked at JAX 25 for -9 yards (93-T.Tart).
# 818303              (3:01) (Shotgun) 11-J.Dobbs sacked at TEN 27 for -8 yards (2-R.Jenkins). FUMBLES (2-R.Jenkins) [2-R.Jenkins], RECOVERED by JAX-41-J.Allen at TEN 37. 41-J.Allen for 37 yards, TOUCHDOWN.
# 818311  (1:55) (Shotgun) 11-J.Dobbs to TEN 45 for -8 yards (41-J.Allen). FUMBLES (41-J.Allen), and recovers at TEN 47. 11-J.Dobbs sacked at TEN 48 for -5 yards (sack split by 96-A.Gotsis and 98-C.Peters).
#
#         incomplete_pass  complete_pass  interceptions  passing_yards  \
# 11                  0.0            0.0            0.0            0.0
# 66                  1.0            0.0            0.0            0.0
# 85                  0.0            0.0            0.0            0.0
# 113                 0.0            0.0            0.0            0.0
# 114                 0.0            0.0            0.0            0.0
# ...                 ...            ...            ...            ...
# 818283              1.0            0.0            0.0            0.0
# 818288              1.0            0.0            0.0            0.0
# 818291              0.0            0.0            0.0            0.0
# 818303              0.0            0.0            0.0            0.0
# 818311              0.0            0.0            0.0            0.0
#
#         yards_after_catch  air_yards  cpoe
# 11                    0.0        0.0   NaN
# 66                    0.0      -30.0   NaN
# 85                    0.0        0.0   NaN
# 113                   0.0        0.0   NaN
# 114                   0.0        0.0   NaN
# ...                   ...        ...   ...
# 818283                0.0       -1.0   NaN
# 818288                0.0       11.0   NaN
# 818291                0.0        0.0   NaN
# 818303                0.0        0.0   NaN
# 818311                0.0        0.0   NaN
#
# [27992 rows x 15 columns]
# Number of rows with NA value in column "cpoe": 27992
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#         player_name  season  week  matchup posteam posteam_home defteam  \
# 2506        J.Kitna    2006     1  DET-SEA     DET            1     SEA
# 2523        J.Kitna    2006     1  DET-SEA     DET            1     SEA
# 4588      E.Manning    2006     2  PHI-NYG     NYG            0     PHI
# 8835       D.McNabb    2006     4   PHI-GB     PHI            1      GB
# 8901       D.McNabb    2006     4   PHI-GB     PHI            1      GB
# ...             ...     ...   ...      ...     ...          ...     ...
# 741230    T.Siemian    2021     8    NO-TB      NO            1      TB
# 749340   T.Lawrence    2021    12  JAX-ATL     JAX            1     ATL
# 775622      G.Smith    2022     2   SF-SEA     SEA            0      SF
# 780811    K.Cousins    2022     4   NO-MIN     MIN            0      NO
# 788480  J.Garoppolo    2022     7    SF-KC      SF            1      KC
#
#                                                                                                                                                  desc  \
# 2506                                                                                        (14:28) 8-J.Kitna pass incomplete left. Ball thrown away.
# 2523                           (8:15) 8-J.Kitna pass incomplete right. PENALTY on DET-8-J.Kitna, Intentional Grounding, 11 yards, enforced at SEA 19.
# 4588                                                                 (3:18) (Shotgun) 10-E.Manning pass left to 17-P.Burress for 31 yards, TOUCHDOWN.
# 8835                                                             (13:02) (Shotgun) 5-D.McNabb pass incomplete left to 18-D.Stallworth (36-N.Collins).
# 8901                                                                         (4:38) 5-D.McNabb pass incomplete middle to 84-H.Baskett (21-C.Woodson).
# ...                                                                                                                                               ...
# 741230                         (:34) (Shotgun) 15-T.Siemian to NO 24 for -5 yards. FUMBLES, and recovers at NO 24. 15-T.Siemian pass incomplete left.
# 749340                                     (14:36) (No Huddle, Shotgun) 16-T.Lawrence pass middle to 7-T.Austin to JAX 39 for 14 yards (21-D.Harmon).
# 775622  (:31) (Shotgun) 7-G.Smith pass incomplete middle [56-S.Ebukam]. PENALTY on SEA-7-G.Smith, Intentional Grounding, 13 yards, enforced at SF 37.
# 780811                                  (2:01) (No Huddle, Shotgun) 8-K.Cousins pass middle to 18-J.Jefferson to NO 19 for 11 yards (23-M.Lattimore).
# 788480                                               (5:44) (No Huddle, Shotgun) 10-J.Garoppolo pass incomplete right to 19-D.Samuel (23-J.Williams).
#
#         incomplete_pass  complete_pass  cpoe  interceptions  passing_yards  \
# 2506                1.0            0.0   NaN            0.0            0.0
# 2523                1.0            0.0   NaN            0.0            0.0
# 4588                0.0            1.0   NaN            0.0           31.0
# 8835                1.0            0.0   NaN            0.0            0.0
# 8901                1.0            0.0   NaN            0.0            0.0
# ...                 ...            ...   ...            ...            ...
# 741230              1.0            0.0   NaN            0.0            0.0
# 749340              0.0            1.0   NaN            0.0           14.0
# 775622              1.0            0.0   NaN            0.0            0.0
# 780811              0.0            1.0   NaN            0.0           11.0
# 788480              1.0            0.0   NaN            0.0            0.0
#
#         yards_after_catch  air_yards
# 2506                  0.0        NaN
# 2523                  0.0        NaN
# 4588                  NaN        NaN
# 8835                  0.0        NaN
# 8901                  0.0        NaN
# ...                   ...        ...
# 741230                0.0        NaN
# 749340                NaN        NaN
# 775622                0.0        NaN
# 780811                NaN        NaN
# 788480                0.0        NaN
#
# [176 rows x 15 columns]
# Number of rows with NA value in column "air_yards": 176
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        player_name  season  week  matchup posteam posteam_home defteam  \
# 4588     E.Manning    2006     2  PHI-NYG     NYG            0     PHI
# 8941      D.McNabb    2006     4   PHI-GB     PHI            1      GB
# 10509      D.Huard    2006     4    KC-SF      KC            1      SF
# 11144    D.Bledsoe    2006     5  PHI-DAL     DAL            0     PHI
# 11149     D.McNabb    2006     5  PHI-DAL     PHI            1     DAL
# ...            ...     ...   ...      ...     ...          ...     ...
# 485127     D.Brees    2016     3   NO-ATL      NO            1     ATL
# 556468    J.McCown    2017    12  NYJ-CAR     NYJ            1     CAR
# 724824   S.Darnold    2021     2   CAR-NO     CAR            1      NO
# 749340  T.Lawrence    2021    12  JAX-ATL     JAX            1     ATL
# 780811   K.Cousins    2022     4   NO-MIN     MIN            0      NO
#
#                                                                                                                                                                                                     desc  \
# 4588                                                                                                                    (3:18) (Shotgun) 10-E.Manning pass left to 17-P.Burress for 31 yards, TOUCHDOWN.
# 8941                                                                                                          (9:12) (No Huddle) 5-D.McNabb pass right to 38-T.Tapeh to GB 23 for 1 yard (74-A.Kampman).
# 10509                                                                                                                           (6:34) 11-D.Huard pass to 18-S.Parker to SF 16 for 6 yards (20-M.Adams).
# 11144                                                                                                                     (13:51) 11-D.Bledsoe pass to 83-T.Glenn to DAL 45 for 7 yards (26-L.Sheppard).
# 11149                                                                                                                         (12:13) 5-D.McNabb pass to 84-H.Baskett to DAL 5 for 7 yards (42-A.Henry).
# ...                                                                                                                                                                                                  ...
# 485127                                                                                        (8:19) (Shotgun) 9-D.Brees pass middle to 22-M.Ingram to ATL 3 for -1 yards (44-V.Beasley). Pass -1, YAC 2
# 556468  (2:12) (Shotgun) 15-J.McCown pass right to 29-B.Powell pushed ob at NYJ 47 for 12 yards (59-L.Kuechly). PENALTY on NYJ-16-C.Hansen, Illegal Block Above the Waist, 10 yards, enforced at NYJ 47.
# 724824                                                                                                                    (2:00) (Shotgun) 14-S.Darnold pass right to 2-Dj.Moore for 2 yards, TOUCHDOWN.
# 749340                                                                                        (14:36) (No Huddle, Shotgun) 16-T.Lawrence pass middle to 7-T.Austin to JAX 39 for 14 yards (21-D.Harmon).
# 780811                                                                                     (2:01) (No Huddle, Shotgun) 8-K.Cousins pass middle to 18-J.Jefferson to NO 19 for 11 yards (23-M.Lattimore).
#
#         incomplete_pass  complete_pass  cpoe  interceptions  passing_yards  \
# 4588                0.0            1.0   NaN            0.0           31.0
# 8941                0.0            1.0   NaN            0.0            1.0
# 10509               0.0            1.0   NaN            0.0            6.0
# 11144               0.0            1.0   NaN            0.0            7.0
# 11149               0.0            1.0   NaN            0.0            7.0
# ...                 ...            ...   ...            ...            ...
# 485127              0.0            1.0   NaN            0.0           -1.0
# 556468              0.0            1.0   NaN            0.0           12.0
# 724824              0.0            1.0   NaN            0.0            2.0
# 749340              0.0            1.0   NaN            0.0           14.0
# 780811              0.0            1.0   NaN            0.0           11.0
#
#         air_yards  yards_after_catch
# 4588          NaN                NaN
# 8941          NaN                NaN
# 10509         NaN                NaN
# 11144         NaN                NaN
# 11149         NaN                NaN
# ...           ...                ...
# 485127        NaN                NaN
# 556468        NaN                NaN
# 724824        NaN                NaN
# 749340        NaN                NaN
# 780811        NaN                NaN
#
# [78 rows x 15 columns]
# Number of rows with NA value in column "yards_after_catch": 78
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#              player_name  season  week matchup posteam posteam_home defteam  \
# 625589  B.Roethlisberger    2019     1  NE-PIT     PIT            0      NE
#
#                                                                                                                            desc  \
# 625589  (:06) (Shotgun) 7-B.Roethlisberger pass short left to 89-V.McDonald to NE 5 for 21 yards (24-S.Gilmore; 30-J.McCourty).
#
#         incomplete_pass  complete_pass       cpoe  interceptions  \
# 625589              0.0            1.0  30.722666            0.0
#
#         passing_yards  yards_after_catch  air_yards  pass_epa
# 625589           21.0               14.0        7.0       NaN
# Number of rows with NA value in column "pass_epa": 1
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /tmp/ipykernel_9872/1537699982.py:55: UserWarning: ['cpoe' 'air_yards' 'yards_after_catch' 'pass_epa'] column(s) in the DataFrame have NA values (None or NaN).
#
#                 See above displayed DataFrame subsets
#   warnings.warn(
# Columns to check for NA values:  ['pass_attempts', 'completion_perc', 'cpoe', 'passing_yards', 'air_yards', 'yards_after_catch', 'pass_touchdowns', 'interceptions', 'qb_hits', 'sacks', 'pass_epa', 'pass_wpa', 'posteam_score', 'score_diff']
#     player_name  season  week matchup posteam posteam_home defteam  \
# 121     D.Huard    2006     4   KC-SF      KC            1      SF
# 122     A.Smith    2006     4   KC-SF      SF            0      KC
# 204    P.Rivers    2006     7  KC-LAC     LAC            0      KC
# 205     D.Huard    2006     7  KC-LAC      KC            1     LAC
# 230     D.Huard    2006     8  KC-SEA      KC            1     SEA
# 231   S.Wallace    2006     8  KC-SEA     SEA            0      KC
# 317    A.Brooks    2006    11   KC-LV      LV            0      KC
# 401     T.Green    2006    14  KC-BAL      KC            1     BAL
# 402    S.McNair    2006    14  KC-BAL     BAL            0      KC
# 520     T.Green    2006    17  KC-JAX      KC            1     JAX
# 521   D.Garrard    2006    17  KC-JAX     JAX            0      KC
# 522      Q.Gray    2006    17  KC-JAX     JAX            0      KC
#
#      pass_attempts  completion_perc  passing_yards  air_yards  \
# 121           23.0        78.260872          208.0      128.0
# 122           22.0        59.090908           92.0      113.0
# 204           41.0        60.975613          266.0      267.0
# 205           27.0        55.555557          232.0      219.0
# 230           25.0        68.000000          312.0      261.0
# 231           28.0        53.571426          198.0      302.0
# 317           21.0        61.904762          179.0      220.0
# 401           25.0        60.000004          178.0      241.0
# 402           27.0        77.777779          283.0      181.0
# 520           19.0        73.684212          181.0      164.0
# 521           17.0        58.823532          140.0      139.0
# 522           22.0        59.090908          166.0      234.0
#
#      yards_after_catch  pass_touchdowns  interceptions  qb_hits  sacks  \
# 121               80.0              2.0            0.0      0.0    0.0
# 122               49.0              0.0            2.0      5.0    5.0
# 204              164.0              2.0            1.0      8.0    4.0
# 205               98.0              2.0            0.0      3.0    2.0
# 230              108.0              1.0            0.0      2.0    1.0
# 231               44.0              3.0            2.0      2.0    1.0
# 317               22.0              1.0            1.0      4.0    0.0
# 401               64.0              1.0            2.0      4.0    5.0
# 402              134.0              1.0            0.0      0.0    0.0
# 520               85.0              1.0            2.0      3.0    3.0
# 521               72.0              1.0            1.0      3.0    2.0
# 522               40.0              0.0            0.0      3.0    1.0
#
#       pass_epa  pass_wpa  posteam_score  score_diff  cpoe
# 121  19.209085  0.293689             41          41   NaN
# 122 -16.610987 -0.156977              0         -41   NaN
# 204   1.337986 -0.205896             27          -3   NaN
# 205   0.575824 -0.081907             30           3   NaN
# 230  20.141027  0.739815             35           7   NaN
# 231   4.436914  0.164734             28          -7   NaN
# 317   5.535492 -0.004448             13          -4   NaN
# 401  -3.478436 -0.426741             10         -10   NaN
# 402   8.032654  0.212695             20          10   NaN
# 520  -2.906317 -0.092565             35           5   NaN
# 521  -6.345139 -0.156089             30          -5   NaN
# 522   5.357984 -0.023623             30          -5   NaN
# Number of rows with NA value in column "cpoe": 12
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# Removing the 12 entries from 2006 with NaN CPOE mean values and re-testing the DataFrame for NA values:
#
#
# Columns to check for NA values:  ['pass_attempts', 'completion_perc', 'cpoe', 'passing_yards', 'air_yards', 'yards_after_catch', 'pass_touchdowns', 'interceptions', 'qb_hits', 'sacks', 'pass_epa', 'pass_wpa', 'posteam_score', 'score_diff']
#
# NO NA VALUES DETECTED :)
#
#
#
# (9272, 21)
# /tmp/ipykernel_9872/1537699982.py:55: UserWarning: ['cpoe'] column(s) in the DataFrame have NA values (None or NaN).
#
#                 See above displayed DataFrame subsets
#   warnings.warn(
#   player_name  season  week  matchup posteam posteam_home defteam  \
# 0      M.Vick    2006     1  CAR-ATL     ATL            0     CAR
# 1  J.Delhomme    2006     1  CAR-ATL     CAR            1     ATL
# 2    S.McNair    2006     1   TB-BAL     BAL            0      TB
# 3     C.Simms    2006     1   TB-BAL      TB            1     BAL
# 4     T.Brady    2006     1   NE-BUF      NE            1     BUF
# 5    J.Losman    2006     1   NE-BUF     BUF            0      NE
# 6  R.Grossman    2006     1   GB-CHI     CHI            0      GB
# 7     B.Favre    2006     1   GB-CHI      GB            1     CHI
# 8     T.Green    2006     1   KC-CIN      KC            1     CIN
# 9    C.Palmer    2006     1   KC-CIN     CIN            0      KC
#
#    pass_attempts  completion_perc       cpoe  passing_yards  air_yards  \
# 0           22.0        45.454548  -8.161228          140.0      223.0
# 1           38.0        55.263157  -6.003302          186.0      315.0
# 2           26.0        65.384613  13.871142          181.0      220.0
# 3           26.0        65.384613  10.953908          133.0      141.0
# 4           22.0        50.000000  -6.189466          163.0      228.0
# 5           23.0        65.217392  14.732922          164.0      156.0
# 6           25.0        72.000000  16.295139          262.0      287.0
# 7           27.0        55.555557  -6.816815          170.0      367.0
# 8           14.0        78.571426  21.952257           90.0      143.0
# 9           19.0        68.421051   1.411423          127.0      132.0
#
#    yards_after_catch  pass_touchdowns  interceptions  qb_hits  sacks  \
# 0               71.0              2.0            0.0      6.0    1.0
# 1               55.0              0.0            1.0      4.0    4.0
# 2               53.0              1.0            0.0      9.0    1.0
# 3               64.0              0.0            3.0      7.0    2.0
# 4               54.0              2.0            1.0      4.0    3.0
# 5               89.0              0.0            0.0     13.0    3.0
# 6               73.0              1.0            1.0      6.0    1.0
# 7               65.0              0.0            2.0      6.0    3.0
# 8               11.0              0.0            1.0      4.0    3.0
# 9               87.0              0.0            0.0      2.0    1.0
#
#     pass_epa  pass_wpa  posteam_score  score_diff
# 0   4.214338  0.155546             20          14
# 1 -16.548756 -0.281846              6         -14
# 2   7.031124  0.073333             27          27
# 3 -27.841118 -0.498364              0         -27
# 4  -4.263944 -0.197327             19           2
# 5   0.724899 -0.030563             17          -2
# 6  11.844118  0.245271             26          26
# 7  -9.652008 -0.048424              0         -26
# 8  -4.619071 -0.104323             10         -13
# 9  -1.528732 -0.010544             23          13

# %% [markdown]
# Below, I was hoping to roughly gauge if a passer left the game appreciably early due to injury so that that passer's<br>
# stats for that week could be removed (so as to avoid including a largely incomplete game in my rolling averages).<br>
# Similarly, I could make sure I retain the stats of the backup quarterback should they play a large majority of the game.
# <br>
# However, as I do not currently have injury data, and players leaving early due to injury could be contaminated by players<br>
# leaving early due to a lopsided score, the use of a rotation of passers, or a passer getting injured but coming back into the<br>
# game it is hard to isolate injured players or even what would be the best criteria with which to decide whether to remove or<br>
# retain that player's stats for the week.
# <br>
# I want to revisit this after I get a prediction model working.

# %%
# count_overall = 0
# count_one  = 0
# count_stob = 0
# count_mix  = 0
# count_multb = 0

# for _, frame in passer_df.groupby(['season', 'week', 'matchup']):
#     if len(frame) == 1:
#         count_one += 1
#         count_overall += 1
#         print('Only one passer listed for this game:')
#         display(frame[['player_name', 'season', 'week', 'matchup', 'posteam', 'game_min_rem_fp', 'game_min_rem_lp', 'pass_attempts', 'score_diff']])
#     elif len(frame) > 2:
#         count_overall += 1
#         for team in frame['posteam'].unique():
#             df_mult_qbs = frame[frame['posteam'] == team]
#             if len(df_mult_qbs) == 2:
#                 starter = df_mult_qbs[df_mult_qbs['game_min_rem_fp'] == df_mult_qbs['game_min_rem_fp'].max()]
#                 backup  = df_mult_qbs[df_mult_qbs['game_min_rem_fp'] == df_mult_qbs['game_min_rem_fp'].min()]
#                 if starter['game_min_rem_lp'].iloc[0] > backup['game_min_rem_fp'].iloc[0]:
#                     count_stob += 1
#                     print('Backup passer clearly put into the game for the remainder:')
#                     display(df_mult_qbs[['player_name', 'season', 'week', 'matchup', 'posteam', 'game_min_rem_fp', 'game_min_rem_lp', 'pass_attempts', 'score_diff']])
#                 elif starter['game_min_rem_lp'].iloc[0] < backup['game_min_rem_fp'].iloc[0]:
#                     count_mix += 1
#                     print('Unclear if starter got hurt and came back or if two qbs were used throughout the game:')
#                     display(df_mult_qbs[['player_name', 'season', 'week', 'matchup', 'posteam', 'game_min_rem_fp', 'game_min_rem_lp', 'pass_attempts', 'score_diff']])
#             elif len(df_mult_qbs) > 2:
#                 count_multb += 1
#                 print('Multiple backup qbs played in this game:')
#                 display(df_mult_qbs[['player_name', 'season', 'week', 'matchup', 'posteam', 'game_min_rem_fp', 'game_min_rem_lp', 'pass_attempts', 'score_diff']])        
        
                
# print()
# print('Overall count: {}'.format(count_overall))
# print('One passer: {}'.format(count_one))
# print('Starter to backup: {}'.format(count_stob))
# print('Unclear: {}'.format(count_mix))
# print('Multiple backups used: {}'.format(count_multb))

# %%
## Merge the passer DataFrame and the compiled_team_stats DataFrame
passer_team_stats_df = pd.merge(passer_df, compiled_team_stats_df.drop(columns='matchup'),
                                how='inner',
                                on=['season', 'week', 'posteam']
                               )

del(passer_df)
del(compiled_team_stats_df)

print(passer_team_stats_df.shape)
passer_team_stats_df.head(10)
# Out:
# (9272, 27)
#   player_name  season  week  matchup posteam posteam_home defteam  \
# 0      M.Vick    2006     1  CAR-ATL     ATL            0     CAR
# 1  J.Delhomme    2006     1  CAR-ATL     CAR            1     ATL
# 2    S.McNair    2006     1   TB-BAL     BAL            0      TB
# 3     C.Simms    2006     1   TB-BAL      TB            1     BAL
# 4     T.Brady    2006     1   NE-BUF      NE            1     BUF
# 5    J.Losman    2006     1   NE-BUF     BUF            0      NE
# 6  R.Grossman    2006     1   GB-CHI     CHI            0      GB
# 7     B.Favre    2006     1   GB-CHI      GB            1     CHI
# 8     T.Green    2006     1   KC-CIN      KC            1     CIN
# 9     D.Huard    2006     1   KC-CIN      KC            1     CIN
#
#    pass_attempts  completion_perc       cpoe  passing_yards  air_yards  \
# 0           22.0        45.454548  -8.161228          140.0      223.0
# 1           38.0        55.263157  -6.003302          186.0      315.0
# 2           26.0        65.384613  13.871142          181.0      220.0
# 3           26.0        65.384613  10.953908          133.0      141.0
# 4           22.0        50.000000  -6.189466          163.0      228.0
# 5           23.0        65.217392  14.732922          164.0      156.0
# 6           25.0        72.000000  16.295139          262.0      287.0
# 7           27.0        55.555557  -6.816815          170.0      367.0
# 8           14.0        78.571426  21.952257           90.0      143.0
# 9           20.0        60.000004  22.763432          140.0      151.0
#
#    yards_after_catch  pass_touchdowns  interceptions  qb_hits  sacks  \
# 0               71.0              2.0            0.0      6.0    1.0
# 1               55.0              0.0            1.0      4.0    4.0
# 2               53.0              1.0            0.0      9.0    1.0
# 3               64.0              0.0            3.0      7.0    2.0
# 4               54.0              2.0            1.0      4.0    3.0
# 5               89.0              0.0            0.0     13.0    3.0
# 6               73.0              1.0            1.0      6.0    1.0
# 7               65.0              0.0            2.0      6.0    3.0
# 8               11.0              0.0            1.0      4.0    3.0
# 9               59.0              1.0            0.0      3.0    4.0
#
#     pass_epa  pass_wpa  posteam_score  score_diff  perc_pass_plays_team  \
# 0   4.214338  0.155546             20          14             33.333333
# 1 -16.548756 -0.281846              6         -14             72.881356
# 2   7.031124  0.073333             27          27             46.551724
# 3 -27.841118 -0.498364              0         -27             74.000000
# 4  -4.263944 -0.197327             19           2             40.625000
# 5   0.724899 -0.030563             17          -2             52.000000
# 6  11.844118  0.245271             26          26             43.750000
# 7  -9.652008 -0.048424              0         -26             58.928571
# 8  -4.619071 -0.104323             10         -13             62.686567
# 9  -4.800004 -0.032150             10         -13             62.686567
#
#    pass_oe_team  total_giveaways_team  turnover_diff_team  \
# 0    -13.694357                   0.0                 2.0
# 1     -0.803797                   2.0                -2.0
# 2     -2.519106                   0.0                 3.0
# 3      3.605388                   3.0                -3.0
# 4    -15.551071                   2.0                -2.0
# 5     -6.181612                   0.0                 2.0
# 6     -4.278595                   1.0                 2.0
# 7     -5.497789                   3.0                -2.0
# 8     -4.007664                   3.0                -2.0
# 9     -4.007664                   3.0                -2.0
#
#    total_penalties_team  penalty_yards_team
# 0                   2.0                20.0
# 1                   8.0                45.0
# 2                   4.0                25.0
# 3                   3.0                21.0
# 4                   1.0                 5.0
# 5                   7.0                53.0
# 6                   4.0                25.0
# 7                   5.0                45.0
# 8                   5.0                40.0
# 9                   5.0                40.0

# %% [markdown]
# ### Defense Data Preprocessing and Feature Engineering<br>
#
# This data is manipulated and processed in the same manner as the passer and passer's team data, *with a few minor changes.*
# <br>
# As with the passer and passer's team data, the defense's full team stats are considered first (have **\_team** in the column names)<br>
# followed by the stats of the pass defense only.

# %%
## Reload the play-by-play data and set up the play-by-play DataFrame similarly to the play-by-play DataFrame used for the passer above
dpbp = nfl.import_pbp_data(seasons, pbp_columns)

print()

dpbp = dpbp[pbp_columns]

print(dpbp.shape)
dpbp.head(180)
# Out:
# 2006 done.
# 2007 done.
# 2008 done.
# 2009 done.
# 2010 done.
# 2011 done.
# 2012 done.
# 2013 done.
# 2014 done.
# 2015 done.
# 2016 done.
# 2017 done.
# 2018 done.
# 2019 done.
# 2020 done.
# 2021 done.
# 2022 done.
# Downcasting floats.
#
# (820627, 36)
#     passer_player_name  season season_type  week home_team away_team posteam  \
# 0                 None    2006         REG     1       CAR       ATL    None
# 1                 None    2006         REG     1       CAR       ATL     ATL
# 2                 None    2006         REG     1       CAR       ATL     ATL
# 3                 None    2006         REG     1       CAR       ATL     ATL
# 4               M.Vick    2006         REG     1       CAR       ATL     ATL
# ..                 ...     ...         ...   ...       ...       ...     ...
# 175         J.Delhomme    2006         REG     1       CAR       ATL     CAR
# 176               None    2006         REG     1       CAR       ATL     ATL
# 177               None    2006         REG     1       CAR       ATL    None
# 178               None    2006         REG     1        TB       BAL    None
# 179               None    2006         REG     1        TB       BAL     BAL
#
#     posteam_type defteam  \
# 0           None    None
# 1           away     CAR
# 2           away     CAR
# 3           away     CAR
# 4           away     CAR
# ..           ...     ...
# 175         home     ATL
# 176         away     CAR
# 177         None    None
# 178         None    None
# 179         away      TB
#
#                                                                                                                desc  \
# 0                                                                                                              GAME
# 1    7-J.Baker kicks 75 yards from CAR 30 to ATL -5. 20-A.Rossum to ATL 33 for 38 yards (7-J.Baker, 31-R.Marshall).
# 2                               (14:54) 28-W.Dunn right tackle to ATL 38 for 5 yards (99-M.Kemoeatu, 77-K.Jenkins).
# 3                                               (14:18) 28-W.Dunn right end to ATL 37 for -1 yards (36-S.Williams).
# 4              (13:33) (Shotgun) 7-M.Vick pass short right to 83-A.Crumpler to ATL 47 for 10 yards (31-R.Marshall).
# ..                                                                                                              ...
# 175                                      (:17) (Shotgun) 17-J.Delhomme pass incomplete short right to 83-K.Colbert.
# 176                                                                   (:13) 7-M.Vick kneels to ATL 32 for -1 yards.
# 177                                                                                                        END GAME
# 178                                                                                                            GAME
# 179                3-M.Bryant kicks 68 yards from TB 30 to BAL 2. 36-B.Sams to BAL 20 for 18 yards (23-J.Phillips).
#
#     play_type  pass_attempt  incomplete_pass  complete_pass    pass_oe  \
# 0        None           NaN              NaN            NaN        NaN
# 1     kickoff           0.0              0.0            0.0        NaN
# 2         run           0.0              0.0            0.0 -44.816696
# 3         run           0.0              0.0            0.0 -43.687210
# 4        pass           1.0              0.0            1.0   3.369230
# ..        ...           ...              ...            ...        ...
# 175      pass           1.0              1.0            0.0   1.456791
# 176  qb_kneel           0.0              0.0            0.0        NaN
# 177      None           NaN              NaN            NaN        NaN
# 178      None           NaN              NaN            NaN        NaN
# 179   kickoff           0.0              0.0            0.0        NaN
#
#           cpoe  passing_yards  air_yards  yards_after_catch  pass_touchdown  \
# 0          NaN            NaN        NaN                NaN             NaN
# 1          NaN            NaN        NaN                NaN             0.0
# 2          NaN            NaN        NaN                NaN             0.0
# 3          NaN            NaN        NaN                NaN             0.0
# 4    41.941399           10.0        9.0                1.0             0.0
# ..         ...            ...        ...                ...             ...
# 175 -57.791496            NaN        8.0                NaN             0.0
# 176        NaN            NaN        NaN                NaN             0.0
# 177        NaN            NaN        NaN                NaN             NaN
# 178        NaN            NaN        NaN                NaN             NaN
# 179        NaN            NaN        NaN                NaN             0.0
#
#      interception  fumble_lost fumbled_1_team fumbled_2_team  \
# 0             NaN          NaN           None           None
# 1             0.0          0.0           None           None
# 2             0.0          0.0           None           None
# 3             0.0          0.0           None           None
# 4             0.0          0.0           None           None
# ..            ...          ...            ...            ...
# 175           0.0          0.0           None           None
# 176           0.0          0.0           None           None
# 177           NaN          NaN           None           None
# 178           NaN          NaN           None           None
# 179           0.0          0.0           None           None
#
#     fumble_recovery_1_team fumble_recovery_2_team  qb_hit  sack  touchback  \
# 0                     None                   None     NaN   NaN        0.0
# 1                     None                   None     0.0   0.0        0.0
# 2                     None                   None     0.0   0.0        0.0
# 3                     None                   None     0.0   0.0        0.0
# 4                     None                   None     0.0   0.0        0.0
# ..                     ...                    ...     ...   ...        ...
# 175                   None                   None     0.0   0.0        0.0
# 176                   None                   None     0.0   0.0        0.0
# 177                   None                   None     NaN   NaN        0.0
# 178                   None                   None     NaN   NaN        0.0
# 179                   None                   None     0.0   0.0        0.0
#
#      penalty penalty_team  penalty_yards       epa       wpa  home_score  \
# 0        NaN         None            NaN -0.000000 -0.000000           6
# 1        0.0         None            NaN  0.892853  0.017605           6
# 2        0.0         None            NaN  0.119106  0.002342           6
# 3        0.0         None            NaN -0.851534 -0.023510           6
# 4        0.0         None            NaN  1.862235  0.043966           6
# ..       ...          ...            ...       ...       ...         ...
# 175      0.0         None            NaN -1.420999 -0.000802           6
# 176      0.0         None            NaN  0.000000       NaN           6
# 177      NaN         None            NaN       NaN       NaN           6
# 178      NaN         None            NaN -0.000000 -0.000000           0
# 179      0.0         None            NaN  0.041341 -0.000000           0
#
#      away_score
# 0            20
# 1            20
# 2            20
# 3            20
# 4            20
# ..          ...
# 175          20
# 176          20
# 177          20
# 178          27
# 179          27
#
# [180 rows x 36 columns]

# %%
dpbp_reg = dpbp[dpbp['season_type'] == 'REG'].drop(columns='season_type')
del(dpbp)

dpbp_reg = dpbp_reg[~dpbp_reg['play_type'].isna()]

dpbp_reg['desc'] = dpbp_reg['desc'].str.strip()
dpbp_reg = dpbp_reg[~dpbp_reg['desc'].str.contains('^timeout', case=False)]

dpbp_reg['matchup'] = dpbp_reg['home_team'] + '-' + dpbp_reg['away_team']
reordered_columns = reorder_columns(dpbp_reg, ['matchup'], 'week')
dpbp_reg = dpbp_reg[reordered_columns]

dpbp_reg.rename(columns={'posteam_type': 'defteam_home'}, inplace=True)
dpbp_reg.loc[dpbp_reg['defteam_home'] == 'home', 'defteam_home'] = 0
dpbp_reg.loc[dpbp_reg['defteam_home'] == 'away', 'defteam_home'] = 1

dpbp_reg.head()
# Out:
#   passer_player_name  season  week  matchup home_team away_team posteam  \
# 1               None    2006     1  CAR-ATL       CAR       ATL     ATL
# 2               None    2006     1  CAR-ATL       CAR       ATL     ATL
# 3               None    2006     1  CAR-ATL       CAR       ATL     ATL
# 4             M.Vick    2006     1  CAR-ATL       CAR       ATL     ATL
# 5               None    2006     1  CAR-ATL       CAR       ATL     ATL
#
#   defteam_home defteam  \
# 1            1     CAR
# 2            1     CAR
# 3            1     CAR
# 4            1     CAR
# 5            1     CAR
#
#                                                                                                                                                    desc  \
# 1                                        7-J.Baker kicks 75 yards from CAR 30 to ATL -5. 20-A.Rossum to ATL 33 for 38 yards (7-J.Baker, 31-R.Marshall).
# 2                                                                   (14:54) 28-W.Dunn right tackle to ATL 38 for 5 yards (99-M.Kemoeatu, 77-K.Jenkins).
# 3                                                                                   (14:18) 28-W.Dunn right end to ATL 37 for -1 yards (36-S.Williams).
# 4                                                  (13:33) (Shotgun) 7-M.Vick pass short right to 83-A.Crumpler to ATL 47 for 10 yards (31-R.Marshall).
# 5  (12:58) 7-M.Vick pass incomplete short left to 12-M.Jenkins. PENALTY on CAR-58-T.Davis, Roughing the Passer, 15 yards, enforced at ATL 47 - No Play.
#
#   play_type  pass_attempt  incomplete_pass  complete_pass    pass_oe  \
# 1   kickoff           0.0              0.0            0.0        NaN
# 2       run           0.0              0.0            0.0 -44.816696
# 3       run           0.0              0.0            0.0 -43.687210
# 4      pass           1.0              0.0            1.0   3.369230
# 5   no_play           0.0              0.0            0.0  55.721855
#
#         cpoe  passing_yards  air_yards  yards_after_catch  pass_touchdown  \
# 1        NaN            NaN        NaN                NaN             0.0
# 2        NaN            NaN        NaN                NaN             0.0
# 3        NaN            NaN        NaN                NaN             0.0
# 4  41.941399           10.0        9.0                1.0             0.0
# 5        NaN            NaN        NaN                NaN             0.0
#
#    interception  fumble_lost fumbled_1_team fumbled_2_team  \
# 1           0.0          0.0           None           None
# 2           0.0          0.0           None           None
# 3           0.0          0.0           None           None
# 4           0.0          0.0           None           None
# 5           0.0          0.0           None           None
#
#   fumble_recovery_1_team fumble_recovery_2_team  qb_hit  sack  touchback  \
# 1                   None                   None     0.0   0.0        0.0
# 2                   None                   None     0.0   0.0        0.0
# 3                   None                   None     0.0   0.0        0.0
# 4                   None                   None     0.0   0.0        0.0
# 5                   None                   None     0.0   0.0        0.0
#
#    penalty penalty_team  penalty_yards       epa       wpa  home_score  \
# 1      0.0         None            NaN  0.892853  0.017605           6
# 2      0.0         None            NaN  0.119106  0.002342           6
# 3      0.0         None            NaN -0.851534 -0.023510           6
# 4      0.0         None            NaN  1.862235  0.043966           6
# 5      1.0          CAR           15.0  1.110637  0.067985           6
#
#    away_score
# 1          20
# 2          20
# 3          20
# 4          20
# 5          20

# %%
## Re-compiling the team stats, but grouping by the "defteam" (this will give the same groupings as "posteam" but return the "defteam" for later merging)

## While "assign_lost_fumbles" originally just assigned how many fumbles each team in the matchup lost,
## by simply switching the team names assigned to those lost fumbles, it is now known how many fumbles were recovered by each team.

recovered_fumbles_df = (dpbp_reg
                        .groupby(['season', 'week', 'matchup'], sort=False, as_index=False)
                        .apply(lambda x: assign_lost_fumbles(x, assign_recoveries=True))
                        .droplevel(0)
                       )

off_scheme_int_df = (dpbp_reg
                     .groupby(['season', 'week', 'matchup', 'defteam'], sort=False, as_index=False)
                     .agg({'play_type': pass_percentage, 
                           'pass_oe': np.nanmean, 
                           'interception': np.nansum
                          }
                         )
                    )

off_scheme_TOs_df = pd.merge(off_scheme_int_df, recovered_fumbles_df, 
                             how='inner', 
                             left_on=['season', 'week', 'matchup', 'defteam'], 
                             right_on=['season', 'week', 'matchup', 'recovering_team']
                            )

del(recovered_fumbles_df)
del(off_scheme_int_df)

off_scheme_TOs_df['total_turnovers'] = off_scheme_TOs_df['interception'] + off_scheme_TOs_df['fumbles_recovered']

display(off_scheme_TOs_df)

if np.all(off_scheme_TOs_df['defteam'] == off_scheme_TOs_df['recovering_team']):
    off_scheme_TOs_df.drop(columns='recovering_team', inplace=True)  ## Drops what is effectively a duplicate column
else:
    raise ValueError('The columns "defteam" and "recovering_team" are not identical as expected after merging')
    
off_scheme_TOs_df.set_index(['season', 'week', 'matchup', 'defteam'], inplace=True)

## A slight modification is required to properly determine the turnover differentials based on recovered turnovers instead of lost turnovers.
off_scheme_TOs_df['turnover_diff'] = (off_scheme_TOs_df['total_turnovers']
                                      .groupby(['season', 'week', 'matchup'], sort=False)
                                      .transform(lambda x: turnover_diff(x, by_recoveries=True))
                                     )

off_scheme_TOs_df = off_scheme_TOs_df.drop(columns=['interception', 'fumbles_recovered'])

off_scheme_TOs_df
# Out:
#       season  week  matchup defteam  play_type    pass_oe  interception  \
# 0       2006     1  CAR-ATL     CAR  33.333333 -13.694357           0.0
# 1       2006     1  CAR-ATL     ATL  72.881356  -0.803797           1.0
# 2       2006     1   TB-BAL      TB  46.551724  -2.519106           0.0
# 3       2006     1   TB-BAL     BAL  74.000000   3.605388           3.0
# 4       2006     1   NE-BUF     BUF  40.625000 -15.551071           1.0
# ...      ...   ...      ...     ...        ...        ...           ...
# 8761    2022    18  MIA-NYJ     MIA  62.264151  -7.393189           0.0
# 8762    2022    18   ATL-TB     ATL  62.962963  -3.075565           0.0
# 8763    2022    18   ATL-TB      TB  47.761194  -6.894469           0.0
# 8764    2022    18  JAX-TEN     JAX  45.833333 -17.373583           1.0
# 8765    2022    18  JAX-TEN     TEN  73.333333   9.846007           0.0
#
#      recovering_team  fumbles_recovered  total_turnovers
# 0                CAR                  0              0.0
# 1                ATL                  1              2.0
# 2                 TB                  0              0.0
# 3                BAL                  0              3.0
# 4                BUF                  1              2.0
# ...              ...                ...              ...
# 8761             MIA                  0              0.0
# 8762             ATL                  1              1.0
# 8763              TB                  1              1.0
# 8764             JAX                  1              2.0
# 8765             TEN                  1              1.0
#
# [8766 rows x 10 columns]
#                              play_type    pass_oe  total_turnovers  \
# season week matchup defteam
# 2006   1    CAR-ATL CAR      33.333333 -13.694357              0.0
#                     ATL      72.881356  -0.803797              2.0
#             TB-BAL  TB       46.551724  -2.519106              0.0
#                     BAL      74.000000   3.605388              3.0
#             NE-BUF  BUF      40.625000 -15.551071              2.0
# ...                                ...        ...              ...
# 2022   18   MIA-NYJ MIA      62.264151  -7.393189              0.0
#             ATL-TB  ATL      62.962963  -3.075565              1.0
#                     TB       47.761194  -6.894469              1.0
#             JAX-TEN JAX      45.833333 -17.373583              2.0
#                     TEN      73.333333   9.846007              1.0
#
#                              turnover_diff
# season week matchup defteam
# 2006   1    CAR-ATL CAR               -2.0
#                     ATL                2.0
#             TB-BAL  TB                -3.0
#                     BAL                3.0
#             NE-BUF  BUF                2.0
# ...                                    ...
# 2022   18   MIA-NYJ MIA                0.0
#             ATL-TB  ATL               -0.0
#                     TB                 0.0
#             JAX-TEN JAX                1.0
#                     TEN               -1.0
#
# [8766 rows x 4 columns]

# %%
## Re-compiling the penalty and penalty yard data
penalties_df = (dpbp_reg
                .groupby(['season', 'week', 'matchup', 'penalty_team'], sort=False, dropna=False)
                .agg({'penalty': np.nansum, 'penalty_yards': np.nansum})
               )

penalties_df = (penalties_df
                .groupby(level=['season', 'week', 'matchup'], sort=False, as_index=False)
                .apply(lambda x: clean_penalty_df(x))
                .droplevel(0)
               )

penalties_df
# Out:
#                                   penalty  penalty_yards
# season week matchup penalty_team
# 2006   1    CAR-ATL CAR               8.0           45.0
#                     ATL               2.0           20.0
#             TB-BAL  BAL               4.0           25.0
#                     TB                3.0           21.0
#             NE-BUF  NE                1.0            5.0
# ...                                   ...            ...
# 2022   18   MIA-NYJ NYJ               6.0           54.0
#             ATL-TB  TB                3.0           30.0
#                     ATL               2.0           18.0
#             JAX-TEN TEN               6.0           40.0
#                     JAX               4.0           25.0
#
# [8766 rows x 2 columns]

# %%
## Merge the two preceding DataFrames
compiled_team_stats_df = pd.merge(off_scheme_TOs_df.reset_index(), penalties_df.reset_index(), 
                                  how='inner', ## Intersection or inner join of keys - Preserves the order of the left keys
                                  left_on=['season', 'week', 'matchup', 'defteam'], 
                                  right_on=['season', 'week', 'matchup', 'penalty_team'])

compiled_team_stats_df = compiled_team_stats_df.rename(columns={'play_type': 'perc_pass_plays_team', 
                                                                'pass_oe': 'pass_oe_team',
                                                                'total_turnovers': 'total_giveaways_team',
                                                                'turnover_diff': 'turnover_diff_team',
                                                                'penalty': 'total_penalties_team',
                                                                'penalty_yards': 'penalty_yards_team'
                                                               }
                                                      )

if np.all(compiled_team_stats_df['defteam'] == compiled_team_stats_df['penalty_team']):
    compiled_team_stats_df.drop(columns='penalty_team', inplace=True)  ## Drops what is effectively a duplicate column
else:
    raise ValueError('The columns "defteam" and "penalty_team" are not identical as expected after merging')


del(off_scheme_TOs_df)
del(penalties_df)
compiled_team_stats_df
# Out:
#       season  week  matchup defteam  perc_pass_plays_team  pass_oe_team  \
# 0       2006     1  CAR-ATL     CAR             33.333333    -13.694357
# 1       2006     1  CAR-ATL     ATL             72.881356     -0.803797
# 2       2006     1   TB-BAL      TB             46.551724     -2.519106
# 3       2006     1   TB-BAL     BAL             74.000000      3.605388
# 4       2006     1   NE-BUF     BUF             40.625000    -15.551071
# ...      ...   ...      ...     ...                   ...           ...
# 8761    2022    18  MIA-NYJ     MIA             62.264151     -7.393189
# 8762    2022    18   ATL-TB     ATL             62.962963     -3.075565
# 8763    2022    18   ATL-TB      TB             47.761194     -6.894469
# 8764    2022    18  JAX-TEN     JAX             45.833333    -17.373583
# 8765    2022    18  JAX-TEN     TEN             73.333333      9.846007
#
#       total_giveaways_team  turnover_diff_team  total_penalties_team  \
# 0                      0.0                -2.0                   8.0
# 1                      2.0                 2.0                   2.0
# 2                      0.0                -3.0                   3.0
# 3                      3.0                 3.0                   4.0
# 4                      2.0                 2.0                   7.0
# ...                    ...                 ...                   ...
# 8761                   0.0                 0.0                   5.0
# 8762                   1.0                -0.0                   2.0
# 8763                   1.0                 0.0                   3.0
# 8764                   2.0                 1.0                   4.0
# 8765                   1.0                -1.0                   6.0
#
#       penalty_yards_team
# 0                   45.0
# 1                   20.0
# 2                   21.0
# 3                   25.0
# 4                   53.0
# ...                  ...
# 8761                47.0
# 8762                18.0
# 8763                30.0
# 8764                25.0
# 8765                40.0
#
# [8766 rows x 10 columns]

# %%
## Creating another DataFrame which focuses on the "pass" play_type and the pass defense
pass_defense_df = dpbp_reg[dpbp_reg['play_type'] == 'pass']
del(dpbp_reg)

pass_defense_df['points_allowed'] = create_score_col(pass_defense_df, 'defteam')
pass_defense_df['defteam_score']  = create_score_col(pass_defense_df, 'defteam', posteam_score=False)
pass_defense_df['score_diff']     = pass_defense_df['defteam_score'] - pass_defense_df['points_allowed']
## "Score_diff" is negative if the defense gives up more points than the defensive team's offense scores

reordered_columns = reorder_columns(pass_defense_df, ['points_allowed', 'defteam_score', 'score_diff'], 'away_score')
pass_defense_df = pass_defense_df[reordered_columns]

print(pass_defense_df.shape)
pass_defense_df.head()
# Out:
# (319773, 39)
#    passer_player_name  season  week  matchup home_team away_team posteam  \
# 4              M.Vick    2006     1  CAR-ATL       CAR       ATL     ATL
# 6              M.Vick    2006     1  CAR-ATL       CAR       ATL     ATL
# 8              M.Vick    2006     1  CAR-ATL       CAR       ATL     ATL
# 11             M.Vick    2006     1  CAR-ATL       CAR       ATL     ATL
# 15         J.Delhomme    2006     1  CAR-ATL       CAR       ATL     CAR
#
#    defteam_home defteam  \
# 4             1     CAR
# 6             1     CAR
# 8             1     CAR
# 11            1     CAR
# 15            0     ATL
#
#                                                                                                     desc  \
# 4   (13:33) (Shotgun) 7-M.Vick pass short right to 83-A.Crumpler to ATL 47 for 10 yards (31-R.Marshall).
# 6           (12:51) (Shotgun) 7-M.Vick pass short left to 87-A.Lelie to CAR 33 for 5 yards (21-K.Lucas).
# 8                          (11:53) 7-M.Vick pass incomplete short middle to 83-A.Crumpler (55-D.Morgan).
# 11                                (11:01) (Shotgun) 7-M.Vick sacked at CAR 37 for -7 yards (92-D.Lewis).
# 15                    (9:42) 17-J.Delhomme pass short left to 19-K.Johnson ran ob at ATL 49 for 8 yards.
#
#    play_type  pass_attempt  incomplete_pass  complete_pass    pass_oe  \
# 4       pass           1.0              0.0            1.0   3.369230
# 6       pass           1.0              0.0            1.0  57.607498
# 8       pass           1.0              1.0            0.0  60.318436
# 11      pass           1.0              0.0            0.0   9.443247
# 15      pass           1.0              0.0            1.0  37.402725
#
#          cpoe  passing_yards  air_yards  yards_after_catch  pass_touchdown  \
# 4   41.941399           10.0        9.0                1.0             0.0
# 6   28.154320            5.0        5.0                0.0             0.0
# 8  -75.039024            NaN        6.0                NaN             0.0
# 11        NaN            NaN        NaN                NaN             0.0
# 15  29.104429            8.0        6.0                2.0             0.0
#
#     interception  fumble_lost fumbled_1_team fumbled_2_team  \
# 4            0.0          0.0           None           None
# 6            0.0          0.0           None           None
# 8            0.0          0.0           None           None
# 11           0.0          0.0           None           None
# 15           0.0          0.0           None           None
#
#    fumble_recovery_1_team fumble_recovery_2_team  qb_hit  sack  touchback  \
# 4                    None                   None     0.0   0.0        0.0
# 6                    None                   None     0.0   0.0        0.0
# 8                    None                   None     0.0   0.0        0.0
# 11                   None                   None     1.0   1.0        0.0
# 15                   None                   None     0.0   0.0        0.0
#
#     penalty penalty_team  penalty_yards       epa       wpa  home_score  \
# 4       0.0         None            NaN  1.862235  0.043966           6
# 6       0.0         None            NaN  0.184564 -0.012592           6
# 8       0.0         None            NaN -0.380531 -0.015467           6
# 11      0.0         None            NaN -2.290171 -0.043999           6
# 15      0.0         None            NaN  0.831313  0.014238           6
#
#     away_score  points_allowed  defteam_score  score_diff
# 4           20              20              6         -14
# 6           20              20              6         -14
# 8           20              20              6         -14
# 11          20              20              6         -14
# 15          20               6             20          14

# %%
## Re-creating the passing game stat DataFrame from a defensive perspective (what they have allowed or seen)
## Applying similar changes to the "pass_defense_df" as to the "pass_defense_df" for consistency

cols_to_drop = ['home_team', 'away_team', 'play_type', 'pass_attempt', 'pass_oe', 'fumble_lost', 'fumbled_1_team', 'fumbled_2_team',
                'fumble_recovery_1_team', 'fumble_recovery_2_team', 'touchback', 'penalty', 'penalty_team', 'penalty_yards',
                'home_score', 'away_score', 'defteam_score']

pass_defense_df = pass_defense_df.drop(columns=cols_to_drop)
pass_defense_df = pass_defense_df.rename(columns={'epa': 'pass_epa', 
                                                  'wpa': 'pass_wpa',
                                                  'pass_touchdown': 'pass_touchdowns',
                                                  'interception': 'interceptions',
                                                  'qb_hit': 'qb_hits',
                                                  'sack': 'sacks'
                                                 }
                                        )

mask1 = pass_defense_df['desc'].str.contains('incomplete|sacked|intercepted|two-point conversion', case=False) 
mask2 = pass_defense_df['desc'].str.contains('sacked|two-point conversion', case=False) ## Air yards are still counted on incomplete/int passes

pass_defense_df.loc[mask1, 'passing_yards'] = pass_defense_df.loc[mask1, 'passing_yards'].fillna(0)
pass_defense_df.loc[mask1, 'yards_after_catch'] = pass_defense_df.loc[mask1, 'yards_after_catch'].fillna(0)
pass_defense_df.loc[mask2, 'air_yards'] = pass_defense_df.loc[mask2, 'air_yards'].fillna(0)

missing_yac = pass_defense_df[pass_defense_df['yards_after_catch'].isna()]
missing_ay  = pass_defense_df[pass_defense_df['air_yards'].isna()]

for entry in missing_yac.index:
    passing_yards = missing_yac.loc[entry, 'passing_yards']
    air_yards = missing_yac.loc[entry, 'air_yards']
    if (np.isnan(passing_yards) == False) and (np.isnan(air_yards) == False):
        pass_defense_df.loc[entry, 'yards_after_catch'] = passing_yards - air_yards

for entry in missing_ay.index:
    passing_yards = missing_ay.loc[entry, 'passing_yards']
    yac = missing_ay.loc[entry, 'yards_after_catch']
    if (np.isnan(passing_yards) == False) and (np.isnan(yac) == False) and ((passing_yards != 0) or (yac != 0)):
        pass_defense_df.loc[entry, 'air_yards'] = passing_yards - yac
        
## When I am considering a team's pass defense, I want that pass defense to reflect the defense against the primary QB,
## much like with "passer_df" I want to consider the stats of only the QB, not other players throwing the ball on a trick play
## or other QBs entering the game for a drive or two (hence the removal of any passers with 5 or fewer pass attempts). 
## Therefore, to help isolate the defensive stats against the primary QB, I am again going to remove any passers with 5 or fewer pass attempts 
## before I grouby by "defteam" and aggregate the defensive stats.
## Unfortunately, this still does not address the existing problem I have of aggregate stats being affected by multiple QBs playing in a game
## for extended time (due to injury, performance, etc.). Perhaps for this cut though, the threshold should be higher, like 10 attempts?

pass_attempts_df = (pass_defense_df
                    .groupby(['passer_player_name', 'season', 'week'], sort=False)
                    .agg({'incomplete_pass': np.nansum, 'complete_pass': np.nansum})
                   )

pass_attempts_df['pass_attempts'] = pass_attempts_df['incomplete_pass'] + pass_attempts_df['complete_pass'] 

pass_attempts_lte5 = pass_attempts_df[pass_attempts_df['pass_attempts'] <= 5]

pass_defense_df = pass_defense_df.set_index(['passer_player_name', 'season', 'week'])
pass_defense_df = pass_defense_df.drop(index=pass_attempts_lte5.index)
pass_defense_df = pass_defense_df.reset_index()


## Aggregating the columns in the pass_defense DataFrame by defteam, season, and week
pass_def_agg_df = pass_defense_df.groupby(['defteam', 'season', 'week'], sort=False).agg(
    {'matchup': 'last',
     'defteam_home': 'last',
     'posteam': 'last',
     'incomplete_pass': np.nansum,
     'complete_pass': np.nansum,
     'cpoe': np.nanmean,
     'passing_yards': np.nansum,
     'air_yards': np.nansum,
     'yards_after_catch': np.nansum,
     'pass_touchdowns': np.nansum,
     'interceptions': np.nansum,
     'qb_hits': np.nansum,
     'sacks': np.nansum,
     'pass_epa': np.nansum,
     'pass_wpa': np.nansum,
     'points_allowed': 'last',
     'score_diff': 'last'
    }
)

del(pass_defense_df)
        
pass_def_agg_df['pass_attempts']   = pass_def_agg_df['incomplete_pass'] + pass_def_agg_df['complete_pass']
pass_def_agg_df['completion_perc'] = pass_def_agg_df['complete_pass'] / pass_def_agg_df['pass_attempts'] * 100.

pass_def_agg_df = pass_def_agg_df.drop(columns=['incomplete_pass', 'complete_pass'])

reordered_columns = reorder_columns(pass_def_agg_df, ['pass_attempts', 'completion_perc'], 'posteam')
pass_def_agg_df = pass_def_agg_df[reordered_columns]

pass_def_agg_df.reset_index(inplace=True)

## Unlike the "passer_df" DataFrame with 12 entries listing NaN for the "cpoe" column, "pass_def_agg_df" only has 11 such entries.
## This is because for the KC-JAX matchup from week 17 of 2006, JAX had two passers (17 and 22 attempts - 39 total pass attempts).
## Since I am not grouping by the "player_name" here, and instead I am grouping by "defteam", the stats of the two JAX passers are 
## combined into one entry, dropping the number of NaN CPOE values from 12 to 11.
## These 11 entries are removed as the 12 were in "passer_df."
print()
print('Removing the 11 entries from 2006 with NaN CPOE mean values:')
print()

pass_def_agg_df = pass_def_agg_df[~pass_def_agg_df['cpoe'].isna()]

print(pass_def_agg_df.shape)
pass_def_agg_df.head(10)
# Out:
# Removing the 11 entries from 2006 with NaN CPOE mean values:
#
# (8754, 20)
#   defteam  season  week  matchup defteam_home posteam  pass_attempts  \
# 0     CAR    2006     1  CAR-ATL            1     ATL           22.0
# 1     ATL    2006     1  CAR-ATL            0     CAR           38.0
# 2      TB    2006     1   TB-BAL            1     BAL           26.0
# 3     BAL    2006     1   TB-BAL            0      TB           26.0
# 4     BUF    2006     1   NE-BUF            0      NE           22.0
# 5      NE    2006     1   NE-BUF            1     BUF           23.0
# 6      GB    2006     1   GB-CHI            1     CHI           25.0
# 7     CHI    2006     1   GB-CHI            0      GB           27.0
# 8     CIN    2006     1   KC-CIN            0      KC           34.0
# 9      KC    2006     1   KC-CIN            1     CIN           19.0
#
#    completion_perc       cpoe  passing_yards  air_yards  yards_after_catch  \
# 0        45.454548  -8.161228          140.0      223.0               71.0
# 1        55.263157  -6.003302          186.0      315.0               55.0
# 2        65.384613  13.871142          181.0      220.0               53.0
# 3        65.384613  10.953908          133.0      141.0               64.0
# 4        50.000000  -6.189466          163.0      228.0               54.0
# 5        65.217392  14.732922          164.0      156.0               89.0
# 6        72.000000  16.295139          262.0      287.0               73.0
# 7        55.555557  -6.816815          170.0      367.0               65.0
# 8        67.647057  22.033375          230.0      294.0               70.0
# 9        68.421051   1.411423          127.0      132.0               87.0
#
#    pass_touchdowns  interceptions  qb_hits  sacks   pass_epa  pass_wpa  \
# 0              2.0            0.0      6.0    1.0   4.214338  0.155546
# 1              0.0            1.0      4.0    4.0 -16.548756 -0.281846
# 2              1.0            0.0      9.0    1.0   7.031124  0.073333
# 3              0.0            3.0      7.0    2.0 -27.841118 -0.498364
# 4              2.0            1.0      4.0    3.0  -4.263944 -0.197327
# 5              0.0            0.0     13.0    3.0   0.724899 -0.030563
# 6              1.0            1.0      6.0    1.0  11.844118  0.245271
# 7              0.0            2.0      6.0    3.0  -9.652008 -0.048424
# 8              1.0            1.0      7.0    7.0  -9.419076 -0.136474
# 9              0.0            0.0      2.0    1.0  -1.528732 -0.010544
#
#    points_allowed  score_diff
# 0              20         -14
# 1               6          14
# 2              27         -27
# 3               0          27
# 4              19          -2
# 5              17           2
# 6              26         -26
# 7               0          26
# 8              10          13
# 9              23         -13

# %%
## Merging the aggregated pass defense DataFrame and the compiled team stats DataFrame
pass_def_team_stats_df = pd.merge(pass_def_agg_df, compiled_team_stats_df.drop(columns='matchup'),
                                  how='inner',
                                  on=['defteam', 'season', 'week']
                                 )

del(pass_def_agg_df)
del(compiled_team_stats_df)

print(pass_def_team_stats_df.shape)
pass_def_team_stats_df.head(10)
# Out:
# (8754, 26)
#   defteam  season  week  matchup defteam_home posteam  pass_attempts  \
# 0     CAR    2006     1  CAR-ATL            1     ATL           22.0
# 1     ATL    2006     1  CAR-ATL            0     CAR           38.0
# 2      TB    2006     1   TB-BAL            1     BAL           26.0
# 3     BAL    2006     1   TB-BAL            0      TB           26.0
# 4     BUF    2006     1   NE-BUF            0      NE           22.0
# 5      NE    2006     1   NE-BUF            1     BUF           23.0
# 6      GB    2006     1   GB-CHI            1     CHI           25.0
# 7     CHI    2006     1   GB-CHI            0      GB           27.0
# 8     CIN    2006     1   KC-CIN            0      KC           34.0
# 9      KC    2006     1   KC-CIN            1     CIN           19.0
#
#    completion_perc       cpoe  passing_yards  air_yards  yards_after_catch  \
# 0        45.454548  -8.161228          140.0      223.0               71.0
# 1        55.263157  -6.003302          186.0      315.0               55.0
# 2        65.384613  13.871142          181.0      220.0               53.0
# 3        65.384613  10.953908          133.0      141.0               64.0
# 4        50.000000  -6.189466          163.0      228.0               54.0
# 5        65.217392  14.732922          164.0      156.0               89.0
# 6        72.000000  16.295139          262.0      287.0               73.0
# 7        55.555557  -6.816815          170.0      367.0               65.0
# 8        67.647057  22.033375          230.0      294.0               70.0
# 9        68.421051   1.411423          127.0      132.0               87.0
#
#    pass_touchdowns  interceptions  qb_hits  sacks   pass_epa  pass_wpa  \
# 0              2.0            0.0      6.0    1.0   4.214338  0.155546
# 1              0.0            1.0      4.0    4.0 -16.548756 -0.281846
# 2              1.0            0.0      9.0    1.0   7.031124  0.073333
# 3              0.0            3.0      7.0    2.0 -27.841118 -0.498364
# 4              2.0            1.0      4.0    3.0  -4.263944 -0.197327
# 5              0.0            0.0     13.0    3.0   0.724899 -0.030563
# 6              1.0            1.0      6.0    1.0  11.844118  0.245271
# 7              0.0            2.0      6.0    3.0  -9.652008 -0.048424
# 8              1.0            1.0      7.0    7.0  -9.419076 -0.136474
# 9              0.0            0.0      2.0    1.0  -1.528732 -0.010544
#
#    points_allowed  score_diff  perc_pass_plays_team  pass_oe_team  \
# 0              20         -14             33.333333    -13.694357
# 1               6          14             72.881356     -0.803797
# 2              27         -27             46.551724     -2.519106
# 3               0          27             74.000000      3.605388
# 4              19          -2             40.625000    -15.551071
# 5              17           2             52.000000     -6.181612
# 6              26         -26             43.750000     -4.278595
# 7               0          26             58.928571     -5.497789
# 8              10          13             62.686567     -4.007664
# 9              23         -13             37.735849     -9.659348
#
#    total_giveaways_team  turnover_diff_team  total_penalties_team  \
# 0                   0.0                -2.0                   8.0
# 1                   2.0                 2.0                   2.0
# 2                   0.0                -3.0                   3.0
# 3                   3.0                 3.0                   4.0
# 4                   2.0                 2.0                   7.0
# 5                   0.0                -2.0                   1.0
# 6                   1.0                -2.0                   5.0
# 7                   3.0                 2.0                   4.0
# 8                   3.0                 2.0                   5.0
# 9                   1.0                -2.0                   5.0
#
#    penalty_yards_team
# 0                45.0
# 1                20.0
# 2                21.0
# 3                25.0
# 4                53.0
# 5                 5.0
# 6                45.0
# 7                25.0
# 8                40.0
# 9                40.0

# %% [markdown]
# ### Calculating moving averages of the data<br>
#
# I want these to be interactive with `ipywidgets`:
#  - weighting scheme (exponential, linear, non-weighted)
#  - window size (# games)
#  - weighting scheme-specific parameters
#  - etc. (such as stat - column - selection in the beginning - though this is much tougher to fully implement)
# <br>
# <br>
# <br>
#
# To begin and get a first-pass working predictive model though, I will start with a default<br>
# **exponentially-weighted moving average (EWMA)** over a window of *N* = **10** games (# currently adjustable).<br>
# The decay for this EWMA method (`pandas.DataFrame.ewm`) is a user-input $\alpha$ smoothing factor ($0 < \alpha \leq 1$; also currently adjustable),<br>
# with the default $\alpha = 2/(N+1)$ (this default is used when the user-input $\alpha$ is left at 0). This default is equivalent to using the<br>
# `span` parameter (`span=N`) in `pandas.DataFrame.ewm`, instead of the `alpha` parameter, to specify the decay.<br>
# From the documentation, `span` corresponds to what is commonly called an "*N*-day EW moving average."
# <br>
# <br>
# ##### Further notes on the EWMA calculations<br>
#
# Initially, I used `pandas.DataFrame.ewm` in order to achieve this. The `pandas.DataFrame.ewm` window is an accumulating window,<br>
# so I first used `pandas.DataFrame.rolling` in order to generate a rolling window of *N* games, to which I then applied<br>
# `pandas.DataFrame.ewm` to the window. Still, the accumulating nature of `pandas.DataFrame.ewm` occured in each window,<br>
# where `pandas.DataFrame.ewm.mean` calculated the weighted average of the window's first element, then first two, then first three,<br>
# and so on until `pandas.DataFrame.ewm.mean` applied to the whole rolling window (length *N*) in the final calculation and returned a<br>
# DataFrame containting all of these averages. I only care about when the whole rolling window is considered, so calculations prior to<br>
# that point were set to `NaN` (via the `min_periods` parameter). As such, I only actually calculated and took the last row of the<br>
# resulting DataFrame of averages. However, this was inefficient as the full accumulation of the window had to play out first.<br>
# Additionally, there was additional, somewhat ugly, code that had to be implemented to construct the full DataFrame of EWMA values<br>
# to be used later in the machine learning.
# <br>
# Currently, I recreate the weighting and averaging of `pandas.DataFrame.ewm` (`adjust=True` variant) in a custom function definition.<br>
# This custom EWMA does not have an accumulating nature. It simply calculates the weights at once for all *N* of the given values and<br>
# provides those weights to `numpy.average`, which it then runs. As such, I apply this custom EWMA to a rolling window of *N* games,<br>
# where it applies to the whole window at once, returning one average value. I may implement the recursive `adjust=False` variant later.
# <br>
# Testing on the "A.Dalton" grouping in the passer DataFrame, this achieves ~2x less computation time as seen below.
# <br>
# <br>
# *Additional weighting schemes (linear, non-weighted) and more interactive features will be added later.*

# %%
## First sorting the passer DataFrame by player_name, season, and week
## Also sorting the pass defense DataFrame by defteam, season, and week
## This will be in the orders of alphabetical (A to Z), ascending numerical, and ascending numerical, respectively, for both frames
sorted_passer_df = passer_team_stats_df.sort_values(['player_name', 'season', 'week'], ascending=True, ignore_index=True)
sorted_passD_df  = pass_def_team_stats_df.sort_values(['defteam', 'season', 'week'], ascending=True, ignore_index=True)

del(passer_team_stats_df)
del(pass_def_team_stats_df)

check_cols_for_NAs(sorted_passer_df, sorted_passer_df.columns.to_list())
check_cols_for_NAs(sorted_passD_df, sorted_passD_df.columns.to_list(), which='defense')

print('Shape of sorted passer DataFrame: ', sorted_passer_df.shape)
display(sorted_passer_df.head(20))

print('Shape of sorted pass defense DataFrame: ', sorted_passD_df.shape)
display(sorted_passD_df.head(20))
# Out:
# Columns to check for NA values:  ['player_name', 'season', 'week', 'matchup', 'posteam', 'posteam_home', 'defteam', 'pass_attempts', 'completion_perc', 'cpoe', 'passing_yards', 'air_yards', 'yards_after_catch', 'pass_touchdowns', 'interceptions', 'qb_hits', 'sacks', 'pass_epa', 'pass_wpa', 'posteam_score', 'score_diff', 'perc_pass_plays_team', 'pass_oe_team', 'total_giveaways_team', 'turnover_diff_team', 'total_penalties_team', 'penalty_yards_team']
#
# NO NA VALUES DETECTED :)
#
#
#
# Columns to check for NA values:  ['defteam', 'season', 'week', 'matchup', 'defteam_home', 'posteam', 'pass_attempts', 'completion_perc', 'cpoe', 'passing_yards', 'air_yards', 'yards_after_catch', 'pass_touchdowns', 'interceptions', 'qb_hits', 'sacks', 'pass_epa', 'pass_wpa', 'points_allowed', 'score_diff', 'perc_pass_plays_team', 'pass_oe_team', 'total_giveaways_team', 'turnover_diff_team', 'total_penalties_team', 'penalty_yards_team']
#
# NO NA VALUES DETECTED :)
#
#
#
# Shape of sorted passer DataFrame:  (9272, 27)
#    player_name  season  week  matchup posteam posteam_home defteam  \
# 0     A.Brooks    2006     1   LV-LAC      LV            1     LAC
# 1     A.Brooks    2006    12   LAC-LV      LV            0     LAC
# 2     A.Brooks    2006    13   LV-HOU      LV            1     HOU
# 3     A.Brooks    2006    14   CIN-LV      LV            0     CIN
# 4     A.Brooks    2006    15    LV-LA      LV            1      LA
# 5     A.Brooks    2006    17   NYJ-LV      LV            0     NYJ
# 6      A.Brown    2022    18  CIN-BAL     BAL            0     CIN
# 7     A.Dalton    2011     1  CLE-CIN     CIN            0     CLE
# 8     A.Dalton    2011     2  DEN-CIN     CIN            0     DEN
# 9     A.Dalton    2011     3   CIN-SF     CIN            1      SF
# 10    A.Dalton    2011     4  CIN-BUF     CIN            1     BUF
# 11    A.Dalton    2011     5  JAX-CIN     CIN            0     JAX
# 12    A.Dalton    2011     6  CIN-IND     CIN            1     IND
# 13    A.Dalton    2011     8  SEA-CIN     CIN            0     SEA
# 14    A.Dalton    2011     9  TEN-CIN     CIN            0     TEN
# 15    A.Dalton    2011    10  CIN-PIT     CIN            1     PIT
# 16    A.Dalton    2011    11  BAL-CIN     CIN            0     BAL
# 17    A.Dalton    2011    12  CIN-CLE     CIN            1     CLE
# 18    A.Dalton    2011    13  PIT-CIN     CIN            0     PIT
# 19    A.Dalton    2011    14  CIN-HOU     CIN            1     HOU
#
#     pass_attempts  completion_perc       cpoe  passing_yards  air_yards  \
# 0            14.0        42.857143 -15.923791           68.0      144.0
# 1            28.0        60.714287  -2.074406          187.0      272.0
# 2            38.0        65.789474  -1.566016          238.0      255.0
# 3            38.0        60.526318   9.570826          199.0      275.0
# 4            18.0        61.111111  -6.421302           98.0      139.0
# 5            25.0        60.000004  -8.056826          136.0      155.0
# 6            40.0        47.500000 -21.050173          286.0      349.0
# 7            15.0        66.666672   7.578177           81.0      106.0
# 8            41.0        65.853661   5.150160          332.0      381.0
# 9            30.0        56.666668  -9.009798          157.0      280.0
# 10           34.0        52.941177  -5.496474          298.0      337.0
# 11           32.0        65.625000   5.779248          179.0      287.0
# 12           32.0        78.125000  10.885772          264.0      174.0
# 13           27.0        66.666672   3.637020          168.0      266.0
# 14           39.0        56.410259  -4.329360          217.0      242.0
# 15           28.0        53.571426  -5.709913          170.0      269.0
# 16           42.0        57.142860  -5.655921          373.0      520.0
# 17           31.0        67.741936   7.146264          270.0      276.0
# 18           24.0        45.833336 -14.186452          135.0      208.0
# 19           28.0        57.142860   1.279265          189.0      182.0
#
#     yards_after_catch  pass_touchdowns  interceptions  qb_hits  sacks  \
# 0                28.0              0.0            0.0      7.0    7.0
# 1                92.0              1.0            2.0      5.0    5.0
# 2               110.0              0.0            2.0      5.0    5.0
# 3                68.0              1.0            1.0     10.0    4.0
# 4                51.0              0.0            1.0      3.0    3.0
# 5                52.0              0.0            1.0      1.0    2.0
# 6               138.0              0.0            2.0      7.0    4.0
# 7                25.0              1.0            0.0      6.0    3.0
# 8               159.0              2.0            0.0      4.0    2.0
# 9                31.0              0.0            2.0      2.0    1.0
# 10              127.0              1.0            2.0      2.0    2.0
# 11               55.0              2.0            1.0      6.0    2.0
# 12              122.0              1.0            0.0      1.0    0.0
# 13               64.0              2.0            2.0      5.0    1.0
# 14               92.0              3.0            0.0      2.0    1.0
# 15               38.0              2.0            2.0      3.0    0.0
# 16              105.0              1.0            3.0      5.0    2.0
# 17              101.0              1.0            0.0      4.0    2.0
# 18               47.0              1.0            0.0      4.0    3.0
# 19               85.0              1.0            0.0      5.0    1.0
#
#      pass_epa  pass_wpa  posteam_score  score_diff  perc_pass_plays_team  \
# 0  -14.423655 -0.297193              0         -27             58.333333
# 1   -4.240446 -0.253677             14          -7             57.377049
# 2  -13.496357 -0.533272             14          -9             63.380282
# 3   -4.567255 -0.244908             10         -17             72.881356
# 4  -10.286832 -0.324430              0         -20             71.186441
# 5  -15.385003 -0.170220              3         -20             56.000000
# 6  -19.332096 -0.342203             16         -11             63.013699
# 7   -0.750068 -0.121717             27          10             50.000000
# 8    5.175748 -0.364772             22          -2             69.841270
# 9  -14.643071 -0.503239              8          -5             62.264151
# 10  -6.969269 -0.054527             23           3             54.285714
# 11   2.328545  0.001965             30          10             53.030303
# 12  11.129445  0.290658             27          10             52.459016
# 13   3.007902  0.130324             34          22             52.631579
# 14   8.303564  0.245881             24           7             57.971014
# 15  -4.317732 -0.228061             17          -7             53.571429
# 16  -2.509478 -0.355275             24          -7             61.538462
# 17   9.307575  0.224747             23           3             51.562500
# 18  -0.881268 -0.032617              7         -28             60.000000
# 19  -4.054164 -0.079263             19          -1             50.000000
#
#     pass_oe_team  total_giveaways_team  turnover_diff_team  \
# 0      -5.715371                   1.0                -1.0
# 1      -0.375330                   2.0                -1.0
# 2       1.553281                   5.0                -3.0
# 3       5.256178                   2.0                 2.0
# 4       2.452526                   5.0                -5.0
# 5      -8.860193                   3.0                -3.0
# 6      -7.521410                   4.0                -3.0
# 7      -4.517600                   0.0                 1.0
# 8      10.298472                   0.0                 2.0
# 9       5.951734                   3.0                -2.0
# 10     -2.343555                   2.0                -2.0
# 11    -11.935055                   2.0                -2.0
# 12     -3.142624                   0.0                 3.0
# 13      0.156886                   2.0                 0.0
# 14      2.987655                   0.0                 1.0
# 15     -5.405236                   2.0                -1.0
# 16     -1.419894                   3.0                -2.0
# 17      0.062803                   1.0                -0.0
# 18     -2.524716                   2.0                -2.0
# 19     -0.883148                   2.0                 2.0
#
#     total_penalties_team  penalty_yards_team
# 0                    7.0                54.0
# 1                    8.0                56.0
# 2                    7.0                60.0
# 3                    6.0                38.0
# 4                    9.0                75.0
# 5                    6.0                32.0
# 6                    5.0                22.0
# 7                    3.0                22.0
# 8                    7.0                69.0
# 9                    6.0                40.0
# 10                   3.0                15.0
# 11                   4.0                33.0
# 12                  11.0               111.0
# 13                   7.0                65.0
# 14                   9.0                87.0
# 15                   4.0                35.0
# 16                   6.0                43.0
# 17                   5.0                35.0
# 18                  10.0               109.0
# 19                   3.0                27.0
# Shape of sorted pass defense DataFrame:  (8754, 26)
#    defteam  season  week  matchup defteam_home posteam  pass_attempts  \
# 0      ARI    2006     1   ARI-SF            1      SF           38.0
# 1      ARI    2006     2  SEA-ARI            0     SEA           25.0
# 2      ARI    2006     3   ARI-LA            1      LA           31.0
# 3      ARI    2006     4  ATL-ARI            0     ATL           21.0
# 4      ARI    2006     5   ARI-KC            1      KC           38.0
# 5      ARI    2006     6  ARI-CHI            1     CHI           33.0
# 6      ARI    2006     7   LV-ARI            0      LV           29.0
# 7      ARI    2006     8   GB-ARI            0      GB           25.0
# 8      ARI    2006    10  ARI-DAL            1     DAL           29.0
# 9      ARI    2006    11  ARI-DET            1     DET           37.0
# 10     ARI    2006    12  MIN-ARI            0     MIN           41.0
# 11     ARI    2006    13   LA-ARI            0      LA           41.0
# 12     ARI    2006    14  ARI-SEA            1     SEA           28.0
# 13     ARI    2006    15  ARI-DEN            1     DEN           30.0
# 14     ARI    2006    16   SF-ARI            0      SF           28.0
# 15     ARI    2006    17  LAC-ARI            0     LAC           23.0
# 16     ARI    2007     1   SF-ARI            0      SF           31.0
# 17     ARI    2007     2  ARI-SEA            1     SEA           36.0
# 18     ARI    2007     3  BAL-ARI            0     BAL           37.0
# 19     ARI    2007     4  ARI-PIT            1     PIT           30.0
#
#     completion_perc       cpoe  passing_yards  air_yards  yards_after_catch  \
# 0         60.526318  -0.583447          288.0      271.0              177.0
# 1         48.000000 -10.021508          221.0      343.0               86.0
# 2         67.741936   5.223290          309.0      249.0              147.0
# 3         61.904762  -0.234863          153.0      186.0               49.0
# 4         68.421051  -0.553475          288.0      208.0              191.0
# 5         42.424244 -18.370857          148.0      410.0               75.0
# 6         58.620689   1.167010          263.0      300.0               77.0
# 7         68.000000   1.358536          180.0      112.0              117.0
# 8         68.965515  11.436465          308.0      321.0              117.0
# 9         62.162163  -2.847840          248.0      315.0               54.0
# 10        65.853661   9.504767          271.0      307.0              128.0
# 11        65.853661   0.078178          314.0      447.0               89.0
# 12        71.428574   7.561702          243.0      216.0               96.0
# 13        70.000000   7.683289          261.0      360.0               74.0
# 14        64.285713   1.888780          190.0      213.0               56.0
# 15        82.608696  16.498730          231.0      248.0              102.0
# 16        48.387096 -17.104227          126.0      231.0               50.0
# 17        61.111111  -2.942063          281.0      285.0              149.0
# 18        75.675674  13.037093          281.0      210.0              122.0
# 19        56.666668  -7.045212          244.0      388.0               96.0
#
#     pass_touchdowns  interceptions  qb_hits  sacks   pass_epa  pass_wpa  \
# 0               1.0            0.0      6.0    1.0   2.853351 -0.021138
# 1               1.0            2.0      6.0    3.0   1.174003  0.065569
# 2               1.0            0.0      0.0    1.0   8.706834  0.496920
# 3               0.0            1.0      2.0    2.0 -15.389883 -0.332261
# 4               2.0            0.0      3.0    3.0   8.076513  0.319881
# 5               0.0            4.0      5.0    2.0 -32.452568 -0.412169
# 6               1.0            1.0      4.0    5.0   1.192437  0.151794
# 7               1.0            0.0      1.0    0.0   8.095279  0.167951
# 8               2.0            0.0      3.0    0.0  20.669048  0.433412
# 9               0.0            1.0      7.0    4.0  -1.024636 -0.293467
# 10              3.0            0.0      5.0    2.0  11.532678  0.299674
# 11              2.0            3.0      5.0    4.0  -8.074299 -0.094582
# 12              3.0            0.0      3.0    3.0  -0.763963 -0.207599
# 13              2.0            1.0      2.0    1.0  14.853359  0.277686
# 14              0.0            1.0      8.0    4.0  -8.550560 -0.232951
# 15              2.0            1.0      2.0    2.0   9.303619  0.286057
# 16              0.0            0.0      3.0    3.0 -13.260427 -0.427647
# 17              1.0            0.0      2.0    1.0  11.936662  0.238169
# 18              1.0            0.0      4.0    4.0   7.773803  0.404572
# 19              2.0            2.0      3.0    4.0  -1.455941 -0.184072
#
#     points_allowed  score_diff  perc_pass_plays_team  pass_oe_team  \
# 0               27           7             68.421053      2.372149
# 1               21         -11             46.153846     -3.128842
# 2               16          -2             54.237288      2.576007
# 3               32         -22             39.344262    -16.590187
# 4               23          -3             66.129032     -1.555548
# 5               24          -1             75.000000      1.147261
# 6               22         -13             51.948052      3.977976
# 7               31         -17             40.322581      0.469331
# 8               27         -17             45.312500     -3.549721
# 9               10           7             67.741935      0.017752
# 10              31          -5             56.578947      3.203822
# 11              20          14             67.605634      1.024742
# 12              21           6             52.542373    -11.874004
# 13              37         -17             45.714286      1.349988
# 14              20           6             73.333333      1.833884
# 15              27          -7             46.774194     -3.981110
# 16              20          -3             61.818182      1.288017
# 17              20           3             60.655738     -0.371839
# 18              26          -3             58.571429      1.600273
# 19              14           7             58.064516     -6.369128
#
#     total_giveaways_team  turnover_diff_team  total_penalties_team  \
# 0                    2.0                 1.0                  11.0
# 1                    2.0                -0.0                  11.0
# 2                    2.0                -2.0                   5.0
# 3                    1.0                -3.0                   4.0
# 4                    2.0                 1.0                   7.0
# 5                    6.0                 4.0                   9.0
# 6                    5.0                 3.0                   4.0
# 7                    0.0                -1.0                   9.0
# 8                    0.0                -3.0                   5.0
# 9                    1.0                 1.0                   4.0
# 10                   1.0                -4.0                   8.0
# 11                   3.0                 3.0                  11.0
# 12                   3.0                 2.0                   9.0
# 13                   2.0                 0.0                   6.0
# 14                   2.0                 1.0                   5.0
# 15                   1.0                -0.0                   9.0
# 16                   1.0                -1.0                  10.0
# 17                   1.0                -0.0                   7.0
# 18                   1.0                -0.0                   6.0
# 19                   2.0                 0.0                   5.0
#
#     penalty_yards_team
# 0                 85.0
# 1                 66.0
# 2                 52.0
# 3                 19.0
# 4                 50.0
# 5                 65.0
# 6                 25.0
# 7                 68.0
# 8                 35.0
# 9                 34.0
# 10                64.0
# 11               107.0
# 12                77.0
# 13                52.0
# 14                45.0
# 15                93.0
# 16                71.0
# 17                55.0
# 18                65.0
# 19                30.0

# %%
# #%%timeit
# N = 10
# alpha = 2. / (N+1.)
# cols_for_MAs = [colname for colname in sorted_passer_df.columns if colname not in ['matchup', 'posteam', 'posteam_home', 'defteam']]
# dalton = sorted_passer_df[sorted_passer_df['player_name'] == 'A.Dalton']
# dalton = dalton[cols_for_MAs].set_index(['player_name', 'season', 'week'])

# for win_num, window in enumerate(dalton.rolling(window=N, closed='left')):
#     if win_num == 0:
#         row1 = dalton.index[0]
#         ewma_dalton = pd.DataFrame(np.full(shape=(1, dalton.shape[1]), fill_value=np.nan), columns=dalton.columns, index=pd.MultiIndex.from_arrays([[row1[0]], [row1[1]], [row1[2]]], names=dalton.index.names))
#         #print('Window: ', win_num+1)
#         #print('Window length: ', len(window))
#         #display(window)
#     else:
#         ewma = pd.DataFrame(window.ewm(alpha=alpha, min_periods=len(window)).mean().iloc[-1]).T
#         current_row = dalton.index[win_num]
#         ewma.index = pd.MultiIndex.from_arrays([[current_row[0]], [current_row[1]], [current_row[2]]], names=dalton.index.names)
#         ewma_dalton = pd.concat([ewma_dalton, ewma])

# %%
# #%%timeit  ## This version is ~2x as fast as the code block above
# N = 10
# alpha = 2. / (N+1.)
# cols_for_MAs = [colname for colname in sorted_passer_df.columns if colname not in ['matchup', 'posteam', 'posteam_home', 'defteam']]
# dalton = sorted_passer_df[sorted_passer_df['player_name'] == 'A.Dalton']
# dalton = dalton[cols_for_MAs].set_index(['player_name', 'season', 'week'])

# def ewma(x):
#     weights = [(1-alpha)**i for i in range(len(x)-1, -1, -1)]
#     avg = np.average(x.values, weights=weights)
#     return avg

# ewma_cust = dalton.rolling(window=N, min_periods=1, closed='left').apply(ewma)

# %%
# display(ewma_dalton.round(5))
# display(ewma_cust.round(5))

# ewma_dalton.round(5).equals(ewma_cust.round(5))

# %%
## Creating widgets to allow the user to specify what weighting scheme they want to use in the moving averages
## (currently only EWMA is supported),
## the smoothing factor (alpha) if the exponential weighting scheme is chosen,
## and the number of games to average over.
sns.set_style({"xtick.direction": "in","ytick.direction": "in"})

weighting = ToggleButtons(
    value='Exponential',
    options=['Unweighted', 'Linear', 'Exponential'],
    description='Weighting for moving average:',
    style={'description_width': 'initial'},
    tooltips=['Elements for moving average are not weighted',
              'Elements for moving average are linearly weighted',
              'Elements for moving average are exponentially weighted (EWMA)'
             ]
)

smoothing_factor = BoundedFloatText(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description='Smoothing factor (EWMA only):',
    style={'description_width': 'initial'},
    layout=Layout(width='325px')
)

games_to_avg = IntText(
    value=10,
    step=1,
    description='Previous # games to average:',
    style={'description_width': 'initial'},
    layout=Layout(width='325px')
)


def calculate_moving_averages(weighting, alpha, N):
    def calc_ewma(group, alpha, N):
        def ewma(window): ## The first value in the window is the oldest, and the last value is the most recent
            weights = [(1.-alpha)**i for i in range(len(window)-1, -1, -1)] ## Range(start, end (not included), step)
            weighted_avg = np.average(window.values, weights=weights)
            return weighted_avg
        
        ## "closed='left'" includes the left interval endpoint, but leaves the right interval endpoint open
        ## This includes the data from the previous N games, but not the current game I am trying to predict for
        ewma_group = group.rolling(window=N, min_periods=1, closed='left').apply(ewma)
        ewma_group.columns = [colname+'_ewma' for colname in ewma_group.columns]
        
        return ewma_group
    
    
    ## Calculate the moving averages for the passer DataFrame
    cols_for_MAs_passer = [colname for colname in sorted_passer_df.columns if colname not in 
                           ['matchup', 'posteam', 'posteam_home', 'defteam']
                          ]
    
    ## Calculate the moving averages for the pass defense DataFrame
    cols_for_MAs_passD = [colname for colname in sorted_passD_df.columns if colname not in
                          ['matchup', 'posteam', 'defteam_home']
                         ]
    
    if weighting == 'Exponential':
        if alpha == 0: ## Alpha=0 signifies to use the default alpha = 2/(N+1)
            alpha = 2. / (N+1.) ## Equivalent to using 'span=N' in the pd.df.ewm call
                                ## Span corresponds to what is commonly called an "N-day EW moving average"
                
        ## Plotting the weights used for each of the N games    
        fig, ax = plt.subplots(figsize=(8,6))
        weights = [(1.-alpha)**i for i in range(N)]
        ax.plot(range(N), weights, linewidth=2, color='black')
        ax.scatter(range(N), weights, s=20, c='black')
        ax.set_xticks(range(N))
        ax.minorticks_on()
        ax.tick_params(which='major', left=True, right=True, top=True, bottom=True)
        ax.tick_params(which='minor', left=True, right=True, top=False, bottom=False)
        ax.set_xlabel('Game (Game 0 is most recent)', fontsize=12)
        ax.set_ylabel(r'Weight $(1-\alpha)^{game}$', fontsize=12)
        ax.set_title(r'Weights Used in the EWMA Calculations ($N$={}, $\alpha$={})'.format(N, round(alpha, 2)), fontsize=15)
        fig.savefig('EWMA_weights_for_{}_games_with_alpha_{}.pdf'.format(N, round(alpha,2)))
        plt.show()
        
        
        passer_ma_df = (sorted_passer_df[cols_for_MAs_passer]
                        .set_index(['player_name', 'season', 'week'])                     
                        .groupby(level=0, sort=False, as_index=False)
                        .apply(lambda x: calc_ewma(x, alpha, N))
                        .droplevel(0)
                       )
        
        passD_ma_df = (sorted_passD_df[cols_for_MAs_passD]
                       .set_index(['defteam', 'season', 'week'])
                       .groupby(level=0, sort=False, as_index=False)
                       .apply(lambda x: calc_ewma(x, alpha, N))
                       .droplevel(0)
                      )
    
    passer_ma_df.reset_index(inplace=True)
    passD_ma_df.reset_index(inplace=True)
        
    display(passer_ma_df)
    display(passD_ma_df)
    
    print('Moving averages calculated!')
    
    return passer_ma_df, passD_ma_df



calc_MAs = interactive(calculate_moving_averages, {'manual': True}, weighting=weighting, alpha=smoothing_factor, N=games_to_avg)

display(calc_MAs)
# Out:
# interactive(children=(ToggleButtons(description='Weighting for moving average:', index=2, options=('Unweighted…

# %%
passer_ma_df, passD_ma_df = calc_MAs.result  ## Returning the resultant DataFrames from the interactive widget instance

sorted_passer_df = sorted_passer_df[['player_name', 'season', 'week', 'posteam', 'defteam', 'passing_yards', 'posteam_home']]
sorted_passD_df  = sorted_passD_df[['defteam', 'season', 'week', 'posteam', 'defteam_home']]

final_passer_df  = pd.merge(sorted_passer_df, passer_ma_df, how='inner', on=['player_name', 'season', 'week'])
final_passD_df   = pd.merge(sorted_passD_df, passD_ma_df, how='inner', on=['defteam', 'season', 'week'])

del(sorted_passer_df)
del(sorted_passD_df)
del(passer_ma_df)
del(passD_ma_df)

display(final_passer_df)
display(final_passD_df)
# Out:
#      player_name  season  week posteam defteam  passing_yards posteam_home  \
# 0       A.Brooks    2006     1      LV     LAC           68.0            1
# 1       A.Brooks    2006    12      LV     LAC          187.0            0
# 2       A.Brooks    2006    13      LV     HOU          238.0            1
# 3       A.Brooks    2006    14      LV     CIN          199.0            0
# 4       A.Brooks    2006    15      LV      LA           98.0            1
# ...          ...     ...   ...     ...     ...            ...          ...
# 9267    Z.Wilson    2022     8     NYJ      NE          355.0            1
# 9268    Z.Wilson    2022     9     NYJ     BUF          154.0            1
# 9269    Z.Wilson    2022    11     NYJ      NE           77.0            0
# 9270    Z.Wilson    2022    15     NYJ     DET          317.0            1
# 9271    Z.Wilson    2022    16     NYJ     JAX           92.0            1
#
#       pass_attempts_ewma  completion_perc_ewma  cpoe_ewma  passing_yards_ewma  \
# 0                    NaN                   NaN        NaN                 NaN
# 1              14.000000             42.857143 -15.923791           68.000000
# 2              21.700000             52.678572  -8.306629          133.450000
# 3              28.252492             57.949068  -5.596948          175.478405
# 4              31.463861             58.798157  -0.599842          183.227723
# ...                  ...                   ...        ...                 ...
# 9267           25.430060             56.705991  -8.551058          160.567914
# 9268           27.771979             55.647306  -7.973250          199.561903
# 9269           26.787937             59.376225  -4.940605          189.922497
# 9270           25.889165             55.577695  -8.374699          166.765002
# 9271           27.702718             54.796318  -7.268452          200.151622
#
#       air_yards_ewma  yards_after_catch_ewma  pass_touchdowns_ewma  \
# 0                NaN                     NaN                   NaN
# 1         144.000000               28.000000              0.000000
# 2         214.400000               63.200000              0.550000
# 3         230.720930               82.013289              0.328904
# 4         245.308911               77.396535              0.550000
# ...              ...                     ...                   ...
# 9267      176.303235               91.279318              0.418237
# 9268      219.334974              112.130130              0.705831
# 9269      204.452290              106.729724              0.787554
# 9270      204.863930               89.218861              0.644362
# 9271      267.901484               83.320258              0.919080
#
#       interceptions_ewma  qb_hits_ewma  sacks_ewma  pass_epa_ewma  \
# 0                    NaN           NaN         NaN            NaN
# 1               0.000000      7.000000    7.000000     -14.423655
# 2               1.100000      5.900000    5.900000      -8.822890
# 3               1.461794      5.538206    5.538206     -10.701593
# 4               1.309653      7.008168    5.031436      -8.680602
# ...                  ...           ...         ...            ...
# 9267            0.264612      4.193498    2.768174      -4.860343
# 9268            0.818431      3.738204    2.628506      -4.491585
# 9269            0.669626      3.575747    2.485994      -3.614662
# 9270            0.547876      3.806464    2.704792      -5.232806
# 9271            0.658318      5.158466    3.024998      -4.107689
#
#       pass_wpa_ewma  posteam_score_ewma  score_diff_ewma  \
# 0               NaN                 NaN              NaN
# 1         -0.297193            0.000000       -27.000000
# 2         -0.273259            7.700000       -16.000000
# 3         -0.377783           10.232558       -13.186047
# 4         -0.334007           10.155941       -14.442574
# ...             ...                 ...              ...
# 9267      -0.103169           23.053369         4.728791
# 9268      -0.097595           21.924519         3.242299
# 9269      -0.083840           21.885224         3.875957
# 9270      -0.161083           17.858549         1.898510
# 9271      -0.106215           17.448308         0.781968
#
#       perc_pass_plays_team_ewma  pass_oe_team_ewma  total_giveaways_team_ewma  \
# 0                           NaN                NaN                        NaN
# 1                     58.333333          -5.715371                   1.000000
# 2                     57.807377          -2.778348                   1.550000
# 3                     60.047648          -1.037062                   2.936877
# 4                     64.275783           1.036280                   2.628218
# ...                         ...                ...                        ...
# 9267                  52.362877          -3.808615                   0.393185
# 9268                  56.398484          -3.042965                   0.923628
# 9269                  53.547211          -3.988218                   0.965752
# 9270                  53.388415          -5.462814                   0.761922
# 9271                  56.010448          -4.530804                   0.833447
#
#       turnover_diff_team_ewma  total_penalties_team_ewma  \
# 0                         NaN                        NaN
# 1                   -1.000000                   7.000000
# 2                   -1.000000                   7.550000
# 3                   -1.803987                   7.328904
# 4                   -0.550743                   6.891089
# ...                       ...                        ...
# 9267                 1.024865                   6.566410
# 9268                 0.446652                   6.043314
# 9269                 0.575499                   5.433508
# 9270                 0.414386                   4.991052
# 9271                 0.100749                   4.306035
#
#       penalty_yards_team_ewma
# 0                         NaN
# 1                   54.000000
# 2                   55.100000
# 3                   57.069767
# 4                   50.787129
# ...                       ...
# 9267                68.109683
# 9268                62.474700
# 9269                56.146639
# 9270                48.185386
# 9271                41.338254
#
# [9272 rows x 27 columns]
#      defteam  season  week posteam defteam_home  pass_attempts_ewma  \
# 0        ARI    2006     1      SF            1                 NaN
# 1        ARI    2006     2     SEA            0           38.000000
# 2        ARI    2006     3      LA            1           30.850000
# 3        ARI    2006     4     ATL            0           30.910299
# 4        ARI    2006     5      KC            1           27.645297
# ...      ...     ...   ...     ...          ...                 ...
# 8749     WAS    2022    13     NYG            0           28.429219
# 8750     WAS    2022    15     NYG            1           28.363569
# 8751     WAS    2022    16      SF            0           29.165929
# 8752     WAS    2022    17     CLE            1           27.568262
# 8753     WAS    2022    18     DAL            1           25.602674
#
#       completion_perc_ewma  cpoe_ewma  passing_yards_ewma  air_yards_ewma  \
# 0                      NaN        NaN                 NaN             NaN
# 1                60.526318  -0.583447          288.000000      271.000000
# 2                53.636843  -5.774381          251.150000      310.600000
# 3                59.306997  -1.353390          274.405316      285.837209
# 4                60.162845  -0.984885          234.407673      252.945297
# ...                    ...        ...                 ...             ...
# 8749             62.880792  -2.587117          196.997923      231.827388
# 8750             67.781251   1.059893          193.590438      217.775216
# 8751             67.673546   0.494476          185.704093      197.735408
# 8752             68.678998   0.722790          195.981780      193.616105
# 8753             65.174209  -0.865428          190.483004      174.481183
#
#       yards_after_catch_ewma  pass_touchdowns_ewma  interceptions_ewma  \
# 0                        NaN                   NaN                 NaN
# 1                 177.000000              1.000000            0.000000
# 2                 126.950000              1.000000            1.100000
# 3                 135.009967              1.000000            0.657807
# 4                 106.673515              0.670545            0.770545
# ...                      ...                   ...                 ...
# 8749               89.188499              1.177896            0.872464
# 8750               93.551577              1.089075            0.713834
# 8751               91.366576              0.834585            0.584046
# 8752               94.748996              1.074717            0.687912
# 8753               98.065342              1.481244            0.534599
#
#       qb_hits_ewma  sacks_ewma  pass_epa_ewma  pass_wpa_ewma  \
# 0              NaN         NaN            NaN            NaN
# 1         6.000000    1.000000       2.853351      -0.021138
# 2         6.000000    2.100000       1.929710       0.026551
# 3         3.588040    1.657807       4.654069       0.215636
# 4         3.064851    1.770545      -1.949520       0.035128
# ...            ...         ...            ...            ...
# 8749      6.279751    2.346928      -5.958377      -0.241265
# 8750      5.808775    2.675724      -5.787377      -0.202027
# 8751      5.479907    2.160991      -4.540531      -0.161166
# 8752      4.774873    2.257062      -2.285550      -0.095744
# 8753      4.618139    2.755778       0.198640      -0.018619
#
#       points_allowed_ewma  score_diff_ewma  perc_pass_plays_team_ewma  \
# 0                     NaN              NaN                        NaN
# 1               27.000000         7.000000                  68.421053
# 2               23.700000        -2.900000                  56.174089
# 3               20.604651        -2.538206                  55.395508
# 4               24.358911        -8.950000                  50.107338
# ...                   ...              ...                        ...
# 8749            16.233418         3.868256                  57.550168
# 8750            16.805299         3.616745                  56.641086
# 8751            17.244964         1.702275                  56.348455
# 8752            21.288596        -2.065232                  55.033798
# 8753            22.261624        -4.771712                  53.380649
#
#       pass_oe_team_ewma  total_giveaways_team_ewma  turnover_diff_team_ewma  \
# 0                   NaN                        NaN                      NaN
# 1              2.372149                   2.000000                 1.000000
# 2             -0.653396                   2.000000                 0.450000
# 3              0.644803                   2.000000                -0.534884
# 4             -5.033359                   1.670545                -1.347030
# ...                 ...                        ...                      ...
# 8749          -4.819349                   1.622605                 0.674684
# 8750          -5.584021                   1.537642                 0.580252
# 8751          -3.608535                   1.258071                 0.111116
# 8752          -2.742251                   1.239387                -0.090905
# 8753          -2.699484                   0.957568                -0.761022
#
#       total_penalties_team_ewma  penalty_yards_team_ewma
# 0                           NaN                      NaN
# 1                     11.000000                85.000000
# 2                     11.000000                74.550000
# 3                      8.588040                65.485050
# 4                      7.076485                50.170297
# ...                         ...                      ...
# 8749                   5.076452                45.591917
# 8750                   5.510902                47.500143
# 8751                   5.458639                43.425634
# 8752                   5.472354                44.238032
# 8753                   5.329996                40.219534
#
# [8754 rows x 25 columns]

# %% [markdown]
# ### Merging the passer and pass defense DataFrames<br>
#
# Aside from a few unique column names that should obviously correspond to the passer or pass defense,<br>
# duplicate column names in the merge will have **\_passer** appended to the column names of the passer's (or their full team's) stats <br>
# and **\_defense** appended to the column names of the pass defense's (or their full team's) stats.

# %%
final_merged_df = pd.merge(final_passer_df, final_passD_df.drop(columns='posteam'),
                           how='inner',
                           on=['season', 'week', 'defteam'],
                           suffixes=['_passer', '_defense']
                          )

final_merged_df = final_merged_df.sort_values(['player_name', 'season', 'week'], ascending=True, ignore_index=True)

# del(final_passer_df)
# del(final_passD_df)

print(final_merged_df.shape)
final_merged_df.head(20)
# Out:
# (9272, 48)
#    player_name  season  week posteam defteam  passing_yards posteam_home  \
# 0     A.Brooks    2006     1      LV     LAC           68.0            1
# 1     A.Brooks    2006    12      LV     LAC          187.0            0
# 2     A.Brooks    2006    13      LV     HOU          238.0            1
# 3     A.Brooks    2006    14      LV     CIN          199.0            0
# 4     A.Brooks    2006    15      LV      LA           98.0            1
# 5     A.Brooks    2006    17      LV     NYJ          136.0            0
# 6      A.Brown    2022    18     BAL     CIN          286.0            0
# 7     A.Dalton    2011     1     CIN     CLE           81.0            0
# 8     A.Dalton    2011     2     CIN     DEN          332.0            0
# 9     A.Dalton    2011     3     CIN      SF          157.0            1
# 10    A.Dalton    2011     4     CIN     BUF          298.0            1
# 11    A.Dalton    2011     5     CIN     JAX          179.0            0
# 12    A.Dalton    2011     6     CIN     IND          264.0            1
# 13    A.Dalton    2011     8     CIN     SEA          168.0            0
# 14    A.Dalton    2011     9     CIN     TEN          217.0            0
# 15    A.Dalton    2011    10     CIN     PIT          170.0            1
# 16    A.Dalton    2011    11     CIN     BAL          373.0            0
# 17    A.Dalton    2011    12     CIN     CLE          270.0            1
# 18    A.Dalton    2011    13     CIN     PIT          135.0            0
# 19    A.Dalton    2011    14     CIN     HOU          189.0            1
#
#     pass_attempts_ewma_passer  completion_perc_ewma_passer  cpoe_ewma_passer  \
# 0                         NaN                          NaN               NaN
# 1                   14.000000                    42.857143        -15.923791
# 2                   21.700000                    52.678572         -8.306629
# 3                   28.252492                    57.949068         -5.596948
# 4                   31.463861                    58.798157         -0.599842
# 5                   27.598753                    59.462143         -2.271025
# 6                         NaN                          NaN               NaN
# 7                         NaN                          NaN               NaN
# 8                   15.000000                    66.666672          7.578177
# 9                   29.300000                    66.219516          6.242768
# 10                  29.581395                    62.379334          0.111338
# 11                  31.037129                    59.269882         -1.736186
# 12                  31.313543                    61.094264          0.421290
# 13                  31.491839                    65.517734          3.139278
# 14                  30.409487                    65.794582          3.259213
# 15                  32.363870                    63.659603          1.532776
# 16                  31.414444                    61.464769         -0.042979
# 17                  33.638006                    60.556925         -1.222012
# 18                  33.610176                    61.893654          0.287296
# 19                  31.382826                    58.408263         -2.890321
#
#     passing_yards_ewma_passer  air_yards_ewma_passer  \
# 0                         NaN                    NaN
# 1                   68.000000             144.000000
# 2                  133.450000             214.400000
# 3                  175.478405             230.720930
# 4                  183.227723             245.308911
# 5                  158.761162             214.790514
# 6                         NaN                    NaN
# 7                         NaN                    NaN
# 8                   81.000000             106.000000
# 9                  219.050000             257.250000
# 10                 194.106312             266.395349
# 11                 228.334653             289.656436
# 12                 214.172016             288.893845
# 13                 227.114065             259.051945
# 14                 212.869950             260.726147
# 15                 213.809556             256.465858
# 16                 204.278130             259.192849
# 17                 239.719199             313.976999
# 18                 250.561778             311.872547
# 19                 223.987663             288.101458
#
#     yards_after_catch_ewma_passer  pass_touchdowns_ewma_passer  \
# 0                             NaN                          NaN
# 1                       28.000000                     0.000000
# 2                       63.200000                     0.550000
# 3                       82.013289                     0.328904
# 4                       77.396535                     0.550000
# 5                       69.818807                     0.392110
# 6                             NaN                          NaN
# 7                             NaN                          NaN
# 8                       25.000000                     1.000000
# 9                       98.700000                     1.550000
# 10                      71.485050                     0.926910
# 11                      89.774752                     0.950990
# 12                      79.791867                     1.252132
# 13                      90.754777                     1.186645
# 14                      84.307950                     1.382631
# 15                      86.057929                     1.750590
# 16                      75.602205                     1.804853
# 17                      81.777393                     1.635789
# 18                      87.418499                     1.520191
# 19                      76.907027                     1.397373
#
#     interceptions_ewma_passer  qb_hits_ewma_passer  sacks_ewma_passer  \
# 0                         NaN                  NaN                NaN
# 1                    0.000000             7.000000           7.000000
# 2                    1.100000             5.900000           5.900000
# 3                    1.461794             5.538206           5.538206
# 4                    1.309653             7.008168           5.031436
# 5                    1.220760             5.857532           4.448266
# 6                         NaN                  NaN                NaN
# 7                         NaN                  NaN                NaN
# 8                    0.000000             6.000000           3.000000
# 9                    0.000000             4.900000           2.450000
# 10                   0.803987             3.734219           1.867110
# 11                   1.198020             3.162871           1.910891
# 12                   1.141174             3.977334           1.936472
# 13                   0.844771             3.204017           1.433503
# 14                   1.123135             3.636777           1.329046
# 15                   0.867616             3.264402           1.254187
# 16                   1.113984             3.206878           0.981320
# 17                   1.510153             3.583534           1.195300
# 18                   1.235580             3.602779           1.313371
# 19                   1.010929             3.675001           1.648269
#
#     pass_epa_ewma_passer  pass_wpa_ewma_passer  posteam_score_ewma  \
# 0                    NaN                   NaN                 NaN
# 1             -14.423655             -0.297193            0.000000
# 2              -8.822890             -0.273259            7.700000
# 3             -10.701593             -0.377783           10.232558
# 4              -8.680602             -0.334007           10.155941
# 5              -9.141707             -0.331257            7.240446
# 6                    NaN                   NaN                 NaN
# 7                    NaN                   NaN                 NaN
# 8              -0.750068             -0.121717           27.000000
# 9               2.509131             -0.255397           24.250000
# 10             -4.385940             -0.355028           17.717608
# 11             -5.237032             -0.256026           19.457921
# 12             -3.065161             -0.181964           22.484265
# 13              0.621669             -0.059208           23.657157
# 14              1.196655             -0.013538           26.149367
# 15              2.813511              0.045481           25.660376
# 16              1.262002             -0.014032           23.776181
# 17              0.469780             -0.085712           23.823196
# 18              2.360659             -0.019482           23.560572
# 19              1.600180             -0.012491           20.125989
#
#     score_diff_ewma_passer  perc_pass_plays_team_ewma_passer  \
# 0                      NaN                               NaN
# 1               -27.000000                         58.333333
# 2               -16.000000                         57.807377
# 3               -13.186047                         60.047648
# 4               -14.442574                         64.275783
# 5               -16.037960                         66.259645
# 6                      NaN                               NaN
# 7                      NaN                               NaN
# 8                10.000000                         50.000000
# 9                 3.400000                         60.912698
# 10                0.023256                         61.455973
# 11                1.003960                         59.093692
# 12                3.586479                         57.353058
# 13                5.252292                         56.081907
# 14                9.287817                         55.250516
# 15                8.767327                         55.869443
# 16                5.336909                         55.369475
# 17                2.745465                         56.665309
# 18                2.594078                         55.781647
# 19               -3.702669                         56.270723
#
#     pass_oe_team_ewma_passer  total_giveaways_team_ewma_passer  \
# 0                        NaN                               NaN
# 1                  -5.715371                          1.000000
# 2                  -2.778348                          1.550000
# 3                  -1.037062                          2.936877
# 4                   1.036280                          2.628218
# 5                   1.442846                          3.309092
# 6                        NaN                               NaN
# 7                        NaN                               NaN
# 8                  -4.517600                          0.000000
# 9                   3.631240                          0.000000
# 10                  4.564063                          1.205980
# 11                  2.288311                          1.467574
# 12                 -1.794831                          1.620419
# 13                 -2.144899                          1.199540
# 14                 -1.590262                          1.392419
# 15                 -0.548763                          1.075637
# 16                 -1.605362                          1.276746
# 17                 -1.566403                          1.638726
# 18                 -1.140843                          1.550832
# 19                 -1.754557                          1.688975
#
#     turnover_diff_team_ewma_passer  total_penalties_team_ewma_passer  \
# 0                              NaN                               NaN
# 1                        -1.000000                          7.000000
# 2                        -1.000000                          7.550000
# 3                        -1.803987                          7.328904
# 4                        -0.550743                          6.891089
# 5                        -1.828003                          7.496500
# 6                              NaN                               NaN
# 7                              NaN                               NaN
# 8                         1.000000                          3.000000
# 9                         1.550000                          5.200000
# 10                        0.122924                          5.521595
# 11                       -0.576485                          4.690842
# 12                       -0.985138                          4.492520
# 13                        0.049940                          6.182737
# 14                        0.037907                          6.379665
# 15                        0.256788                          6.975804
# 16                       -0.016645                          6.328373
# 17                       -0.433261                          6.259396
# 18                       -0.382724                          6.086891
# 19                       -0.789727                          6.883079
#
#     penalty_yards_team_ewma_passer defteam_home  pass_attempts_ewma_defense  \
# 0                              NaN            0                         NaN
# 1                        54.000000            1                   33.554966
# 2                        55.100000            0                   29.731557
# 3                        57.069767            1                   35.189142
# 4                        50.787129            0                   24.398139
# 5                        57.737986            1                   32.961531
# 6                              NaN            1                   33.606104
# 7                              NaN            1                   27.281350
# 8                        22.000000            1                   30.271347
# 9                        47.850000            0                   37.444120
# 10                       44.694352            0                   30.783426
# 11                       34.911386            1                   32.536426
# 12                       34.362679            0                   33.346136
# 13                       54.268039            1                   33.652967
# 14                       56.854010            1                   37.936684
# 15                       63.712368            0                   36.090594
# 16                       57.465562            1                   30.193101
# 17                       54.426981            0                   28.142070
# 18                       51.261897            1                   32.526573
# 19                       62.889253            0                   33.421195
#
#     completion_perc_ewma_defense  cpoe_ewma_defense  \
# 0                            NaN                NaN
# 1                      60.554168           0.387882
# 2                      64.314291          -0.570190
# 3                      67.589438           5.806228
# 4                      60.094737          -1.379740
# 5                      62.796755          -0.640073
# 6                      65.122746           3.425798
# 7                      63.424158           1.127360
# 8                      59.830996          -1.981366
# 9                      64.994495           2.227986
# 10                     66.712654           3.636188
# 11                     66.847625           2.631321
# 12                     70.482977           4.915864
# 13                     66.096341           1.874171
# 14                     66.169037           3.342720
# 15                     58.993348          -1.880283
# 16                     54.912583          -5.643484
# 17                     57.757072          -4.375885
# 18                     60.951146          -1.709778
# 19                     51.910227         -10.922127
#
#     passing_yards_ewma_defense  air_yards_ewma_defense  \
# 0                          NaN                     NaN
# 1                   251.876214              305.339813
# 2                   235.250891              275.170953
# 3                   275.202154              299.853847
# 4                   189.059057              232.859267
# 5                   207.531185              276.828428
# 6                   251.791581              299.782840
# 7                   215.447601              219.240604
# 8                   233.629724              278.760551
# 9                   283.155467              298.696836
# 10                  234.002813              298.179810
# 11                  240.629976              263.964311
# 12                  268.353108              232.151105
# 13                  255.212586              290.226012
# 14                  256.271091              289.443970
# 15                  217.625399              313.433747
# 16                  215.640282              274.642812
# 17                  169.722681              236.246625
# 18                  198.825398              283.817978
# 19                  198.430925              329.069918
#
#     yards_after_catch_ewma_defense  pass_touchdowns_ewma_defense  \
# 0                              NaN                           NaN
# 1                        91.466372                      1.296915
# 2                       106.558290                      1.258135
# 3                       112.582549                      1.380993
# 4                        74.951545                      1.595847
# 5                       106.690690                      1.396846
# 6                       105.574726                      1.522667
# 7                       115.054785                      1.355554
# 8                       117.595974                      1.141249
# 9                       131.781835                      1.973909
# 10                       88.294386                      2.086218
# 11                      122.986681                      1.362566
# 12                      133.073718                      1.843107
# 13                      115.781882                      1.353260
# 14                      107.074043                      1.725825
# 15                       86.187736                      1.282275
# 16                       80.736372                      0.597878
# 17                       82.715412                      0.638720
# 18                       76.901934                      1.094293
# 19                       71.037623                      0.843522
#
#     interceptions_ewma_defense  qb_hits_ewma_defense  sacks_ewma_defense  \
# 0                          NaN                   NaN                 NaN
# 1                     0.857575              4.015568            3.199542
# 2                     0.849378              3.367137            1.689100
# 3                     1.369597              4.977447            1.863564
# 4                     0.465308              3.078397            1.564335
# 5                     0.764056              3.855904            2.700158
# 6                     0.610372              6.282379            2.035759
# 7                     0.909925              3.847578            1.648146
# 8                     0.594136              3.708391            1.569725
# 9                     1.232832              5.748859            2.690787
# 10                    1.631481              3.430920            1.046947
# 11                    0.977776              3.194805            1.337766
# 12                    0.380436              4.291506            1.781510
# 13                    1.060944              3.882379            2.292591
# 14                    1.052587              4.491859            1.588877
# 15                    0.338287              5.064941            2.785667
# 16                    0.699641              5.853212            2.700173
# 17                    0.563365              3.184872            1.507730
# 18                    1.131042              4.756221            1.954188
# 19                    1.696950              8.310678            2.957496
#
#     pass_epa_ewma_defense  pass_wpa_ewma_defense  points_allowed_ewma  \
# 0                     NaN                    NaN                  NaN
# 1               -0.432685              -0.193707            23.981025
# 2                2.481578               0.069548            21.485388
# 3                2.634717               0.102551            17.935765
# 4                5.037321               0.076052            29.386940
# 5               -5.447212              -0.111251            15.162432
# 6                1.943659               0.033633            20.305381
# 7                3.848339               0.079958            22.959711
# 8                2.739898               0.022052            29.166312
# 9               -0.240340               0.154231            21.299477
# 10               2.975008               0.129900            26.370492
# 11               3.380635               0.104464            23.254456
# 12               7.004865               0.190004            26.455946
# 13               2.277555              -0.048867            20.878589
# 14               2.976242               0.026794            22.520057
# 15               1.805326               0.095420            18.017749
# 16              -4.243673              -0.074888            18.181308
# 17              -2.606821              -0.211838            17.496715
# 18              -0.794508              -0.064140            15.677401
# 19             -10.361464              -0.185561            13.756551
#
#     score_diff_ewma_defense  perc_pass_plays_team_ewma_defense  \
# 0                       NaN                                NaN
# 1                 12.223476                          60.433595
# 2                 -5.721180                          56.508803
# 3                  6.245307                          62.193416
# 4                 -8.744495                          44.936457
# 5                  4.423467                          59.275731
# 6                  7.060581                          61.176771
# 7                 -8.436677                          46.861322
# 8                 -7.025856                          49.145926
# 9                  3.646274                          61.900149
# 10                -0.628427                          52.831780
# 11                -9.384251                          56.462486
# 12                -4.884557                          53.047065
# 13                -4.053504                          54.307326
# 14                -2.512029                          57.395039
# 15                 5.679683                          64.164537
# 16                 4.641533                          53.905522
# 17                -4.360305                          49.179184
# 18                 5.896717                          58.756898
# 19                11.092165                          65.012488
#
#     pass_oe_team_ewma_defense  total_giveaways_team_ewma_defense  \
# 0                         NaN                                NaN
# 1                   -3.413789                           1.506841
# 2                    0.511924                           1.080107
# 3                    0.248033                           1.961160
# 4                   -8.215147                           1.194721
# 5                   -4.114269                           1.117249
# 6                   -2.072847                           1.445332
# 7                   -5.274194                           1.214536
# 8                   -4.456894                           1.132572
# 9                    2.025120                           1.820183
# 10                  -4.405910                           2.415873
# 11                   2.173702                           1.029333
# 12                  -4.666418                           1.032231
# 13                   0.045244                           1.404672
# 14                   0.747436                           1.265526
# 15                   0.447741                           0.611357
# 16                  -1.268230                           1.437839
# 17                  -5.633026                           1.000116
# 18                  -4.091717                           1.523897
# 19                   1.269347                           2.015629
#
#     turnover_diff_team_ewma_defense  total_penalties_team_ewma_defense  \
# 0                               NaN                                NaN
# 1                          0.781032                           5.807103
# 2                         -0.504930                           6.381763
# 3                          0.986314                           5.349110
# 4                         -0.392951                           7.922503
# 5                         -0.502382                           3.400414
# 6                          0.211024                           5.662584
# 7                         -0.887597                           3.845699
# 8                         -0.985405                           6.927147
# 9                          1.086961                           6.142378
# 10                        -0.217141                           5.605482
# 11                        -0.440945                           4.619808
# 12                        -0.039708                           4.663540
# 13                        -0.520491                           7.765739
# 14                         0.167404                           6.939213
# 15                        -0.636087                           6.491848
# 16                        -0.581547                           6.275698
# 17                        -0.255550                           6.337119
# 18                         0.294520                           6.054837
# 19                         1.192770                           5.975021
#
#     penalty_yards_team_ewma_defense
# 0                               NaN
# 1                         51.924668
# 2                         53.799634
# 3                         45.256983
# 4                         70.936039
# 5                         25.216490
# 6                         45.390776
# 7                         33.277508
# 8                         60.173383
# 9                         51.571257
# 10                        42.143076
# 11                        39.620114
# 12                        39.587481
# 13                        58.904642
# 14                        61.921570
# 15                        56.502009
# 16                        49.177165
# 17                        53.015899
# 18                        51.580047
# 19                        49.460585

# %% [markdown]
# ### Visual Exploratory Data Analysis<br>
# #### Looking at the distributions and correlations of the various features<br>
#
# I will start by creating a feature pair plot (scatter matrix) that will plot pairwise relationships in the data.<br>
# *Unfortunately, when I add in the defensive data, this visualization likely will not be practical given the large number of features.*
# <br>
# I will also create a correlation heatmap **very similar to *Tim Bryan's* correlation heatmap.**
# <br>
# I am using the Pearson correlation coefficient here.
# <br>
# The Pearson correlation coefficient measures the strength and direction of **linear** relationships between pairs of continuous variables.<br>
# The Pearson correlation coefficient can range from $[-1, +1]$, with the sign indicating the direction and the magnitude the strength.<br>
# The strength refers to how close the relationship is to being a perfectly straight line.<br>
#  - -1: Perfectly negative linear relationship
#  -  0: No relationship
#  - +1: Perfectly positive linear relationship
# <br>
#
# The Pearson correlation coefficient (a parametric measure) assumes that each variable is approximately normally distributed.<br>
# Pearson correlation coefficient: $r_p = \frac{S_{xy}}{\sqrt(S_x\ *\ S_y)}$ where $S_{xy}$ is the covariance, and $S_x$ ($S_y$) is the variance of $x$ ($y$).
# <br>
# *A general question*:<br>
# Is it safe to assume that the EWMA values are normally distributed via the Central Limit Theorem (since this is a moving, weighted average)?
# <br>
# **I am including the target passing yards data to see which EWMA features correlate with the passing yards.<br>
# The features that correlate with the target value should be preferred in the machine learning model I would think.**

# %%
## Create feature pair plot - I will use 2D histograms instead of scatter plots to better show densities in the feature space
pairplot = sns.pairplot(final_passer_df.drop(columns=['player_name', 'posteam', 'defteam']),
                        kind='hist',
                        diag_kind='hist', ## Displays the count
                        height=2.,
                        corner=True,
                        dropna=True,
                       )

pairplot.figure.suptitle('Histogram Pair Plot of Passer and Team EWMA Features (Includes the Target Column: Passing Yards)', fontsize=30)

pairplot.savefig('player_passing_yards_feature_pairplot.pdf')
plt.show()

# %%
## Print out some summary statistics of the DataFrame
final_merged_df.dropna().describe().round(3)
# Out:
#          season     week  passing_yards  pass_attempts_ewma_passer  \
# count  9007.000  9007.00       9007.000                   9007.000
# mean   2014.081     9.22        229.685                     31.240
# std       4.895     5.02         85.129                      5.680
# min    2006.000     1.00         -7.000                      6.000
# 25%    2010.000     5.00        175.000                     27.980
# 50%    2014.000     9.00        230.000                     31.602
# 75%    2018.000    14.00        287.000                     35.001
# max    2022.000    18.00        527.000                     58.000
#
#        completion_perc_ewma_passer  cpoe_ewma_passer  \
# count                     9007.000          9007.000
# mean                        64.201             0.202
# std                          5.585             5.038
# min                         31.750           -35.749
# 25%                         60.784            -2.782
# 50%                         64.542             0.415
# 75%                         67.984             3.585
# max                        100.000            37.050
#
#        passing_yards_ewma_passer  air_yards_ewma_passer  \
# count                   9007.000               9007.000
# mean                     229.681                266.120
# std                       51.932                 55.523
# min                       17.000                 15.000
# 25%                      197.459                232.046
# 50%                      231.135                267.186
# 75%                      265.806                302.258
# max                      427.500                567.000
#
#        yards_after_catch_ewma_passer  pass_touchdowns_ewma_passer  \
# count                       9007.000                     9007.000
# mean                         103.053                        1.411
# std                           28.082                        0.613
# min                           -1.000                        0.000
# 25%                           85.024                        1.000
# 50%                          102.984                        1.378
# 75%                          122.058                        1.812
# max                          267.000                        4.005
#
#        interceptions_ewma_passer  qb_hits_ewma_passer  sacks_ewma_passer  \
# count                   9007.000             9007.000           9007.000
# mean                       0.828                4.561              2.129
# std                        0.424                1.541              0.836
# min                        0.000                0.000              0.000
# 25%                        0.542                3.518              1.547
# 50%                        0.787                4.445              2.060
# 75%                        1.059                5.481              2.650
# max                        5.000               14.000              7.000
#
#        pass_epa_ewma_passer  pass_wpa_ewma_passer  posteam_score_ewma  \
# count              9007.000              9007.000            9007.000
# mean                  0.926                 0.025              22.292
# std                   5.530                 0.147               5.541
# min                 -27.841                -0.845               0.000
# 25%                  -2.683                -0.074              18.658
# 50%                   0.762                 0.022              22.240
# 75%                   4.541                 0.121              25.924
# max                  21.026                 0.557              59.000
#
#        score_diff_ewma_passer  perc_pass_plays_team_ewma_passer  \
# count                9007.000                          9007.000
# mean                   -0.314                            58.228
# std                     8.064                             5.931
# min                   -44.000                            18.966
# 25%                    -5.372                            54.650
# 50%                    -0.174                            58.638
# 75%                     5.117                            62.327
# max                    59.000                            81.818
#
#        pass_oe_team_ewma_passer  total_giveaways_team_ewma_passer  \
# count                  9007.000                          9007.000
# mean                     -0.423                             1.523
# std                       4.910                             0.605
# min                     -35.786                             0.000
# 25%                      -3.408                             1.098
# 50%                      -0.223                             1.452
# 75%                       2.686                             1.874
# max                      22.800                             6.000
#
#        turnover_diff_team_ewma_passer  total_penalties_team_ewma_passer  \
# count                        9007.000                          9007.000
# mean                           -0.024                             6.242
# std                             0.867                             1.332
# min                            -5.000                             1.000
# 25%                            -0.538                             5.354
# 50%                             0.000                             6.193
# 75%                             0.528                             7.073
# max                             5.000                            13.000
#
#        penalty_yards_team_ewma_passer  pass_attempts_ewma_defense  \
# count                        9007.000                    9007.000
# mean                           52.449                      32.918
# std                            12.518                       3.443
# min                             5.000                      11.000
# 25%                            44.049                      30.720
# 50%                            51.937                      32.934
# 75%                            60.306                      35.176
# max                           130.000                      44.405
#
#        completion_perc_ewma_defense  cpoe_ewma_defense  \
# count                      9007.000           9007.000
# mean                         64.340              0.286
# std                           4.582              3.883
# min                          39.714            -16.337
# 25%                          61.234             -2.272
# 50%                          64.483              0.368
# 75%                          67.529              2.904
# max                          86.207             22.033
#
#        passing_yards_ewma_defense  air_yards_ewma_defense  \
# count                    9007.000                9007.000
# mean                      241.060                 279.813
# std                        32.642                  40.431
# min                        68.000                  84.000
# 25%                       219.357                 252.743
# 50%                       241.097                 278.363
# 75%                       262.935                 306.348
# max                       361.300                 436.795
#
#        yards_after_catch_ewma_defense  pass_touchdowns_ewma_defense  \
# count                        9007.000                      9007.000
# mean                          108.342                         1.474
# std                            19.579                         0.465
# min                            28.000                         0.000
# 25%                            94.970                         1.157
# 50%                           107.819                         1.457
# 75%                           121.041                         1.777
# max                           191.772                         3.553
#
#        interceptions_ewma_defense  qb_hits_ewma_defense  sacks_ewma_defense  \
# count                    9007.000              9007.000            9007.000
# mean                        0.879                 4.835               2.260
# std                         0.388                 1.272               0.688
# min                         0.000                 0.000               0.000
# 25%                         0.599                 3.953               1.780
# 50%                         0.842                 4.800               2.226
# 75%                         1.115                 5.664               2.696
# max                         3.000                13.000               7.000
#
#        pass_epa_ewma_defense  pass_wpa_ewma_defense  points_allowed_ewma  \
# count               9007.000               9007.000             9007.000
# mean                   0.737                  0.023               22.451
# std                    4.659                  0.123                4.491
# min                  -25.808                 -0.637                0.000
# 25%                   -2.275                 -0.059               19.374
# 50%                    0.921                  0.023               22.377
# 75%                    3.888                  0.105               25.519
# max                   21.886                  0.507               38.207
#
#        score_diff_ewma_defense  perc_pass_plays_team_ewma_defense  \
# count                 9007.000                           9007.000
# mean                    -0.016                             58.059
# std                      7.290                              4.802
# min                    -27.000                             18.966
# 25%                     -5.004                             55.120
# 50%                     -0.127                             58.352
# 75%                      5.110                             61.273
# max                     30.300                             75.043
#
#        pass_oe_team_ewma_defense  total_giveaways_team_ewma_defense  \
# count                   9007.000                           9007.000
# mean                      -0.493                              1.495
# std                        3.387                              0.515
# min                      -28.282                              0.000
# 25%                       -2.607                              1.128
# 50%                       -0.443                              1.453
# 75%                        1.765                              1.814
# max                       14.421                              5.000
#
#        turnover_diff_team_ewma_defense  total_penalties_team_ewma_defense  \
# count                         9007.000                           9007.000
# mean                            -0.002                              6.217
# std                              0.761                              1.231
# min                             -5.000                              1.000
# 25%                             -0.502                              5.376
# 50%                              0.004                              6.185
# 75%                              0.507                              7.040
# max                              5.000                             11.716
#
#        penalty_yards_team_ewma_defense
# count                         9007.000
# mean                            52.295
# std                             11.563
# min                              5.000
# 25%                             44.274
# 50%                             51.843
# 75%                             59.803
# max                            103.934

# %%
## Create correlation heat map
## Computing pairwise correlation of the columns (excluding NA values)
corrs = final_merged_df.drop(columns=['player_name', 'posteam', 'defteam', 'season', 'week', 'posteam_home', 'defteam_home']).corr(method='pearson')

display(corrs)

mask = np.zeros_like(corrs) ## Returns an array of zeros with the same shape and type as "corrs"
mask[np.triu_indices_from(mask)] = True ## np.triu_indices_from returns the indices for the upper-triangle of "mask"

sns.set_style({"xtick.direction": "out","ytick.direction": "out"})

fig, ax = plt.subplots(figsize=(20,18))

sns.heatmap(
    corrs,
    vmin=-1.,
    vmax=1.,
    center=0.,
    annot=True,
    annot_kws={"fontsize": 8},
    fmt='.2f',
    linewidths=0.5,
    linecolor='xkcd:cool grey',
    cmap=sns.diverging_palette(250, 30, l=60, s=90, sep=1, center='light', as_cmap=True),
    cbar=True,
    cbar_kws={'shrink': 0.9, 'pad': 0.04},
    square=True,
    mask=mask
)

sns.despine(top=False, left=False, right=False, bottom=False)

ax.collections[0].colorbar.set_label('Pearson Correlation Coefficient ($r$)', labelpad=30, rotation=270, fontsize=13)

ax.set_title('Correlation Heatmap of Passer and Pass Def. EWMA Features (Includes Target Column: Passing Yards)', fontsize=15, pad=17)

plt.tight_layout()

plt.savefig('player_passing_yards_feature_correlation_heatmap_passer_passD.pdf')
plt.show()
# Out:
#                                    passing_yards  pass_attempts_ewma_passer  \
# passing_yards                           1.000000                   0.313531
# pass_attempts_ewma_passer               0.313531                   1.000000
# completion_perc_ewma_passer             0.233742                   0.268853
# cpoe_ewma_passer                        0.234037                   0.195276
# passing_yards_ewma_passer               0.380749                   0.843839
# air_yards_ewma_passer                   0.257489                   0.764837
# yards_after_catch_ewma_passer           0.324927                   0.734146
# pass_touchdowns_ewma_passer             0.334433                   0.510651
# interceptions_ewma_passer              -0.070685                   0.127993
# qb_hits_ewma_passer                     0.054557                   0.333285
# sacks_ewma_passer                      -0.064293                   0.044886
# pass_epa_ewma_passer                    0.331001                   0.315886
# pass_wpa_ewma_passer                    0.293119                   0.285110
# posteam_score_ewma                      0.293849                   0.314131
# score_diff_ewma_passer                  0.234418                   0.178065
# perc_pass_plays_team_ewma_passer        0.131984                   0.547974
# pass_oe_team_ewma_passer                0.263421                   0.576213
# total_giveaways_team_ewma_passer       -0.143104                  -0.106640
# turnover_diff_team_ewma_passer          0.131084                   0.037131
# total_penalties_team_ewma_passer        0.022921                   0.083100
# penalty_yards_team_ewma_passer          0.043312                   0.114107
# pass_attempts_ewma_defense              0.067549                   0.065886
# completion_perc_ewma_defense            0.059030                   0.037086
# cpoe_ewma_defense                       0.049158                   0.006646
# passing_yards_ewma_defense              0.105856                   0.078968
# air_yards_ewma_defense                  0.059793                   0.044612
# yards_after_catch_ewma_defense          0.087972                   0.081395
# pass_touchdowns_ewma_defense            0.056583                   0.041566
# interceptions_ewma_defense             -0.033657                  -0.048480
# qb_hits_ewma_defense                    0.034991                   0.099723
# sacks_ewma_defense                     -0.001206                   0.030426
# pass_epa_ewma_defense                   0.064860                   0.028150
# pass_wpa_ewma_defense                   0.052902                   0.037150
# points_allowed_ewma                     0.059133                   0.031033
# score_diff_ewma_defense                -0.015220                  -0.008418
# perc_pass_plays_team_ewma_defense       0.036556                   0.051728
# pass_oe_team_ewma_defense               0.049828                   0.038391
# total_giveaways_team_ewma_defense      -0.035011                  -0.053129
# turnover_diff_team_ewma_defense         0.002458                   0.000569
# total_penalties_team_ewma_defense       0.041377                   0.055561
# penalty_yards_team_ewma_defense         0.050669                   0.065741
#
#                                    completion_perc_ewma_passer  \
# passing_yards                                         0.233742
# pass_attempts_ewma_passer                             0.268853
# completion_perc_ewma_passer                           1.000000
# cpoe_ewma_passer                                      0.856233
# passing_yards_ewma_passer                             0.510187
# air_yards_ewma_passer                                 0.007516
# yards_after_catch_ewma_passer                         0.516993
# pass_touchdowns_ewma_passer                           0.447177
# interceptions_ewma_passer                            -0.122502
# qb_hits_ewma_passer                                   0.012260
# sacks_ewma_passer                                    -0.067675
# pass_epa_ewma_passer                                  0.563756
# pass_wpa_ewma_passer                                  0.525698
# posteam_score_ewma                                    0.440094
# score_diff_ewma_passer                                0.363700
# perc_pass_plays_team_ewma_passer                      0.085717
# pass_oe_team_ewma_passer                              0.270238
# total_giveaways_team_ewma_passer                     -0.188010
# turnover_diff_team_ewma_passer                        0.106858
# total_penalties_team_ewma_passer                     -0.010267
# penalty_yards_team_ewma_passer                        0.016848
# pass_attempts_ewma_defense                            0.043156
# completion_perc_ewma_defense                          0.085477
# cpoe_ewma_defense                                    -0.004120
# passing_yards_ewma_defense                            0.051233
# air_yards_ewma_defense                               -0.023462
# yards_after_catch_ewma_defense                        0.090464
# pass_touchdowns_ewma_defense                          0.029915
# interceptions_ewma_defense                           -0.043182
# qb_hits_ewma_defense                                  0.086199
# sacks_ewma_defense                                    0.032233
# pass_epa_ewma_defense                                -0.000605
# pass_wpa_ewma_defense                                 0.030118
# points_allowed_ewma                                   0.025534
# score_diff_ewma_defense                               0.019071
# perc_pass_plays_team_ewma_defense                     0.049103
# pass_oe_team_ewma_defense                             0.001579
# total_giveaways_team_ewma_defense                    -0.049588
# turnover_diff_team_ewma_defense                       0.012134
# total_penalties_team_ewma_defense                     0.039531
# penalty_yards_team_ewma_defense                       0.057071
#
#                                    cpoe_ewma_passer  \
# passing_yards                              0.234037
# pass_attempts_ewma_passer                  0.195276
# completion_perc_ewma_passer                0.856233
# cpoe_ewma_passer                           1.000000
# passing_yards_ewma_passer                  0.497800
# air_yards_ewma_passer                      0.129338
# yards_after_catch_ewma_passer              0.393414
# pass_touchdowns_ewma_passer                0.503925
# interceptions_ewma_passer                 -0.229687
# qb_hits_ewma_passer                        0.003981
# sacks_ewma_passer                         -0.084269
# pass_epa_ewma_passer                       0.675961
# pass_wpa_ewma_passer                       0.581452
# posteam_score_ewma                         0.502103
# score_diff_ewma_passer                     0.468880
# perc_pass_plays_team_ewma_passer          -0.051918
# pass_oe_team_ewma_passer                   0.243476
# total_giveaways_team_ewma_passer          -0.243097
# turnover_diff_team_ewma_passer             0.217856
# total_penalties_team_ewma_passer          -0.007190
# penalty_yards_team_ewma_passer             0.002789
# pass_attempts_ewma_defense                -0.004925
# completion_perc_ewma_defense               0.000317
# cpoe_ewma_defense                         -0.009804
# passing_yards_ewma_defense                -0.001709
# air_yards_ewma_defense                    -0.008342
# yards_after_catch_ewma_defense             0.008468
# pass_touchdowns_ewma_defense              -0.019237
# interceptions_ewma_defense                -0.004448
# qb_hits_ewma_defense                      -0.004443
# sacks_ewma_defense                         0.013579
# pass_epa_ewma_defense                     -0.014251
# pass_wpa_ewma_defense                     -0.008624
# points_allowed_ewma                       -0.008960
# score_diff_ewma_defense                    0.014588
# perc_pass_plays_team_ewma_defense          0.004210
# pass_oe_team_ewma_defense                 -0.007063
# total_giveaways_team_ewma_defense         -0.002698
# turnover_diff_team_ewma_defense            0.001118
# total_penalties_team_ewma_defense          0.019207
# penalty_yards_team_ewma_defense            0.024725
#
#                                    passing_yards_ewma_passer  \
# passing_yards                                       0.380749
# pass_attempts_ewma_passer                           0.843839
# completion_perc_ewma_passer                         0.510187
# cpoe_ewma_passer                                    0.497800
# passing_yards_ewma_passer                           1.000000
# air_yards_ewma_passer                               0.721365
# yards_after_catch_ewma_passer                       0.848028
# pass_touchdowns_ewma_passer                         0.716100
# interceptions_ewma_passer                           0.022728
# qb_hits_ewma_passer                                 0.236207
# sacks_ewma_passer                                  -0.011133
# pass_epa_ewma_passer                                0.651528
# pass_wpa_ewma_passer                                0.584649
# posteam_score_ewma                                  0.579872
# score_diff_ewma_passer                              0.393174
# perc_pass_plays_team_ewma_passer                    0.382693
# pass_oe_team_ewma_passer                            0.570667
# total_giveaways_team_ewma_passer                   -0.186450
# turnover_diff_team_ewma_passer                      0.123511
# total_penalties_team_ewma_passer                    0.089721
# penalty_yards_team_ewma_passer                      0.130207
# pass_attempts_ewma_defense                          0.071026
# completion_perc_ewma_defense                        0.035957
# cpoe_ewma_defense                                  -0.004953
# passing_yards_ewma_defense                          0.081555
# air_yards_ewma_defense                              0.043935
# yards_after_catch_ewma_defense                      0.092259
# pass_touchdowns_ewma_defense                        0.033246
# interceptions_ewma_defense                         -0.043964
# qb_hits_ewma_defense                                0.105166
# sacks_ewma_defense                                  0.043594
# pass_epa_ewma_defense                               0.017058
# pass_wpa_ewma_defense                               0.028735
# points_allowed_ewma                                 0.022686
# score_diff_ewma_defense                            -0.000529
# perc_pass_plays_team_ewma_defense                   0.059399
# pass_oe_team_ewma_defense                           0.044104
# total_giveaways_team_ewma_defense                  -0.051469
# turnover_diff_team_ewma_defense                     0.002866
# total_penalties_team_ewma_defense                   0.063263
# penalty_yards_team_ewma_defense                     0.077110
#
#                                    air_yards_ewma_passer  \
# passing_yards                                   0.257489
# pass_attempts_ewma_passer                       0.764837
# completion_perc_ewma_passer                     0.007516
# cpoe_ewma_passer                                0.129338
# passing_yards_ewma_passer                       0.721365
# air_yards_ewma_passer                           1.000000
# yards_after_catch_ewma_passer                   0.408471
# pass_touchdowns_ewma_passer                     0.467256
# interceptions_ewma_passer                       0.242117
# qb_hits_ewma_passer                             0.277939
# sacks_ewma_passer                               0.062378
# pass_epa_ewma_passer                            0.282547
# pass_wpa_ewma_passer                            0.237635
# posteam_score_ewma                              0.299147
# score_diff_ewma_passer                          0.166143
# perc_pass_plays_team_ewma_passer                0.368791
# pass_oe_team_ewma_passer                        0.418626
# total_giveaways_team_ewma_passer                0.011639
# turnover_diff_team_ewma_passer                 -0.003855
# total_penalties_team_ewma_passer                0.100301
# penalty_yards_team_ewma_passer                  0.120510
# pass_attempts_ewma_defense                      0.060241
# completion_perc_ewma_defense                   -0.007422
# cpoe_ewma_defense                               0.005011
# passing_yards_ewma_defense                      0.069973
# air_yards_ewma_defense                          0.075367
# yards_after_catch_ewma_defense                  0.052032
# pass_touchdowns_ewma_defense                    0.028479
# interceptions_ewma_defense                     -0.014377
# qb_hits_ewma_defense                            0.059125
# sacks_ewma_defense                              0.015578
# pass_epa_ewma_defense                           0.027707
# pass_wpa_ewma_defense                           0.019443
# points_allowed_ewma                             0.011143
# score_diff_ewma_defense                        -0.010146
# perc_pass_plays_team_ewma_defense               0.046189
# pass_oe_team_ewma_defense                       0.061968
# total_giveaways_team_ewma_defense              -0.020849
# turnover_diff_team_ewma_defense                 0.003086
# total_penalties_team_ewma_defense               0.058046
# penalty_yards_team_ewma_defense                 0.063778
#
#                                    yards_after_catch_ewma_passer  \
# passing_yards                                           0.324927
# pass_attempts_ewma_passer                               0.734146
# completion_perc_ewma_passer                             0.516993
# cpoe_ewma_passer                                        0.393414
# passing_yards_ewma_passer                               0.848028
# air_yards_ewma_passer                                   0.408471
# yards_after_catch_ewma_passer                           1.000000
# pass_touchdowns_ewma_passer                             0.591831
# interceptions_ewma_passer                              -0.040220
# qb_hits_ewma_passer                                     0.215861
# sacks_ewma_passer                                      -0.006300
# pass_epa_ewma_passer                                    0.536921
# pass_wpa_ewma_passer                                    0.491335
# posteam_score_ewma                                      0.488301
# score_diff_ewma_passer                                  0.336537
# perc_pass_plays_team_ewma_passer                        0.348056
# pass_oe_team_ewma_passer                                0.514728
# total_giveaways_team_ewma_passer                       -0.214970
# turnover_diff_team_ewma_passer                          0.127633
# total_penalties_team_ewma_passer                        0.082780
# penalty_yards_team_ewma_passer                          0.128794
# pass_attempts_ewma_defense                              0.081552
# completion_perc_ewma_defense                            0.061252
# cpoe_ewma_defense                                      -0.008104
# passing_yards_ewma_defense                              0.090111
# air_yards_ewma_defense                                  0.031006
# yards_after_catch_ewma_defense                          0.115393
# pass_touchdowns_ewma_defense                            0.043756
# interceptions_ewma_defense                             -0.055323
# qb_hits_ewma_defense                                    0.134198
# sacks_ewma_defense                                      0.060942
# pass_epa_ewma_defense                                   0.011218
# pass_wpa_ewma_defense                                   0.037282
# points_allowed_ewma                                     0.033404
# score_diff_ewma_defense                                 0.001742
# perc_pass_plays_team_ewma_defense                       0.066280
# pass_oe_team_ewma_defense                               0.035881
# total_giveaways_team_ewma_defense                      -0.057820
# turnover_diff_team_ewma_defense                         0.005914
# total_penalties_team_ewma_defense                       0.072245
# penalty_yards_team_ewma_defense                         0.091170
#
#                                    pass_touchdowns_ewma_passer  \
# passing_yards                                         0.334433
# pass_attempts_ewma_passer                             0.510651
# completion_perc_ewma_passer                           0.447177
# cpoe_ewma_passer                                      0.503925
# passing_yards_ewma_passer                             0.716100
# air_yards_ewma_passer                                 0.467256
# yards_after_catch_ewma_passer                         0.591831
# pass_touchdowns_ewma_passer                           1.000000
# interceptions_ewma_passer                            -0.121858
# qb_hits_ewma_passer                                   0.037662
# sacks_ewma_passer                                    -0.153386
# pass_epa_ewma_passer                                  0.731379
# pass_wpa_ewma_passer                                  0.637383
# posteam_score_ewma                                    0.730779
# score_diff_ewma_passer                                0.515305
# perc_pass_plays_team_ewma_passer                      0.148737
# pass_oe_team_ewma_passer                              0.436417
# total_giveaways_team_ewma_passer                     -0.260317
# turnover_diff_team_ewma_passer                        0.256343
# total_penalties_team_ewma_passer                      0.031167
# penalty_yards_team_ewma_passer                        0.069362
# pass_attempts_ewma_defense                            0.033580
# completion_perc_ewma_defense                          0.027113
# cpoe_ewma_defense                                    -0.013315
# passing_yards_ewma_defense                            0.041791
# air_yards_ewma_defense                                0.008800
# yards_after_catch_ewma_defense                        0.059128
# pass_touchdowns_ewma_defense                          0.014840
# interceptions_ewma_defense                           -0.047606
# qb_hits_ewma_defense                                  0.065333
# sacks_ewma_defense                                    0.029390
# pass_epa_ewma_defense                                 0.009963
# pass_wpa_ewma_defense                                 0.013836
# points_allowed_ewma                                   0.016087
# score_diff_ewma_defense                              -0.001401
# perc_pass_plays_team_ewma_defense                     0.023219
# pass_oe_team_ewma_defense                             0.012097
# total_giveaways_team_ewma_defense                    -0.056424
# turnover_diff_team_ewma_defense                      -0.009006
# total_penalties_team_ewma_defense                     0.032882
# penalty_yards_team_ewma_defense                       0.046839
#
#                                    interceptions_ewma_passer  \
# passing_yards                                      -0.070685
# pass_attempts_ewma_passer                           0.127993
# completion_perc_ewma_passer                        -0.122502
# cpoe_ewma_passer                                   -0.229687
# passing_yards_ewma_passer                           0.022728
# air_yards_ewma_passer                               0.242117
# yards_after_catch_ewma_passer                      -0.040220
# pass_touchdowns_ewma_passer                        -0.121858
# interceptions_ewma_passer                           1.000000
# qb_hits_ewma_passer                                 0.057323
# sacks_ewma_passer                                   0.040175
# pass_epa_ewma_passer                               -0.412612
# pass_wpa_ewma_passer                               -0.363570
# posteam_score_ewma                                 -0.254123
# score_diff_ewma_passer                             -0.325164
# perc_pass_plays_team_ewma_passer                    0.230599
# pass_oe_team_ewma_passer                            0.030795
# total_giveaways_team_ewma_passer                    0.719653
# turnover_diff_team_ewma_passer                     -0.530950
# total_penalties_team_ewma_passer                    0.000492
# penalty_yards_team_ewma_passer                     -0.032845
# pass_attempts_ewma_defense                         -0.017846
# completion_perc_ewma_defense                       -0.066303
# cpoe_ewma_defense                                  -0.013212
# passing_yards_ewma_defense                         -0.024659
# air_yards_ewma_defense                              0.021297
# yards_after_catch_ewma_defense                     -0.039134
# pass_touchdowns_ewma_defense                       -0.016996
# interceptions_ewma_defense                          0.038169
# qb_hits_ewma_defense                               -0.050395
# sacks_ewma_defense                                 -0.015398
# pass_epa_ewma_defense                              -0.011542
# pass_wpa_ewma_defense                              -0.021938
# points_allowed_ewma                                -0.024729
# score_diff_ewma_defense                            -0.002831
# perc_pass_plays_team_ewma_defense                  -0.014657
# pass_oe_team_ewma_defense                           0.005941
# total_giveaways_team_ewma_defense                   0.055509
# turnover_diff_team_ewma_defense                     0.007705
# total_penalties_team_ewma_defense                  -0.015342
# penalty_yards_team_ewma_defense                    -0.025700
#
#                                    qb_hits_ewma_passer  sacks_ewma_passer  \
# passing_yards                                 0.054557          -0.064293
# pass_attempts_ewma_passer                     0.333285           0.044886
# completion_perc_ewma_passer                   0.012260          -0.067675
# cpoe_ewma_passer                              0.003981          -0.084269
# passing_yards_ewma_passer                     0.236207          -0.011133
# air_yards_ewma_passer                         0.277939           0.062378
# yards_after_catch_ewma_passer                 0.215861          -0.006300
# pass_touchdowns_ewma_passer                   0.037662          -0.153386
# interceptions_ewma_passer                     0.057323           0.040175
# qb_hits_ewma_passer                           1.000000           0.612444
# sacks_ewma_passer                             0.612444           1.000000
# pass_epa_ewma_passer                         -0.170115          -0.354032
# pass_wpa_ewma_passer                         -0.139691          -0.304336
# posteam_score_ewma                           -0.105229          -0.261902
# score_diff_ewma_passer                       -0.147899          -0.251596
# perc_pass_plays_team_ewma_passer              0.268031           0.120960
# pass_oe_team_ewma_passer                      0.146106           0.010694
# total_giveaways_team_ewma_passer             -0.027929           0.032219
# turnover_diff_team_ewma_passer               -0.070366          -0.091956
# total_penalties_team_ewma_passer              0.097568           0.044297
# penalty_yards_team_ewma_passer                0.101292           0.033036
# pass_attempts_ewma_defense                    0.103809           0.045537
# completion_perc_ewma_defense                  0.107815           0.028230
# cpoe_ewma_defense                             0.021593           0.002875
# passing_yards_ewma_defense                    0.125604           0.061083
# air_yards_ewma_defense                        0.033710           0.029283
# yards_after_catch_ewma_defense                0.154327           0.071702
# pass_touchdowns_ewma_defense                  0.089940           0.051056
# interceptions_ewma_defense                   -0.082082          -0.021984
# qb_hits_ewma_defense                          0.171573           0.061715
# sacks_ewma_defense                            0.060202           0.021954
# pass_epa_ewma_defense                         0.045194           0.025559
# pass_wpa_ewma_defense                         0.058659           0.011432
# points_allowed_ewma                           0.069493           0.040628
# score_diff_ewma_defense                      -0.028843          -0.031440
# perc_pass_plays_team_ewma_defense             0.077956           0.032744
# pass_oe_team_ewma_defense                     0.045009           0.035662
# total_giveaways_team_ewma_defense            -0.100659          -0.028245
# turnover_diff_team_ewma_defense               0.001815          -0.001959
# total_penalties_team_ewma_defense             0.073323           0.044741
# penalty_yards_team_ewma_defense               0.093953           0.045201
#
#                                    pass_epa_ewma_passer  pass_wpa_ewma_passer  \
# passing_yards                                  0.331001              0.293119
# pass_attempts_ewma_passer                      0.315886              0.285110
# completion_perc_ewma_passer                    0.563756              0.525698
# cpoe_ewma_passer                               0.675961              0.581452
# passing_yards_ewma_passer                      0.651528              0.584649
# air_yards_ewma_passer                          0.282547              0.237635
# yards_after_catch_ewma_passer                  0.536921              0.491335
# pass_touchdowns_ewma_passer                    0.731379              0.637383
# interceptions_ewma_passer                     -0.412612             -0.363570
# qb_hits_ewma_passer                           -0.170115             -0.139691
# sacks_ewma_passer                             -0.354032             -0.304336
# pass_epa_ewma_passer                           1.000000              0.854938
# pass_wpa_ewma_passer                           0.854938              1.000000
# posteam_score_ewma                             0.761912              0.649545
# score_diff_ewma_passer                         0.663978              0.522383
# perc_pass_plays_team_ewma_passer              -0.067700             -0.033057
# pass_oe_team_ewma_passer                       0.334038              0.297160
# total_giveaways_team_ewma_passer              -0.468839             -0.420418
# turnover_diff_team_ewma_passer                 0.408078              0.343176
# total_penalties_team_ewma_passer              -0.008136             -0.005333
# penalty_yards_team_ewma_passer                 0.032651              0.036343
# pass_attempts_ewma_defense                     0.011122              0.023428
# completion_perc_ewma_defense                   0.009415              0.032263
# cpoe_ewma_defense                             -0.011387             -0.011379
# passing_yards_ewma_defense                     0.008314              0.016705
# air_yards_ewma_defense                        -0.001818             -0.008647
# yards_after_catch_ewma_defense                 0.018140              0.041363
# pass_touchdowns_ewma_defense                  -0.017730             -0.010962
# interceptions_ewma_defense                    -0.014686             -0.022812
# qb_hits_ewma_defense                           0.029725              0.057025
# sacks_ewma_defense                             0.026213              0.022977
# pass_epa_ewma_defense                         -0.010650             -0.008817
# pass_wpa_ewma_defense                         -0.003112              0.008528
# points_allowed_ewma                           -0.006595             -0.004119
# score_diff_ewma_defense                        0.016155              0.019075
# perc_pass_plays_team_ewma_defense              0.010720              0.027043
# pass_oe_team_ewma_defense                      0.005120              0.005384
# total_giveaways_team_ewma_defense             -0.019377             -0.031873
# turnover_diff_team_ewma_defense               -0.000911             -0.001692
# total_penalties_team_ewma_defense              0.018865              0.017693
# penalty_yards_team_ewma_defense                0.027243              0.029811
#
#                                    posteam_score_ewma  score_diff_ewma_passer  \
# passing_yards                                0.293849                0.234418
# pass_attempts_ewma_passer                    0.314131                0.178065
# completion_perc_ewma_passer                  0.440094                0.363700
# cpoe_ewma_passer                             0.502103                0.468880
# passing_yards_ewma_passer                    0.579872                0.393174
# air_yards_ewma_passer                        0.299147                0.166143
# yards_after_catch_ewma_passer                0.488301                0.336537
# pass_touchdowns_ewma_passer                  0.730779                0.515305
# interceptions_ewma_passer                   -0.254123               -0.325164
# qb_hits_ewma_passer                         -0.105229               -0.147899
# sacks_ewma_passer                           -0.261902               -0.251596
# pass_epa_ewma_passer                         0.761912                0.663978
# pass_wpa_ewma_passer                         0.649545                0.522383
# posteam_score_ewma                           1.000000                0.799247
# score_diff_ewma_passer                       0.799247                1.000000
# perc_pass_plays_team_ewma_passer            -0.159211               -0.361797
# pass_oe_team_ewma_passer                     0.280302                0.156800
# total_giveaways_team_ewma_passer            -0.394622               -0.486858
# turnover_diff_team_ewma_passer               0.497134                0.631705
# total_penalties_team_ewma_passer             0.002289               -0.051232
# penalty_yards_team_ewma_passer               0.057778               -0.007225
# pass_attempts_ewma_defense                   0.022507               -0.017420
# completion_perc_ewma_defense                 0.018766               -0.010090
# cpoe_ewma_defense                           -0.016228               -0.012620
# passing_yards_ewma_defense                   0.026921               -0.018842
# air_yards_ewma_defense                       0.003710               -0.015673
# yards_after_catch_ewma_defense               0.043617               -0.012960
# pass_touchdowns_ewma_defense                -0.000576               -0.036638
# interceptions_ewma_defense                  -0.027280               -0.006678
# qb_hits_ewma_defense                         0.053791                0.011012
# sacks_ewma_defense                           0.035430                0.019819
# pass_epa_ewma_defense                       -0.001584               -0.019862
# pass_wpa_ewma_defense                        0.011136               -0.011923
# points_allowed_ewma                          0.009408               -0.022440
# score_diff_ewma_defense                      0.015252                0.023495
# perc_pass_plays_team_ewma_defense            0.018653               -0.014173
# pass_oe_team_ewma_defense                    0.009664               -0.026584
# total_giveaways_team_ewma_defense           -0.042041               -0.003781
# turnover_diff_team_ewma_defense             -0.000866                0.000902
# total_penalties_team_ewma_defense            0.014281                0.007491
# penalty_yards_team_ewma_defense              0.026791                0.010373
#
#                                    perc_pass_plays_team_ewma_passer  \
# passing_yards                                              0.131984
# pass_attempts_ewma_passer                                  0.547974
# completion_perc_ewma_passer                                0.085717
# cpoe_ewma_passer                                          -0.051918
# passing_yards_ewma_passer                                  0.382693
# air_yards_ewma_passer                                      0.368791
# yards_after_catch_ewma_passer                              0.348056
# pass_touchdowns_ewma_passer                                0.148737
# interceptions_ewma_passer                                  0.230599
# qb_hits_ewma_passer                                        0.268031
# sacks_ewma_passer                                          0.120960
# pass_epa_ewma_passer                                      -0.067700
# pass_wpa_ewma_passer                                      -0.033057
# posteam_score_ewma                                        -0.159211
# score_diff_ewma_passer                                    -0.361797
# perc_pass_plays_team_ewma_passer                           1.000000
# pass_oe_team_ewma_passer                                   0.728756
# total_giveaways_team_ewma_passer                           0.233102
# turnover_diff_team_ewma_passer                            -0.319111
# total_penalties_team_ewma_passer                           0.099587
# penalty_yards_team_ewma_passer                             0.087438
# pass_attempts_ewma_defense                                 0.066058
# completion_perc_ewma_defense                               0.049981
# cpoe_ewma_defense                                          0.013005
# passing_yards_ewma_defense                                 0.072254
# air_yards_ewma_defense                                     0.029825
# yards_after_catch_ewma_defense                             0.086446
# pass_touchdowns_ewma_defense                               0.050911
# interceptions_ewma_defense                                -0.036494
# qb_hits_ewma_defense                                       0.075045
# sacks_ewma_defense                                         0.014400
# pass_epa_ewma_defense                                      0.025489
# pass_wpa_ewma_defense                                      0.028437
# points_allowed_ewma                                        0.023385
# score_diff_ewma_defense                                   -0.003445
# perc_pass_plays_team_ewma_defense                          0.053948
# pass_oe_team_ewma_defense                                  0.036143
# total_giveaways_team_ewma_defense                         -0.042148
# turnover_diff_team_ewma_defense                            0.008311
# total_penalties_team_ewma_defense                          0.044635
# penalty_yards_team_ewma_defense                            0.048584
#
#                                    pass_oe_team_ewma_passer  \
# passing_yards                                      0.263421
# pass_attempts_ewma_passer                          0.576213
# completion_perc_ewma_passer                        0.270238
# cpoe_ewma_passer                                   0.243476
# passing_yards_ewma_passer                          0.570667
# air_yards_ewma_passer                              0.418626
# yards_after_catch_ewma_passer                      0.514728
# pass_touchdowns_ewma_passer                        0.436417
# interceptions_ewma_passer                          0.030795
# qb_hits_ewma_passer                                0.146106
# sacks_ewma_passer                                  0.010694
# pass_epa_ewma_passer                               0.334038
# pass_wpa_ewma_passer                               0.297160
# posteam_score_ewma                                 0.280302
# score_diff_ewma_passer                             0.156800
# perc_pass_plays_team_ewma_passer                   0.728756
# pass_oe_team_ewma_passer                           1.000000
# total_giveaways_team_ewma_passer                  -0.031517
# turnover_diff_team_ewma_passer                     0.050633
# total_penalties_team_ewma_passer                   0.015680
# penalty_yards_team_ewma_passer                     0.027000
# pass_attempts_ewma_defense                         0.039494
# completion_perc_ewma_defense                      -0.005623
# cpoe_ewma_defense                                 -0.007047
# passing_yards_ewma_defense                         0.037882
# air_yards_ewma_defense                             0.041865
# yards_after_catch_ewma_defense                     0.037221
# pass_touchdowns_ewma_defense                       0.010750
# interceptions_ewma_defense                        -0.009304
# qb_hits_ewma_defense                               0.035777
# sacks_ewma_defense                                 0.010972
# pass_epa_ewma_defense                              0.003648
# pass_wpa_ewma_defense                             -0.000198
# points_allowed_ewma                                0.010170
# score_diff_ewma_defense                            0.002378
# perc_pass_plays_team_ewma_defense                  0.021703
# pass_oe_team_ewma_defense                          0.033896
# total_giveaways_team_ewma_defense                 -0.008168
# turnover_diff_team_ewma_defense                    0.010081
# total_penalties_team_ewma_defense                  0.025880
# penalty_yards_team_ewma_defense                    0.027987
#
#                                    total_giveaways_team_ewma_passer  \
# passing_yards                                             -0.143104
# pass_attempts_ewma_passer                                 -0.106640
# completion_perc_ewma_passer                               -0.188010
# cpoe_ewma_passer                                          -0.243097
# passing_yards_ewma_passer                                 -0.186450
# air_yards_ewma_passer                                      0.011639
# yards_after_catch_ewma_passer                             -0.214970
# pass_touchdowns_ewma_passer                               -0.260317
# interceptions_ewma_passer                                  0.719653
# qb_hits_ewma_passer                                       -0.027929
# sacks_ewma_passer                                          0.032219
# pass_epa_ewma_passer                                      -0.468839
# pass_wpa_ewma_passer                                      -0.420418
# posteam_score_ewma                                        -0.394622
# score_diff_ewma_passer                                    -0.486858
# perc_pass_plays_team_ewma_passer                           0.233102
# pass_oe_team_ewma_passer                                  -0.031517
# total_giveaways_team_ewma_passer                           1.000000
# turnover_diff_team_ewma_passer                            -0.746178
# total_penalties_team_ewma_passer                           0.005680
# penalty_yards_team_ewma_passer                            -0.057914
# pass_attempts_ewma_defense                                -0.039861
# completion_perc_ewma_defense                              -0.074830
# cpoe_ewma_defense                                         -0.004039
# passing_yards_ewma_defense                                -0.046118
# air_yards_ewma_defense                                     0.010650
# yards_after_catch_ewma_defense                            -0.066427
# pass_touchdowns_ewma_defense                              -0.028444
# interceptions_ewma_defense                                 0.061078
# qb_hits_ewma_defense                                      -0.092947
# sacks_ewma_defense                                        -0.017404
# pass_epa_ewma_defense                                     -0.017469
# pass_wpa_ewma_defense                                     -0.037604
# points_allowed_ewma                                       -0.039715
# score_diff_ewma_defense                                   -0.000819
# perc_pass_plays_team_ewma_defense                         -0.028341
# pass_oe_team_ewma_defense                                  0.008359
# total_giveaways_team_ewma_defense                          0.079111
# turnover_diff_team_ewma_defense                            0.005261
# total_penalties_team_ewma_defense                         -0.024485
# penalty_yards_team_ewma_defense                           -0.044767
#
#                                    turnover_diff_team_ewma_passer  \
# passing_yards                                            0.131084
# pass_attempts_ewma_passer                                0.037131
# completion_perc_ewma_passer                              0.106858
# cpoe_ewma_passer                                         0.217856
# passing_yards_ewma_passer                                0.123511
# air_yards_ewma_passer                                   -0.003855
# yards_after_catch_ewma_passer                            0.127633
# pass_touchdowns_ewma_passer                              0.256343
# interceptions_ewma_passer                               -0.530950
# qb_hits_ewma_passer                                     -0.070366
# sacks_ewma_passer                                       -0.091956
# pass_epa_ewma_passer                                     0.408078
# pass_wpa_ewma_passer                                     0.343176
# posteam_score_ewma                                       0.497134
# score_diff_ewma_passer                                   0.631705
# perc_pass_plays_team_ewma_passer                        -0.319111
# pass_oe_team_ewma_passer                                 0.050633
# total_giveaways_team_ewma_passer                        -0.746178
# turnover_diff_team_ewma_passer                           1.000000
# total_penalties_team_ewma_passer                         0.008035
# penalty_yards_team_ewma_passer                           0.038658
# pass_attempts_ewma_defense                              -0.022518
# completion_perc_ewma_defense                             0.002664
# cpoe_ewma_defense                                       -0.001081
# passing_yards_ewma_defense                              -0.010412
# air_yards_ewma_defense                                  -0.013117
# yards_after_catch_ewma_defense                          -0.005970
# pass_touchdowns_ewma_defense                            -0.015977
# interceptions_ewma_defense                              -0.014134
# qb_hits_ewma_defense                                    -0.003400
# sacks_ewma_defense                                      -0.004037
# pass_epa_ewma_defense                                    0.003208
# pass_wpa_ewma_defense                                    0.003065
# points_allowed_ewma                                      0.000865
# score_diff_ewma_defense                                 -0.002071
# perc_pass_plays_team_ewma_defense                       -0.019535
# pass_oe_team_ewma_defense                               -0.027040
# total_giveaways_team_ewma_defense                       -0.016176
# turnover_diff_team_ewma_defense                         -0.012670
# total_penalties_team_ewma_defense                        0.007068
# penalty_yards_team_ewma_defense                          0.009134
#
#                                    total_penalties_team_ewma_passer  \
# passing_yards                                              0.022921
# pass_attempts_ewma_passer                                  0.083100
# completion_perc_ewma_passer                               -0.010267
# cpoe_ewma_passer                                          -0.007190
# passing_yards_ewma_passer                                  0.089721
# air_yards_ewma_passer                                      0.100301
# yards_after_catch_ewma_passer                              0.082780
# pass_touchdowns_ewma_passer                                0.031167
# interceptions_ewma_passer                                  0.000492
# qb_hits_ewma_passer                                        0.097568
# sacks_ewma_passer                                          0.044297
# pass_epa_ewma_passer                                      -0.008136
# pass_wpa_ewma_passer                                      -0.005333
# posteam_score_ewma                                         0.002289
# score_diff_ewma_passer                                    -0.051232
# perc_pass_plays_team_ewma_passer                           0.099587
# pass_oe_team_ewma_passer                                   0.015680
# total_giveaways_team_ewma_passer                           0.005680
# turnover_diff_team_ewma_passer                             0.008035
# total_penalties_team_ewma_passer                           1.000000
# penalty_yards_team_ewma_passer                             0.883384
# pass_attempts_ewma_defense                                 0.070358
# completion_perc_ewma_defense                               0.033195
# cpoe_ewma_defense                                          0.005696
# passing_yards_ewma_defense                                 0.082987
# air_yards_ewma_defense                                     0.061221
# yards_after_catch_ewma_defense                             0.084981
# pass_touchdowns_ewma_defense                               0.042426
# interceptions_ewma_defense                                -0.028495
# qb_hits_ewma_defense                                       0.090065
# sacks_ewma_defense                                         0.043941
# pass_epa_ewma_defense                                      0.018490
# pass_wpa_ewma_defense                                      0.025739
# points_allowed_ewma                                        0.001650
# score_diff_ewma_defense                                    0.012064
# perc_pass_plays_team_ewma_defense                          0.079585
# pass_oe_team_ewma_defense                                  0.065091
# total_giveaways_team_ewma_defense                         -0.030261
# turnover_diff_team_ewma_defense                            0.006194
# total_penalties_team_ewma_defense                          0.126782
# penalty_yards_team_ewma_defense                            0.135067
#
#                                    penalty_yards_team_ewma_passer  \
# passing_yards                                            0.043312
# pass_attempts_ewma_passer                                0.114107
# completion_perc_ewma_passer                              0.016848
# cpoe_ewma_passer                                         0.002789
# passing_yards_ewma_passer                                0.130207
# air_yards_ewma_passer                                    0.120510
# yards_after_catch_ewma_passer                            0.128794
# pass_touchdowns_ewma_passer                              0.069362
# interceptions_ewma_passer                               -0.032845
# qb_hits_ewma_passer                                      0.101292
# sacks_ewma_passer                                        0.033036
# pass_epa_ewma_passer                                     0.032651
# pass_wpa_ewma_passer                                     0.036343
# posteam_score_ewma                                       0.057778
# score_diff_ewma_passer                                  -0.007225
# perc_pass_plays_team_ewma_passer                         0.087438
# pass_oe_team_ewma_passer                                 0.027000
# total_giveaways_team_ewma_passer                        -0.057914
# turnover_diff_team_ewma_passer                           0.038658
# total_penalties_team_ewma_passer                         0.883384
# penalty_yards_team_ewma_passer                           1.000000
# ...
# completion_perc_ewma_defense                               -0.054934
# cpoe_ewma_defense                                          -0.181244
# passing_yards_ewma_defense                                  0.420037
# air_yards_ewma_defense                                      0.494034
# yards_after_catch_ewma_defense                              0.330508
# pass_touchdowns_ewma_defense                                0.012173
# interceptions_ewma_defense                                  0.245827
# qb_hits_ewma_defense                                        0.474726
# sacks_ewma_defense                                          0.363364
# pass_epa_ewma_defense                                      -0.272964
# pass_wpa_ewma_defense                                      -0.202785
# points_allowed_ewma                                        -0.353734
# score_diff_ewma_defense                                     0.578884
# perc_pass_plays_team_ewma_defense                           1.000000
# pass_oe_team_ewma_defense                                   0.725606
# total_giveaways_team_ewma_defense                           0.235231
# turnover_diff_team_ewma_defense                             0.386690
# total_penalties_team_ewma_defense                           0.065166
# penalty_yards_team_ewma_defense                             0.107999
#
#                                    pass_oe_team_ewma_defense  \
# passing_yards                                       0.049828
# pass_attempts_ewma_passer                           0.038391
# completion_perc_ewma_passer                         0.001579
# cpoe_ewma_passer                                   -0.007063
# passing_yards_ewma_passer                           0.044104
# air_yards_ewma_passer                               0.061968
# yards_after_catch_ewma_passer                       0.035881
# pass_touchdowns_ewma_passer                         0.012097
# interceptions_ewma_passer                           0.005941
# qb_hits_ewma_passer                                 0.045009
# sacks_ewma_passer                                   0.035662
# pass_epa_ewma_passer                                0.005120
# pass_wpa_ewma_passer                                0.005384
# posteam_score_ewma                                  0.009664
# score_diff_ewma_passer                             -0.026584
# perc_pass_plays_team_ewma_passer                    0.036143
# pass_oe_team_ewma_passer                            0.033896
# total_giveaways_team_ewma_passer                    0.008359
# turnover_diff_team_ewma_passer                     -0.027040
# total_penalties_team_ewma_passer                    0.065091
# penalty_yards_team_ewma_passer                      0.068620
# pass_attempts_ewma_defense                          0.642788
# completion_perc_ewma_defense                        0.102501
# cpoe_ewma_defense                                   0.099179
# passing_yards_ewma_defense                          0.530032
# air_yards_ewma_defense                              0.400374
# yards_after_catch_ewma_defense                      0.418300
# pass_touchdowns_ewma_defense                        0.230893
# interceptions_ewma_defense                          0.048249
# qb_hits_ewma_defense                                0.269200
# sacks_ewma_defense                                  0.152004
# pass_epa_ewma_defense                               0.082631
# pass_wpa_ewma_defense                               0.077298
# points_allowed_ewma                                 0.027027
# score_diff_ewma_defense                             0.125360
# perc_pass_plays_team_ewma_defense                   0.725606
# pass_oe_team_ewma_defense                           1.000000
# total_giveaways_team_ewma_defense                   0.055600
# turnover_diff_team_ewma_defense                     0.066007
# total_penalties_team_ewma_defense                   0.105121
# penalty_yards_team_ewma_defense                     0.127190
#
#                                    total_giveaways_team_ewma_defense  \
# passing_yards                                              -0.035011
# pass_attempts_ewma_passer                                  -0.053129
# completion_perc_ewma_passer                                -0.049588
# cpoe_ewma_passer                                           -0.002698
# passing_yards_ewma_passer                                  -0.051469
# air_yards_ewma_passer                                      -0.020849
# yards_after_catch_ewma_passer                              -0.057820
# pass_touchdowns_ewma_passer                                -0.056424
# interceptions_ewma_passer                                   0.055509
# qb_hits_ewma_passer                                        -0.100659
# sacks_ewma_passer                                          -0.028245
# pass_epa_ewma_passer                                       -0.019377
# pass_wpa_ewma_passer                                       -0.031873
# posteam_score_ewma                                         -0.042041
# score_diff_ewma_passer                                     -0.003781
# perc_pass_plays_team_ewma_passer                           -0.042148
# pass_oe_team_ewma_passer                                   -0.008168
# total_giveaways_team_ewma_passer                            0.079111
# turnover_diff_team_ewma_passer                             -0.016176
# total_penalties_team_ewma_passer                           -0.030261
# penalty_yards_team_ewma_passer                             -0.048362
# pass_attempts_ewma_defense                                  0.108809
# completion_perc_ewma_defense                               -0.175836
# cpoe_ewma_defense                                          -0.229047
# passing_yards_ewma_defense                                 -0.046655
# air_yards_ewma_defense                                      0.206474
# yards_after_catch_ewma_defense                             -0.120002
# pass_touchdowns_ewma_defense                               -0.230687
# interceptions_ewma_defense                                  0.809572
# qb_hits_ewma_defense                                        0.046168
# sacks_ewma_defense                                          0.141414
# pass_epa_ewma_defense                                      -0.517681
# pass_wpa_ewma_defense                                      -0.447077
# points_allowed_ewma                                        -0.358046
# score_diff_ewma_defense                                     0.448195
# perc_pass_plays_team_ewma_defense                           0.235231
# pass_oe_team_ewma_defense                                   0.055600
# total_giveaways_team_ewma_defense                           1.000000
# turnover_diff_team_ewma_defense                             0.714344
# total_penalties_team_ewma_defense                           0.005502
# penalty_yards_team_ewma_defense                            -0.021081
#
#                                    turnover_diff_team_ewma_defense  \
# passing_yards                                             0.002458
# pass_attempts_ewma_passer                                 0.000569
# completion_perc_ewma_passer                               0.012134
# cpoe_ewma_passer                                          0.001118
# passing_yards_ewma_passer                                 0.002866
# air_yards_ewma_passer                                     0.003086
# yards_after_catch_ewma_passer                             0.005914
# pass_touchdowns_ewma_passer                              -0.009006
# interceptions_ewma_passer                                 0.007705
# qb_hits_ewma_passer                                       0.001815
# sacks_ewma_passer                                        -0.001959
# pass_epa_ewma_passer                                     -0.000911
# pass_wpa_ewma_passer                                     -0.001692
# posteam_score_ewma                                       -0.000866
# score_diff_ewma_passer                                    0.000902
# perc_pass_plays_team_ewma_passer                          0.008311
# pass_oe_team_ewma_passer                                  0.010081
# total_giveaways_team_ewma_passer                          0.005261
# turnover_diff_team_ewma_passer                           -0.012670
# total_penalties_team_ewma_passer                          0.006194
# penalty_yards_team_ewma_passer                            0.011160
# pass_attempts_ewma_defense                                0.234915
# completion_perc_ewma_defense                             -0.103284
# cpoe_ewma_defense                                        -0.233599
# passing_yards_ewma_defense                                0.060833
# air_yards_ewma_defense                                    0.258442
# yards_after_catch_ewma_defense                           -0.009827
# pass_touchdowns_ewma_defense                             -0.207299
# interceptions_ewma_defense                                0.615725
# qb_hits_ewma_defense                                      0.160789
# sacks_ewma_defense                                        0.186622
# pass_epa_ewma_defense                                    -0.429263
# pass_wpa_ewma_defense                                    -0.337263
# points_allowed_ewma                                      -0.470375
# score_diff_ewma_defense                                   0.628204
# perc_pass_plays_team_ewma_defense                         0.386690
# pass_oe_team_ewma_defense                                 0.066007
# total_giveaways_team_ewma_defense                         0.714344
# turnover_diff_team_ewma_defense                           1.000000
# total_penalties_team_ewma_defense                        -0.007165
# penalty_yards_team_ewma_defense                           0.017009
#
#                                    total_penalties_team_ewma_defense  \
# passing_yards                                               0.041377
# pass_attempts_ewma_passer                                   0.055561
# completion_perc_ewma_passer                                 0.039531
# cpoe_ewma_passer                                            0.019207
# passing_yards_ewma_passer                                   0.063263
# air_yards_ewma_passer                                       0.058046
# yards_after_catch_ewma_passer                               0.072245
# pass_touchdowns_ewma_passer                                 0.032882
# interceptions_ewma_passer                                  -0.015342
# qb_hits_ewma_passer                                         0.073323
# sacks_ewma_passer                                           0.044741
# pass_epa_ewma_passer                                        0.018865
# pass_wpa_ewma_passer                                        0.017693
# posteam_score_ewma                                          0.014281
# score_diff_ewma_passer                                      0.007491
# perc_pass_plays_team_ewma_passer                            0.044635
# pass_oe_team_ewma_passer                                    0.025880
# total_giveaways_team_ewma_passer                           -0.024485
# turnover_diff_team_ewma_passer                              0.007068
# total_penalties_team_ewma_passer                            0.126782
# penalty_yards_team_ewma_passer                              0.133983
# pass_attempts_ewma_defense                                  0.094431
# completion_perc_ewma_defense                               -0.025868
# cpoe_ewma_defense                                          -0.038804
# passing_yards_ewma_defense                                  0.077403
# air_yards_ewma_defense                                      0.063437
# yards_after_catch_ewma_defense                              0.088158
# pass_touchdowns_ewma_defense                                0.108497
# interceptions_ewma_defense                                 -0.015562
# qb_hits_ewma_defense                                        0.162466
# sacks_ewma_defense                                          0.070027
# pass_epa_ewma_defense                                      -0.003608
# pass_wpa_ewma_defense                                       0.015383
# points_allowed_ewma                                         0.102007
# score_diff_ewma_defense                                    -0.072613
# perc_pass_plays_team_ewma_defense                           0.065166
# pass_oe_team_ewma_defense                                   0.105121
# total_giveaways_team_ewma_defense                           0.005502
# turnover_diff_team_ewma_defense                            -0.007165
# total_penalties_team_ewma_defense                           1.000000
# penalty_yards_team_ewma_defense                             0.891054
#
#                                    penalty_yards_team_ewma_defense
# passing_yards                                             0.050669
# pass_attempts_ewma_passer                                 0.065741
# completion_perc_ewma_passer                               0.057071
# cpoe_ewma_passer                                          0.024725
# passing_yards_ewma_passer                                 0.077110
# air_yards_ewma_passer                                     0.063778
# yards_after_catch_ewma_passer                             0.091170
# pass_touchdowns_ewma_passer                               0.046839
# interceptions_ewma_passer                                -0.025700
# qb_hits_ewma_passer                                       0.093953
# sacks_ewma_passer                                         0.045201
# pass_epa_ewma_passer                                      0.027243
# pass_wpa_ewma_passer                                      0.029811
# posteam_score_ewma                                        0.026791
# score_diff_ewma_passer                                    0.010373
# perc_pass_plays_team_ewma_passer                          0.048584
# pass_oe_team_ewma_passer                                  0.027987
# total_giveaways_team_ewma_passer                         -0.044767
# turnover_diff_team_ewma_passer                            0.009134
# total_penalties_team_ewma_passer                          0.135067
# penalty_yards_team_ewma_passer                            0.147208
# pass_attempts_ewma_defense                                0.126869
# completion_perc_ewma_defense                             -0.033406
# cpoe_ewma_defense                                        -0.060125
# passing_yards_ewma_defense                                0.089539
# air_yards_ewma_defense                                    0.094947
# yards_after_catch_ewma_defense                            0.105401
# pass_touchdowns_ewma_defense                              0.127429
# interceptions_ewma_defense                               -0.027635
# qb_hits_ewma_defense                                      0.207122
# sacks_ewma_defense                                        0.083104
# pass_epa_ewma_defense                                    -0.005016
# pass_wpa_ewma_defense                                     0.015292
# points_allowed_ewma                                       0.094281
# score_diff_ewma_defense                                  -0.028145
# perc_pass_plays_team_ewma_defense                         0.107999
# pass_oe_team_ewma_defense                                 0.127190
# total_giveaways_team_ewma_defense                        -0.021081
# turnover_diff_team_ewma_defense                           0.017009
# total_penalties_team_ewma_defense                         0.891054
# penalty_yards_team_ewma_defense                           1.000000

# %% [markdown]
# ### Machine Learning Model to Predict Quarterback Passing Yards<br>
#
# Here I want to set up, roughly tune, and compare a couple of different linear regression models.<br>
# I will compare Ridge regression and Lasso regression to see if minimizing the sum of squared feature weights<br>
# or a sparse solution (where the least influential variables have their weights set to exactly 0) is better.
# <br>
# Given that the target "passing yards" does not seem to be strongly correlated with any EWMA feature,<br>
# Ridge regression may perform well (many small/medium-sized effects). However, there are many features<br>
# that do not, or at best negligibly, correlate with passing yards. Lasso regression may do well when setting<br>
# the weights of these features to 0 (only a few variables with medium/large effects).
# <br>
# To capture interactions between features, I may employ a polynomial feature transformation.<br>
# *Does this make sense? What degree would be appropriate?*
# <br>
# *As I go further into my machine learning course, I will expand and improve this section when it comes to<br>
# evaluating/optimizing models and employing more advanced algorithms.
# <br>
# More to be added...*

# %%
from sklearn.model_selection import validation_curve
from sklearn.linear_model import Ridge, Lasso, LinearRegression

def plot_validation_curve(estimator_name, param_name, param_vals, training_scores, test_scores, 
                          plot_log10=False, training_color='xkcd:slate', test_color='xkcd:brick', savefig=False, 
                          fname_out='validation_curve.pdf'
                         ):
    
    if plot_log10:
        param_vals = np.log10(param_vals)
    
    training_scores_mean = np.mean(training_scores, axis=1)
    training_scores_std  = np.std(training_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std  = np.std(test_scores, axis=1)
    
    plotted_vals = (training_scores_mean, training_scores_std, test_scores_mean, test_scores_std)
    
    fig, ax = plt.subplots(figsize=(8,6))
    
    ax.plot(param_vals, training_scores_mean, linestyle='-', linewidth=2, color=training_color, label='Training Scores')
    ax.fill_between(param_vals, np.subtract(training_scores_mean, training_scores_std), np.add(training_scores_mean, training_scores_std),
                    color=training_color, alpha=0.2, linewidth=1)
    
    ax.plot(param_vals, test_scores_mean, linestyle='-', linewidth=2, color=test_color, label='Test Scores')
    ax.fill_between(param_vals, np.subtract(test_scores_mean, test_scores_std), np.add(test_scores_mean, test_scores_std),
                    color=test_color, alpha=0.2, linewidth=1)    
    
    for val in param_vals:
        ax.axvline(x = val, linewidth=1, color='black', alpha=0.3)
        if plot_log10:
            val_text = str('%.2f' % (10**val))
        else:
            val_text = str('%.2f' % val)
        ax.text(val, 0.25, val_text, ha='center', va='center', rotation='vertical', backgroundcolor='white')
    
    ax.set_ylim([0., 0.3])
    ax.legend(loc='best')
    if plot_log10:
        ax.set_xlabel('$\log_{10}$'+'({})'.format(param_name), fontsize=12)
    else:
        ax.set_xlabel(param_name, fontsize=12)
    ax.set_ylabel('Mean $R^2$ Score ({} Folds)'.format(training_scores.shape[1]), fontsize=12)
    ax.set_title(
        '''Validation Curve for {} Regression and the {} Parameter
        (Annotations display linear {} values)'''
        .format(estimator_name, param_name, param_name),
        fontsize=14
    )
    plt.tight_layout()
    
    if savefig:
        fig.savefig(fname_out)
        
    plt.show()
    
    return plotted_vals

# %%
## Ridge regression

alpha_values = [0.01, 0.1, 0.2, 0.5, 1.0, 2.0, 5.0, 10.0, 100.0]

ridge_train_scores, ridge_test_scores = validation_curve(
    Ridge(), 
    final_merged_df.dropna().drop(columns=['player_name', 'posteam', 'defteam', 'passing_yards']),
    final_merged_df.dropna()['passing_yards'],
    param_name='alpha',
    param_range=alpha_values,
    error_score='raise'
)

ridge_agg_scores = plot_validation_curve(
    'Ridge', 
    'alpha', 
    alpha_values, 
    ridge_train_scores, 
    ridge_test_scores,
    plot_log10=True,
    savefig=True,
    fname_out='ridge_validation_curve.pdf'
)

ridge_train_scores_mean = ridge_agg_scores[0]
ridge_train_scores_std  = ridge_agg_scores[1]
ridge_test_scores_mean  = ridge_agg_scores[2]
ridge_test_scores_std   = ridge_agg_scores[3]

for i, val in enumerate(alpha_values):
    print('For the alpha value {}, the mean R^2 score and STD for the training data is: {} +/- {}'
          .format(val, '%.2f' % ridge_train_scores_mean[i], '%.2f' % ridge_train_scores_std[i])
         )
    print('For the alpha value {}, the mean R^2 score and STD for the test data is: {} +/- {}'
          .format(val, '%.2f' % ridge_test_scores_mean[i], '%.2f' % ridge_test_scores_std[i])
         )
    print()
    
print(ridge_train_scores)
# Out:
# For the alpha value 0.01, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 0.01, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 0.1, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 0.1, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 0.2, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 0.2, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 0.5, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 0.5, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 1.0, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 1.0, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 2.0, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 2.0, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 5.0, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 5.0, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 10.0, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 10.0, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 100.0, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 100.0, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# [[0.18702466 0.17934015 0.19264221 0.17220234 0.18258879]
#  [0.18702466 0.17934015 0.19264221 0.17220233 0.18258879]
#  [0.18702465 0.17934013 0.1926422  0.17220232 0.18258877]
#  [0.18702457 0.17934005 0.19264213 0.1722022  0.18258869]
#  [0.18702432 0.17933977 0.19264189 0.17220182 0.18258839]
#  [0.18702336 0.17933872 0.19264101 0.1722004  0.18258729]
#  [0.18701776 0.1793326  0.19263588 0.1721921  0.18258083]
#  [0.1870031  0.17931671 0.19262254 0.17217042 0.182564  ]
#  [0.18676386 0.17909065 0.19241253 0.17184159 0.18230331]]

# %%
## Lasso regression

alpha_values = [0.01, 0.1, 0.2, 0.5, 1.0, 2.0, 5.0, 10.0, 100.0]

lasso_train_scores, lasso_test_scores = validation_curve(
    Lasso(), 
    final_merged_df.dropna().drop(columns=['player_name', 'posteam', 'defteam', 'passing_yards']),
    final_merged_df.dropna()['passing_yards'],
    param_name='alpha',
    param_range=alpha_values,
    error_score='raise'
)

lasso_agg_scores = plot_validation_curve(
    'Lasso', 
    'alpha', 
    alpha_values, 
    lasso_train_scores, 
    lasso_test_scores,
    plot_log10=True,
    savefig=True,
    fname_out='lasso_validation_curve.pdf'
)

lasso_train_scores_mean = lasso_agg_scores[0]
lasso_train_scores_std  = lasso_agg_scores[1]
lasso_test_scores_mean  = lasso_agg_scores[2]
lasso_test_scores_std   = lasso_agg_scores[3]

for i, val in enumerate(alpha_values):
    print('For the alpha value {}, the mean R^2 score and STD for the training data is: {} +/- {}'
          .format(val, '%.2f' % lasso_train_scores_mean[i], '%.2f' % lasso_train_scores_std[i])
         )
    print('For the alpha value {}, the mean R^2 score and STD for the test data is: {} +/- {}'
          .format(val, '%.2f' % lasso_test_scores_mean[i], '%.2f' % lasso_test_scores_std[i])
         )
    print()
    
print(lasso_train_scores)
# Out:
# For the alpha value 0.01, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 0.01, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 0.1, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 0.1, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 0.2, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 0.2, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 0.5, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 0.5, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 1.0, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 1.0, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 2.0, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 2.0, the mean R^2 score and STD for the test data is: 0.17 +/- 0.02
#
# For the alpha value 5.0, the mean R^2 score and STD for the training data is: 0.18 +/- 0.01
# For the alpha value 5.0, the mean R^2 score and STD for the test data is: 0.17 +/- 0.03
#
# For the alpha value 10.0, the mean R^2 score and STD for the training data is: 0.17 +/- 0.01
# For the alpha value 10.0, the mean R^2 score and STD for the test data is: 0.17 +/- 0.03
#
# For the alpha value 100.0, the mean R^2 score and STD for the training data is: 0.15 +/- 0.01
# For the alpha value 100.0, the mean R^2 score and STD for the test data is: 0.14 +/- 0.02
#
# [[0.18701685 0.1793322  0.19263434 0.17219469 0.18258118]
#  [0.18645888 0.17881591 0.19210762 0.17166503 0.18201992]
#  [0.18605484 0.17858395 0.19164775 0.17115361 0.18160382]
#  [0.18510714 0.1780248  0.19084654 0.17015996 0.18043011]
#  [0.18334776 0.17679674 0.18972944 0.16854183 0.17942631]
#  [0.18253286 0.17596226 0.18915291 0.16781223 0.17876755]
#  [0.18041637 0.17383529 0.18716817 0.16588802 0.17693567]
#  [0.17560124 0.16992515 0.18409903 0.16187852 0.17311139]
#  [0.15288922 0.1429163  0.15903366 0.13752701 0.15091857]]
